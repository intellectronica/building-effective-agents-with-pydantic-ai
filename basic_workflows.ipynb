# %%
# %pip install pydantic-ai python-dotenv nest_asyncio
from IPython.display import clear_output ; clear_output()

from dotenv import load_dotenv ; load_dotenv()
import nest_asyncio ; nest_asyncio.apply()

# %%
import os
import asyncio
from typing import List, Dict

from pydantic import BaseModel, Field
from pydantic_ai import Agent

AI_MODEL = os.environ['AI_MODEL']

# %%
async def chain(input: str, prompts: List[str]) -> str:
    """Chain multiple LLM calls sequentially, passing results between steps."""
    agent = Agent(AI_MODEL)
    result = input
    for i, prompt in enumerate(prompts, 1):
        print(f"\nStep {i}:")
        result = (await agent.run(f"{prompt}\nInput: {result}")).data
        print(result)
    return result

# %%
data_processing_steps = [
    """Extract only the numerical values and their associated metrics from the text.
    Format each as 'value: metric' on a new line.
    Example format:
    92: customer satisfaction
    45%: revenue growth""",
    
    """Convert all numerical values to percentages where possible.
    If not a percentage or points, convert to decimal (e.g., 92 points -> 92%).
    Keep one number per line.
    Example format:
    92%: customer satisfaction
    45%: revenue growth""",
    
    """Sort all lines in descending order by numerical value.
    Keep the format 'value: metric' on each line.
    Example:
    92%: customer satisfaction
    87%: employee satisfaction""",
    
    """Format the sorted data as a markdown table with columns:
    | Metric | Value |
    |:--|--:|
    | Customer Satisfaction | 92% |"""
]

report = """
Q3 Performance Summary:
Our customer satisfaction score rose to 92 points this quarter.
Revenue grew by 45% compared to last year.
Market share is now at 23% in our primary market.
Customer churn decreased to 5% from 8%.
New user acquisition cost is $43 per user.
Product adoption rate increased to 78%.
Employee satisfaction is at 87 points.
Operating margin improved to 34%.
"""

print("\nInput text:")
print(report)
formatted_result = await chain(report, data_processing_steps)
print(formatted_result)
# Out:
# Input text:
#
# Q3 Performance Summary:
# Our customer satisfaction score rose to 92 points this quarter.
# Revenue grew by 45% compared to last year.
# Market share is now at 23% in our primary market.
# Customer churn decreased to 5% from 8%.
# New user acquisition cost is $43 per user.
# Product adoption rate increased to 78%.
# Employee satisfaction is at 87 points.
# Operating margin improved to 34%.
#
#
# Step 1:
# 92: customer satisfaction
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# 43: new user acquisition cost
# 78%: product adoption rate
# 87: employee satisfaction
# 34%: operating margin
#
# Step 2:
# 92%: customer satisfaction
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# 43%: new user acquisition cost
# 78%: product adoption rate
# 87%: employee satisfaction
# 34%: operating margin
#
# Step 3:
# Here's the input sorted in descending order by numerical value:
#
# ```
# 92%: customer satisfaction
# 87%: employee satisfaction
# 78%: product adoption rate
# 45%: revenue growth
# 43%: new user acquisition cost
# 34%: operating margin
# 23%: market share
# 5%: customer churn
# ```
#
# Step 4:
# Here is the data formatted as a markdown table:
#
# | Metric                     | Value |
# |:---------------------------|------:|
# | Customer Satisfaction      |   92% |
# | Employee Satisfaction      |   87% |
# | Product Adoption Rate      |   78% |
# | Revenue Growth             |   45% |
# | New User Acquisition Cost  |   43% |
# | Operating Margin           |   34% |
# | Market Share               |   23% |
# | Customer Churn             |    5% |
# Here is the data formatted as a markdown table:
#
# | Metric                     | Value |
# |:---------------------------|------:|
# | Customer Satisfaction      |   92% |
# | Employee Satisfaction      |   87% |
# | Product Adoption Rate      |   78% |
# | Revenue Growth             |   45% |
# | New User Acquisition Cost  |   43% |
# | Operating Margin           |   34% |
# | Market Share               |   23% |
# | Customer Churn             |    5% |

# %%
async def parallel(prompt: str, inputs: List[str]) -> List[str]:
    """Process multiple inputs concurrently with the same prompt."""
    agent = Agent(
        AI_MODEL,
        system_prompt=prompt,
    )
    results = await asyncio.gather(*[
        agent.run(input)
        for input in inputs
    ])
    return [result.data for result in results]

# %%
stakeholders = [
    """Customers:
    - Price sensitive
    - Want better tech
    - Environmental concerns""",
    
    """Employees:
    - Job security worries
    - Need new skills
    - Want clear direction""",
    
    """Investors:
    - Expect growth
    - Want cost control
    - Risk concerns""",
    
    """Suppliers:
    - Capacity constraints
    - Price pressures
    - Tech transitions"""
]

impact_results = await parallel(
    """Analyze how market changes will impact this stakeholder group.
    Provide specific impacts and recommended actions.
    Format with clear sections and priorities.""",
    stakeholders
)

for result in impact_results:
    print(result)
# Out:
# **Impact of Market Changes on Customers**
#
# 1. **Cost Fluctuations**
#
#    *Impact*: As the market experiences price volatility due to supply chain disruptions, inflation, or changes in raw material costs, price-sensitive customers will be directly affected. An increase in prices could lead to decreased purchasing power, while a decrease might increase demand.
#
#    *Recommended Actions*:
#    - Introduce flexible pricing models, such as subscription-based services or tiered pricing, to provide more options at different price points.
#    - Offer discounts or loyalty programs to retain and attract price-sensitive customers.
#    - Enhance transparency about cost structures to justify pricing and build trust.
#
# 2. **Technological Advancements**
#
#    *Impact*: As competition drives rapid technological innovation, customers desiring better tech will anticipate newer, feature-rich products. However, they also might be overwhelmed by the fast-paced changes if products become obsolete quickly.
#
#    *Recommended Actions*:
#    - Regularly update product lines with incremental improvements rather than large, infrequent overhauls.
#    - Educate customers on the benefits and usage of new technologies through webinars, guides, or interactive sessions.
#    - Offer upgrade incentives to encourage customers to transition to newer products seamlessly.
#
# 3. **Environmental Sustainability**
#
#    *Impact*: With increasing awareness and concern for environmental issues, customers are likely to favor companies that demonstrate a commitment to sustainability. Market changes that affect environmental policies, such as stricter regulations or incentives for eco-friendly practices, will shift customer expectations.
#
#    *Recommended Actions*:
#    - Invest in sustainable product design and manufacturing processes to reduce environmental impact.
#    - Communicate clearly and honestly about sustainability initiatives and achievements through marketing efforts.
#    - Implement recycling or trade-in programs to promote eco-friendly use and disposal of products.
#
# **Priorities**
#
# 1. **Address Cost Concerns**: Immediate efforts should focus on ensuring that customers can afford current offerings through flexible pricing strategies. This includes fortifying loyalty programs and ensuring pricing transparency.
#
# 2. **Enhance Technological Offerings**: Staying ahead or at least abreast of technological advancements is crucial. Focusing on frequent updates and customer education can help manage expectations and improve satisfaction.
#
# 3. **Elevate Sustainability Efforts**: Sustainable practices should be integrated into the business model and actively communicated to customers, aligning with their environmental concerns. This may require a longer-term commitment but is essential for brand loyalty and future market competitiveness.
#
# **Conclusion**
#
# Price-sensitive customers with a desire for better technology and environmental consciousness require a strategic approach that balances affordability, innovation, and sustainability. By implementing these actions, businesses can better navigate market changes and maintain strong relationships with their customer base.
# **Analysis of Market Changes Impact on Employees**
#
# **1. Job Security Worries**
#
# *Impact:*
# - **Increased Anxiety and Reduced Productivity:** Market fluctuations often lead to restructuring or downsizing, which can cause employees to feel insecure about their job stability, potentially decreasing morale and productivity.
# - **Talent Loss Risks:** High-performing employees might leave the organization due to a lack of perceived security, leading to talent drain and increased turnover rates.
#
# *Recommended Actions:*
# - **Transparent Communication:** Regularly update employees about market conditions and the company’s strategies to address them. This will build trust and reduce uncertainties.
# - **Job Assurance Programs:** Develop initiatives like internal job placement or transfer programs that reinforce employees' confidence in their job security.
#
# **2. Need New Skills**
#
# *Impact:*
# - **Skill Gaps and Reduced Competitiveness:** With changes in market demands, current skills may become obsolete, minimizing the company's ability to adapt and compete.
# - **Employee Disengagement:** If employees feel they lack the skills needed for future success, they might become disengaged, affecting overall performance.
#
# *Recommended Actions:*
# - **Training and Development Programs:** Implement upskilling and reskilling programs tailored to emerging market needs. Utilize online platforms, workshops, and professional courses to equip employees with necessary competencies.
# - **Personalized Development Plans:** Conduct skills assessments to identify individual learning needs and create tailored development plans.
#
# **3. Want Clear Direction**
#
# *Impact:*
# - **Confusion and Inefficiency:** Lack of clarity on the company’s direction in response to market changes can lead to confusion, inefficiency, and misaligned efforts.
# - **Decreased Employee Motivation:** Employees might lose motivation if they're unclear about company priorities and their role in achieving organizational goals.
#
# *Recommended Actions:*
# - **Strategic Vision Workshops:** Hold regular sessions explaining the company's vision, goals, and how changes may affect strategic directions. Encourage open discussion to align understanding.
# - **Leadership Visibility:** Encourage leadership to actively engage with employees, providing direction and reassurance. Regular presence can show commitment to guiding the team.
#
# **Priority Recommendations**
#
# 1. **Enhance Communication and Assurance:**
#    - Prioritize transparency and reassurance through regular updates and job assurance initiatives. This addresses the immediate concerns of job security and clarity, reducing anxiety.
#
# 2. **Implement Comprehensive Skill Development:**
#    - Develop and launch extensive training programs as soon as possible to address skill gaps, ensuring that employees are equipped to meet the evolving market demands.
#
# 3. **Foster a Vision-Oriented Culture:**
#    - Embed the new strategic directions into the company culture by incorporating vision workshops and increasing leadership visibility, ensuring everyone is aligned and motivated.
#
# These strategic actions will not only help in mitigating risks associated with market changes but will also prepare the workforce for future challenges, maintaining morale and productivity.
# **Analysis of Market Changes and Impacts on Investors**
#
# **1. Economic Growth and Market Trends**
#
# *Current Market Context:*
#    - The global economy is experiencing fluctuations due to factors such as geopolitical tensions, technological disruptions, and post-pandemic recovery processes.
#    - Emerging markets are showing potential for high growth, although they come with increased volatility and risks.
#
# *Impact on Investors:*
#    - **Expectation of Growth:** Investors expecting growth will be increasingly focused on sectors showing resilience and potential for expansion, such as technology and renewable energy. This trend could lead to heightened demand for stocks and equities in these areas.
#    - **Cost Control:** As markets deal with inflationary pressures, firms that can demonstrate effective cost controls will attract more investment. Investors will prioritize businesses with high operational efficiency and lean management structures.
#    - **Risk Concerns:** With the uncertainty in global markets, investors will become more risk-averse, demanding strategies that offer diversification and hedging against downside risks.
#
# *Recommended Actions:*
#    - **Diversify Investments:** To capture growth and mitigate risks, investors should diversify portfolios across a mix of sectors and geographies. Consider increasing allocations to stable blue-chip stocks while exploring high-growth emerging markets.
#    - **Focus on Cost-efficient Companies:** Invest in companies that have a strong track record of managing expenses and maintaining profit margins during inflationary periods.
#    - **Explore Technological Innovations:** Consider investments in companies at the forefront of technological innovations, as these firms are likely to drive future growth.
#
# **2. Interest Rates and Inflation**
#
# *Current Market Context:*
#    - Central banks worldwide are adjusting interest rates in response to inflationary trends, leading to fluctuating bond yields and borrowing costs.
#
# *Impact on Investors:*
#    - **Cost Control and Valuation:** Rising interest rates can increase borrowing costs for companies, affecting profit margins. Investors will need to reassess valuations and seek companies with low debt levels.
#    - **Risk Concerns:** Higher interest rates can increase the cost of debt servicing, leading to potential defaults in high-risk sectors. This increases the perceived risk and may trigger shifts to safer assets.
#
# *Recommended Actions:*
#    - **Evaluate Interest-sensitivity:** Invest in sectors less sensitive to interest rate hikes, such as healthcare, consumer staples, and utilities.
#    - **Inflation-hedging Assets:** Incorporate inflation-protected securities into portfolios to offset the erosion of purchasing power.
#    - **Focus on Dividend-yielding Stocks:** These can provide a steady income stream that can offset potential losses from rising rates.
#
# **3. Regulatory Changes and ESG Considerations**
#
# *Current Market Context:*
#    - Increasing regulatory scrutiny on environmental, social, and governance (ESG) factors is reshaping corporate policies and opening new investment opportunities in sustainability-oriented businesses.
#
# *Impact on Investors:*
#    - **Expectation of Growth:** Companies that align with ESG criteria are anticipated to experience growth due to investor preference and regulatory support.
#    - **Risk Concerns:** Non-compliance with upcoming regulations may expose companies to legal and reputational risks, reducing their attractiveness to investors.
#
# *Recommended Actions:*
#    - **Integrate ESG Criteria:** Include ESG metrics in investment decisions to align with evolving regulatory landscapes and consumer preferences.
#    - **Support Sustainable Innovations:** Invest in companies and funds focusing on sustainable solutions, as they are likely to benefit from both regulatory support and consumer trends.
#    - **Engage in Active Stewardship:** Investors should engage with companies to improve their ESG practices, thereby reducing risks and unlocking potential value enhancement.
#
# **Priority Recommendations:**
#
# 1. **Enhance Portfolio Diversification:** To manage growth expectations and risk concerns amid market volatility and inflation.
# 2. **Embrace ESG-focused Investing:** To tap into growth opportunities driven by regulatory changes and societal shifts.
# 3. **Adopt a Forward-looking Approach:** Regularly review and adjust investment strategies in response to global economic indicators and sector-specific trends to maintain growth and control costs effectively.
#
# By implementing these strategies, investors can better navigate the current market dynamics to achieve growth objectives while effectively managing risks and costs.
# ## Analysis of Market Changes on Suppliers
#
# ### 1. Capacity Constraints
#
# #### Impact:
# - **Production Bottlenecks**: Suppliers experiencing capacity constraints may face significant production bottlenecks, resulting in delays in fulfilling orders.
# - **Quality Compromise**: During periods of maximum capacity, the emphasis might shift from quality to quantity, leading to potential dissatisfaction among buyers.
# - **Customer Diversification**: Buyers may diversify their supplier base to mitigate risks, potentially reducing order volumes for current suppliers.
#
# #### Recommended Actions:
# - **Capacity Optimization**: Invest in efficient resource management systems to maximize existing capacity.
# - **Scalable Solutions**: Develop scalable production strategies that can be adjusted quickly to meet demand without compromising quality.
# - **Supplier Partnerships**: Form strategic alliances with other suppliers to share production loads and enhance collective capacity.
#
# ### 2. Price Pressures
#
# #### Impact:
# - **Margin Compression**: Rising raw material costs and competitive pricing pressures could squeeze profit margins.
# - **Cost-Pass-Through Challenges**: Difficulty in transferring increased costs to customers could strain supplier-buyer relationships.
# - **Increased Competition**: Lowering prices to stay competitive may necessitate cost-efficiencies or innovations that not all suppliers can easily achieve.
#
# #### Recommended Actions:
# - **Cost Management**: Implement robust cost-control measures and pursue cost-reduction innovations without sacrificing product quality.
# - **Value Addition**: Focus on adding value through enhanced services or product differentiation to justify pricing.
# - **Dynamic Pricing Strategies**: Develop flexible pricing models that can adapt to volatile market conditions while maintaining competitiveness.
#
# ### 3. Tech Transitions
#
# #### Impact:
# - **Investment Pressure**: The need to adopt new technologies requires significant capital investment, which may be challenging for suppliers with tighter budgets.
# - **Skill Set Evolution**: Rapid technology transitions necessitate the acquisition of new skills among the workforce and management.
# - **Legacy System Obsolescence**: Suppliers relying on outdated systems may find themselves at a competitive disadvantage.
#
# #### Recommended Actions:
# - **Incremental Tech Adoption**: Prioritize the adoption of technologies that provide the greatest immediate returns and fit within budgetary constraints.
# - **Training and Development**: Invest in training programs to upskill the workforce and align their capabilities with new technological demands.
# - **Legacy System Integration**: Explore options to integrate new technologies with existing systems to extend their usability and enhance overall performance.
#
# ## Priorities
#
# 1. **Capacity Expansion and Optimization**: Address capacity challenges by optimizing current resources and exploring scalable options.
# 2. **Cost-Effective Pricing Strategies**: Navigate price pressures by implementing dynamic pricing and cost reduction measures.
# 3. **Strategic Tech Investment**: Engage in calculated technology adoption to stay competitive while managing investment risks.
#
# Overall, a proactive approach addressing these areas will enhance the suppliers' resilience and enable them to better navigate changing market dynamics.

# %%
async def route(input: str, routes: Dict[str, str]) -> str:
    """Route input to specialized prompt using content classification."""
    # First determine appropriate route using LLM with chain-of-thought
    print(f"\nAvailable routes: {list(routes.keys())}")

    class RouteSelection(BaseModel):
        reasoning: str = Field(..., description=(
            'Brief explanation of why this ticket should be routed to a specific team. '
            'Consider key terms, user intent, and urgency level.'
        ))
        selection: str = Field(..., description='The chosen team name')
    
    route_response = await Agent(
        AI_MODEL,
        system_prompt=(
            'Analyze the input and select the most appropriate support team from these options: '
            f'{list(routes.keys())}'
        ),
        result_type=RouteSelection,
    ).run(input)
    reasoning = route_response.data.reasoning
    route_key = route_response.data.selection.strip().lower()
    
    print("Routing Analysis:")
    print(reasoning)
    print(f"\nSelected route: {route_key}")
    
    # Process input with selected specialized prompt
    return (await Agent(
        AI_MODEL,
        system_prompt=routes[route_key],
    ).run(input)).data

# %%
support_routes = {
    "billing": """You are a billing support specialist. Follow these guidelines:
    1. Always start with "Billing Support Response:"
    2. First acknowledge the specific billing issue
    3. Explain any charges or discrepancies clearly
    4. List concrete next steps with timeline
    5. End with payment options if relevant
    
    Keep responses professional but friendly.
    
    Input: """,
    
    "technical": """You are a technical support engineer. Follow these guidelines:
    1. Always start with "Technical Support Response:"
    2. List exact steps to resolve the issue
    3. Include system requirements if relevant
    4. Provide workarounds for common problems
    5. End with escalation path if needed
    
    Use clear, numbered steps and technical details.
    
    Input: """,
    
    "account": """You are an account security specialist. Follow these guidelines:
    1. Always start with "Account Support Response:"
    2. Prioritize account security and verification
    3. Provide clear steps for account recovery/changes
    4. Include security tips and warnings
    5. Set clear expectations for resolution time
    
    Maintain a serious, security-focused tone.
    
    Input: """,
    
    "product": """You are a product specialist. Follow these guidelines:
    1. Always start with "Product Support Response:"
    2. Focus on feature education and best practices
    3. Include specific examples of usage
    4. Link to relevant documentation sections
    5. Suggest related features that might help
    
    Be educational and encouraging in tone.
    
    Input: """
}

# Test with different support tickets
tickets = [
    """Subject: Can't access my account
    Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error. 
    I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to 
    submit a report by end of day.
    - John""",
    
    """Subject: Unexpected charge on my card
    Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
    I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
    Thanks,
    Sarah""",
    
    """Subject: How to export data?
    Message: I need to export all my project data to Excel. I've looked through the docs but can't
    figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
    Best regards,
    Mike"""
]

print("Processing support tickets...\n")
for i, ticket in enumerate(tickets, 1):
    print(f"\nTicket {i}:")
    print("-" * 40)
    print(ticket)
    print("\nResponse:")
    print("-" * 40)
    response = await route(ticket, support_routes)
    print(response)
# Out:
# Processing support tickets...
#
#
# Ticket 1:
# ----------------------------------------
# Subject: Can't access my account
#     Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error.
#     I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to
#     submit a report by end of day.
#     - John
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
# The user's primary issue is being unable to log in to their account due to an "invalid password" error, despite being sure of entering the correct password. This suggests that the problem is related to account access or potential password/security issues. Thus, the 'account' support team is best equipped to handle such issues, as they generally deal with login problems, password resets, and account recovery.
#
# Selected route: account
# Account Support Response:
#
# To address your access issue, please follow the steps outlined below:
#
# 1. **Verify and Reset Password:**
#    - Navigate to the login page of your account and select "Forgot Password?"
#    - Enter your email address or username associated with the account.
#    - Check your email inbox (and spam/junk folder) for a password reset link. Click the link and follow the instructions to create a new, secure password.
#
# 2. **Check Email Notifications:**
#    - Ensure your email is up-to-date and check for any notifications regarding login attempts or changes to your account. Report any unfamiliar activity immediately.
#
# 3. **Account Security Verification:**
#    - If you continue to encounter issues, it may be necessary to conduct further verification for security purposes. Please contact support through your account's official support page or use a verified contact method to ensure the integrity of the communication.
#
# 4. **Further Assistance:**
#    - If resetting your password does not resolve the issue, please provide the support team with:
#      - Full name
#      - Account username
#      - Recent login attempts with dates and times for additional context.
#
# **Security Tips:**
# - Avoid reusing passwords across multiple sites. Use a combination of letters, numbers, and symbols.
# - Enable two-factor authentication (2FA) for an added layer of security.
#
# **Expected Resolution Time:**
# - Password reset requests are generally processed within a few minutes, but email delivery may vary. If further verification is required, resolution could extend to 24-48 hours.
#
# Please address these steps promptly to regain access and meet your report submission deadline.
#
# For any unresolved access issues, do not hesitate to reach out immediately through official contact methods. Your account security and timely access are a priority.
#
# Ticket 2:
# ----------------------------------------
# Subject: Unexpected charge on my card
#     Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
#     I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
#     Thanks,
#     Sarah
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
# Sarah is inquiring about an unexpected charge and mentions a billing issue regarding her subscription plan. The issue revolves around payment discrepancies, which falls under the scope of the billing team. The billing team is responsible for addressing questions about charges, adjusting subscriptions, and handling financial transactions, making them the most appropriate to address her concern.
#
# Selected route: billing
# Billing Support Response:
#
# Hello Sarah,
#
# Thank you for reaching out to us regarding the unexpected charge on your card.
#
# Upon reviewing your account, I can confirm that the charge of $49.99 was indeed processed. It appears that your account was automatically upgraded to a plan that costs $49.99, which may have led to this discrepancy. The upgrade could have been initiated if there was an adjustment in your service needs or an automatic feature enhancement associated with your account settings.
#
# To resolve this, I will:
# 1. Verify your subscription details and make sure your account reflects the plan you originally intended to subscribe to.
# 2. Initiate a refund for the difference of $20, ensuring you are only charged the $29.99 as per your intended plan. Please allow 3-5 business days for the refund to be processed and to reflect on your card.
# 3. Confirm any modifications to your account settings to prevent future occurrences.
#
# Please double-check your account settings and reach out if you need further adjustments. If you have any preferences for changes to your account or require assistance in adjusting subscription settings, feel free to let us know.
#
# For the payment that was processed, you can continue using your preferred credit card. If there are any other issues or additional changes needed, we're here to assist.
#
# Thank you for your patience and understanding.
#
# Best regards,
# Billing Support Team
#
# Ticket 3:
# ----------------------------------------
# Subject: How to export data?
#     Message: I need to export all my project data to Excel. I've looked through the docs but can't
#     figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
#     Best regards,
#     Mike
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
# The customer is inquiring about exporting data to Excel, which is a technical operation that involves data management and software functionalities. This is directly related to software usage issues, thus making the 'technical' support team the most appropriate choice to help with this inquiry.
#
# Selected route: technical
# Technical Support Response:
#
# 1. **Access Export Feature**:
#    - Open the project management application you're using.
#    - Navigate to the section where your project data is stored.
#    - Look for an 'Export' or 'Export Data' option, generally available in the 'File' or 'Menu' toolbar.
#
# 2. **Select Data to Export**:
#    - Once in the export section, you will need to choose the data you wish to export.
#    - There should be options to select specific projects or choose 'Select All' for a complete export.
#
# 3. **Choose Export Format**:
#    - Select 'Excel' or 'CSV' as your export format. Most applications support direct export to Excel or provide CSV format, which can then be opened with Excel.
#
# 4. **System Requirements**:
#    - Ensure you have Excel 2013 or later version installed on your system.
#    - The application should support bulk data export functionality (consult the specific application guide for detailed capabilities).
#
# 5. **Initiate Export**:
#    - Click the 'Export' button after confirming your selections.
#    - Choose the destination on your device where the Excel file will be saved.
#    - You might be prompted to name the file or confirm download location.
#
# 6. **Verify and Troubleshoot**:
#    - After the export, open the file in Excel to verify all the data has been exported accurately.
#    - If data appears missing or garbled, ensure your system supports the file format and version compatibility.
#
# 7. **Common Problems**:
#    - If the 'Export' option is inaccessible, check your user permissions. You may need administrative access.
#    - In case of export limits (like number of rows), perform multiple exports of subsets of data if necessary.
#
# 8. **Escalation Path**:
#    - If you encounter issues beyond these steps, reach out to your IT department for additional access rights.
#    - Contact [Application Name] Support directly by visiting their support page or calling their helpline.
