# %%
# %pip install pydantic-ai python-dotenv nest_asyncio
from IPython.display import clear_output ; clear_output()

from dotenv import load_dotenv ; load_dotenv()
import nest_asyncio ; nest_asyncio.apply()

# %%
import os
import asyncio
from typing import List, Dict

from pydantic import BaseModel, Field
from pydantic_ai import Agent

AI_MODEL = os.environ['AI_MODEL']

# %%
async def chain(input: str, prompts: List[str]) -> str:
    """Chain multiple LLM calls sequentially, passing results between steps."""
    agent = Agent(AI_MODEL)
    result = input
    for i, prompt in enumerate(prompts, 1):
        print(f"\nStep {i}:")
        result = (await agent.run(f"{prompt}\nInput: {result}")).data
        print(result)
    return result

# %%
data_processing_steps = [
    """Extract only the numerical values and their associated metrics from the text.
    Format each as 'value: metric' on a new line.
    Example format:
    92: customer satisfaction
    45%: revenue growth""",
    
    """Convert all numerical values to percentages where possible.
    If not a percentage or points, convert to decimal (e.g., 92 points -> 92%).
    Keep one number per line.
    Example format:
    92%: customer satisfaction
    45%: revenue growth""",
    
    """Sort all lines in descending order by numerical value.
    Keep the format 'value: metric' on each line.
    Example:
    92%: customer satisfaction
    87%: employee satisfaction""",
    
    """Format the sorted data as a markdown table with columns:
    | Metric | Value |
    |:--|--:|
    | Customer Satisfaction | 92% |"""
]

report = """
Q3 Performance Summary:
Our customer satisfaction score rose to 92 points this quarter.
Revenue grew by 45% compared to last year.
Market share is now at 23% in our primary market.
Customer churn decreased to 5% from 8%.
New user acquisition cost is $43 per user.
Product adoption rate increased to 78%.
Employee satisfaction is at 87 points.
Operating margin improved to 34%.
"""

print("\nInput text:")
print(report)
formatted_result = await chain(report, data_processing_steps)
print(formatted_result)
# Out:
# Input text:
#
# Q3 Performance Summary:
# Our customer satisfaction score rose to 92 points this quarter.
# Revenue grew by 45% compared to last year.
# Market share is now at 23% in our primary market.
# Customer churn decreased to 5% from 8%.
# New user acquisition cost is $43 per user.
# Product adoption rate increased to 78%.
# Employee satisfaction is at 87 points.
# Operating margin improved to 34%.
#
#
# Step 1:
# 92: customer satisfaction
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# 43: user acquisition cost
# 78%: product adoption rate
# 87: employee satisfaction
# 34%: operating margin
#
# Step 2:
# 92%: customer satisfaction
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# 43%: user acquisition cost
# 78%: product adoption rate
# 87%: employee satisfaction
# 34%: operating margin
#
# Step 3:
# Here is the sorted list in descending order by numerical value:
#
# ```
# 92%: customer satisfaction
# 87%: employee satisfaction
# 78%: product adoption rate
# 45%: revenue growth
# 43%: user acquisition cost
# 34%: operating margin
# 23%: market share
# 5%: customer churn
# ```
#
# Step 4:
# Here is the markdown table formatted with the sorted data:
#
# ```markdown
# | Metric                  | Value |
# |:------------------------|------:|
# | Customer Satisfaction   |   92% |
# | Employee Satisfaction   |   87% |
# | Product Adoption Rate   |   78% |
# | Revenue Growth          |   45% |
# | User Acquisition Cost   |   43% |
# | Operating Margin        |   34% |
# | Market Share            |   23% |
# | Customer Churn          |    5% |
# ```
# Here is the markdown table formatted with the sorted data:
#
# ```markdown
# | Metric                  | Value |
# |:------------------------|------:|
# | Customer Satisfaction   |   92% |
# | Employee Satisfaction   |   87% |
# | Product Adoption Rate   |   78% |
# | Revenue Growth          |   45% |
# | User Acquisition Cost   |   43% |
# | Operating Margin        |   34% |
# | Market Share            |   23% |
# | Customer Churn          |    5% |
# ```

# %%
async def parallel(prompt: str, inputs: List[str]) -> List[str]:
    """Process multiple inputs concurrently with the same prompt."""
    agent = Agent(
        AI_MODEL,
        system_prompt=prompt,
    )
    results = await asyncio.gather(*[
        agent.run(input)
        for input in inputs
    ])
    return [result.data for result in results]

# %%
stakeholders = [
    """Customers:
    - Price sensitive
    - Want better tech
    - Environmental concerns""",
    
    """Employees:
    - Job security worries
    - Need new skills
    - Want clear direction""",
    
    """Investors:
    - Expect growth
    - Want cost control
    - Risk concerns""",
    
    """Suppliers:
    - Capacity constraints
    - Price pressures
    - Tech transitions"""
]

impact_results = await parallel(
    """Analyze how market changes will impact this stakeholder group.
    Provide specific impacts and recommended actions.
    Format with clear sections and priorities.""",
    stakeholders
)

for result in impact_results:
    print(result)
# Out:
# ### Analysis of Market Changes on Customers
#
# **1. Economic Fluctuations:**
#
# **Impact:**
# - Price-sensitive customers are likely to be heavily influenced by any changes in the economy, such as inflation and shifts in disposable income, which may affect their purchasing decisions.
# - Rising costs in production due to economic changes could lead to increased retail prices, directly impacting this group negatively.
#
# **Recommended Actions:**
# - Implement differential pricing strategies and offer discounts or loyalty programs to reduce the burden of increased prices.
# - Increase transparency in pricing by showing how costs are calculated to gain customer trust and understanding.
#
# **2. Technological Advancements:**
#
# **Impact:**
# - Customers demanding better technology will gravitate towards products that offer the latest and most efficient technological innovations.
# - A failure to innovate quickly could lead to customers defecting to competitors that provide up-to-date technological solutions.
#
# **Recommended Actions:**
# - Invest in research and development to stay ahead of technological trends and bring innovative products to the market.
# - Establish partnerships with tech companies to integrate cutting-edge technologies into existing products.
#
# **3. Environmental Concerns:**
#
# **Impact:**
# - Environmentally conscious customers will favor companies that prioritize sustainability in their business practices and offer eco-friendly products.
# - Companies failing to address environmental issues may face boycotts or damage to their reputation.
#
# **Recommended Actions:**
# - Implement sustainable practices in production, packaging, and distribution to minimize the environmental footprint.
# - Clearly communicate sustainability efforts and the environmental benefits of products through marketing channels.
# - Obtain certifications or labels that affirm the eco-friendliness of products.
#
# ### Prioritization of Actions
#
# **High Priority:**
# 1. Develop robust pricing strategies and customer loyalty programs to mitigate economic impacts on price-sensitive customers.
# 2. Invest in sustainable initiatives and effectively communicate these efforts to build trust with environmentally concerned customers.
#
# **Medium Priority:**
# 1. Enhance partnerships and R&D initiatives focusing on technological advancements to meet the demands for better tech.
#
# **Low Priority:**
# 1. Analyze consumer behavior and feedback regularly to adjust strategies quickly in response to market changes.
#
# Adopting these strategies will help in maintaining customer loyalty and ensuring competitiveness in a changing market landscape.
# **Impact of Market Changes on Employees**
#
# As the market landscape evolves, employees inevitably experience various impacts due to these shifts. Understanding and addressing the implications can help facilitate a smooth transition and ensure organizational stability.
#
# ### 1. Job Security Worries
#
# **Impacts:**
# - **Increased Anxiety**: Employees may become anxious about potential layoffs or restructuring.
# - **Decline in Productivity**: Worries about job security can lead to decreased concentration and morale, impacting overall performance.
# - **Resistance to Change**: Fear of job loss can make employees resistant to adapting new processes or technologies.
#
# **Recommended Actions:**
# - **Transparent Communication**: Regular updates about company performance, market changes, and job security can alleviate fears. Open forums or town halls can be effective.
# - **Job Assurance Programs**: Implement programs like retraining, redeployment, or offers of additional projects within the company to show commitment to employee retention.
# - **Employee Support Systems**: Establish support channels such as counseling or stress management workshops to aid employees in coping with uncertainty.
#
# ### 2. Need for New Skills
#
# **Impacts:**
# - **Skill Gaps**: With technological advancements, there is a risk of skill obsolescence, causing reduced employee value in the marketplace.
# - **Career Stagnation**: Lack of opportunities to acquire new skills may hinder career progression and lead to dissatisfaction.
# - **Increased Turnover**: Employees may leave in search of better opportunities that offer learning and development.
#
# **Recommended Actions:**
# - **Training Programs**: Invest in upskilling and reskilling programs tailored to emerging market demands. Include workshops, courses, and certifications.
# - **Mentorship and Guidance**: Pair employees with mentors who can provide career advice and skill development guidance.
# - **Incentives for Learning**: Offer incentives for employees who actively participate in skill enhancement programs, such as bonuses or recognitions.
#
# ### 3. Desire for Clear Direction
#
# **Impacts:**
# - **Uncertainty and Confusion**: Without a clear direction, employees might feel lost, leading to misaligned efforts with the company’s goals.
# - **Lack of Motivation**: Ambiguity in direction may demotivate employees, reducing engagement and initiative.
# - **Miscommunication**: A lack of clear direction can result in misunderstandings about roles and responsibilities.
#
# **Recommended Actions:**
# - **Define and Communicate Vision**: Clearly articulate the company’s vision, goals, and strategy in response to market changes. Ensure alignment across all departments.
# - **Regular Feedback Loops**: Establish channels for continuous feedback and ensure employees understand how their roles contribute to the company’s objectives.
# - **Targeted Leadership Development**: Equip leaders to effectively communicate changes and strategies to their teams, reinforcing confidence in the direction.
#
# **Priorities:**
#
# 1. **Communication**: First and foremost, address job security concerns with transparent and regular communication to build trust.
# 2. **Training and Development**: Implement structured and comprehensive skill development programs, given their long-term impact on employee value and satisfaction.
# 3. **Strategic Alignment**: Ensure that leadership distinctly shares the company’s strategic direction and empowers teams with the necessary tools to meet these objectives.
#
# Addressing these factors thoughtfully will not only reduce the negative impacts of market changes on employees but will also enhance organizational resilience and adaptability.
# ### Analysis of Market Changes Impacting Investors
#
# **1. Expectations for Growth**
#
# - **Current Market Trends:** In 2023, markets are experiencing varied growth rates across different sectors, with particular emphasis on technology and green energy. However, geopolitical tensions and supply chain disruptions are creating unpredictable environments.
#
# - **Impact on Investors:** Investors are likely to prioritize portfolios that include high-growth sectors such as technology and sustainable energy. This might lead to shifts in investment strategies, focusing on companies with strong growth potential and innovative capabilities.
#
# - **Recommended Actions:**
#   - **Diversify Portfolios:** Encourage diversification into emerging markets and resilient industries.
#   - **Focus on Innovation:** Direct investments towards companies with robust R&D and innovation pipelines.
#   - **Monitor Market Trends:** Stay informed about sector performance and adjust strategies accordingly to capitalize on growth opportunities.
#
# **2. Cost Control**
#
# - **Current Market Trends:** Inflationary pressures and increased operational costs are prevalent, forcing companies to implement stringent cost control measures.
#
# - **Impact on Investors:** Investors demand evidence of efficient cost management from companies to ensure profitability despite higher costs. Companies unable to control costs effectively may see decreased investor confidence.
#
# - **Recommended Actions:**
#   - **Invest in Efficiency:** Look for companies that are investing in automation and technology to reduce operational costs.
#   - **Demand Transparency:** Insist on clear financial disclosures that outline cost management strategies.
#   - **Evaluate Management Practices:** Prioritize investments in companies with a proven track record of efficient cost management and lean operations.
#
# **3. Risk Concerns**
#
# - **Current Market Trends:** Global uncertainties, such as geopolitical tensions, climate change impact, and potential economic downturns, elevate risk concerns.
#
# - **Impact on Investors:** Investors may become risk-averse, seeking safer and more stable investments. Heightened risk perception may lead to an increase in demand for thorough risk assessments of potential investments.
#
# - **Recommended Actions:**
#   - **Enhance Risk Management Frameworks:** Invest in companies with strong risk management practices in place.
#   - **Increase Due Diligence:** Conduct comprehensive research and risk analysis before committing to investments.
#   - **Opt for Risk Mitigating Instruments:** Utilize financial instruments that hedge against market volatility, such as derivatives or diversified ETFs.
#
# ### Priorities for Investors
#
# **Top Priorities:**
# 1. **Adapt Investment Strategies:** Shift focus to sectors demonstrating resilience and potential for growth amidst market changes.
# 2. **Enforce Cost-Efficiency:** Prioritize investments in companies with robust cost-control measures and transparency.
# 3. **Strengthen Risk Management:** Enhance due diligence processes and investment in risk mitigation strategies.
#
# By addressing growth potential, enforcing cost efficiency, and bolstering risk management, investors can navigate market changes effectively to safeguard their investments and optimize returns.
# Market Changes Impacting Suppliers:
#
# 1. **Capacity Constraints:**
#
#     **Impacts:**
#     - Increased demand or supply chain disruptions may lead to challenges in meeting delivery schedules.
#     - Potential revenue loss due to inability to fulfill orders.
#     - Strain on production facilities and workforce, potentially leading to increased overtime costs or need for temporary labor.
#
#     **Recommended Actions:**
#     - Prioritize strategic partnerships to secure stable raw material supplies.
#     - Invest in capacity expansion or optimization projects to improve efficiency and throughput.
#     - Implement advanced demand forecasting tools to better manage inventory and production planning.
#     - Consider establishing contingency plans, such as relationships with alternative suppliers, to mitigate risks from single points of failure.
#
# 2. **Price Pressures:**
#
#     **Impacts:**
#     - Profit margins may shrink as costs of raw materials, labor, or logistics increase.
#     - Price competitiveness could be affected if unable to pass on cost increases to customers.
#     - Potential loss of business to competitors with more efficient cost structures or alternative sourcing options.
#
#     **Recommended Actions:**
#     - Engage in cost analysis and lean manufacturing to identify areas for operational cost reduction.
#     - Negotiate long-term contracts with fixed pricing with key customers or suppliers to stabilize cost structures.
#     - Diversify product offerings to include value-added services that can justify price increases or improve margins.
#     - Explore options for bulk purchasing or alternative materials to lower costs.
#
# 3. **Tech Transitions:**
#
#     **Impacts:**
#     - Potential disruption in the supply chain as industries shift towards new technologies, requiring suppliers to adapt quickly.
#     - Need for re-skilling or up-skilling workforce to handle new technologies and tools.
#     - Initial capital expenditure towards new machinery, systems, or processes could impact cash flow.
#
#     **Recommended Actions:**
#     - Invest in R&D to stay ahead of technological trends and maintain relevance in the market.
#     - Form alliances with tech innovators to leverage cutting-edge solutions at a lower cost.
#     - Gradually integrate new technologies with minimal disruption by planning phased rollouts and training programs.
#     - Assess current capabilities and identify gaps that need addressing to meet future tech demands effectively.
#
# **Priority Actions:**
#
# 1. **Capacity Expansion and Efficiency:**
#    - Immediately assess current production capabilities and invest in bottleneck solutions.
#    - Develop strategic contingency plans to handle sudden demand spikes or supply disruptions.
#
# 2. **Cost Management and Strategic Pricing:**
#    - Initiate cost reduction programs and negotiate strategic partnerships to combat price pressures.
#    - Evaluate pricing strategies with customer-centric value propositions to maintain competitiveness.
#
# 3. **Investing in Technology and Workforce Development:**
#    - Prioritize workforce training and re-skilling to handle technological advancements.
#    - Implement technology transition plans to ensure seamless adaptation with minimal disruption.
#
# By systematically addressing these market changes, suppliers can not only mitigate potential risks but also capitalize on emerging opportunities for growth and innovation.

# %%
async def route(input: str, routes: Dict[str, str]) -> str:
    """Route input to specialized prompt using content classification."""
    # First determine appropriate route using LLM with chain-of-thought
    print(f"\nAvailable routes: {list(routes.keys())}")

    class RouteSelection(BaseModel):
        reasoning: str = Field(..., description=(
            'Brief explanation of why this ticket should be routed to a specific team. '
            'Consider key terms, user intent, and urgency level.'
        ))
        selection: str = Field(..., description='The chosen team name')
    
    route_response = await Agent(
        AI_MODEL,
        system_prompt=(
            'Analyze the input and select the most appropriate support team from these options: '
            f'{list(routes.keys())}'
        ),
        result_type=RouteSelection,
    ).run(input)
    reasoning = route_response.data.reasoning
    route_key = route_response.data.selection.strip().lower()
    
    print("Routing Analysis:")
    print(reasoning)
    print(f"\nSelected route: {route_key}")
    
    # Process input with selected specialized prompt
    return (await Agent(
        AI_MODEL,
        system_prompt=routes[route_key],
    ).run(input)).data

# %%
support_routes = {
    "billing": """You are a billing support specialist. Follow these guidelines:
    1. Always start with "Billing Support Response:"
    2. First acknowledge the specific billing issue
    3. Explain any charges or discrepancies clearly
    4. List concrete next steps with timeline
    5. End with payment options if relevant
    
    Keep responses professional but friendly.
    
    Input: """,
    
    "technical": """You are a technical support engineer. Follow these guidelines:
    1. Always start with "Technical Support Response:"
    2. List exact steps to resolve the issue
    3. Include system requirements if relevant
    4. Provide workarounds for common problems
    5. End with escalation path if needed
    
    Use clear, numbered steps and technical details.
    
    Input: """,
    
    "account": """You are an account security specialist. Follow these guidelines:
    1. Always start with "Account Support Response:"
    2. Prioritize account security and verification
    3. Provide clear steps for account recovery/changes
    4. Include security tips and warnings
    5. Set clear expectations for resolution time
    
    Maintain a serious, security-focused tone.
    
    Input: """,
    
    "product": """You are a product specialist. Follow these guidelines:
    1. Always start with "Product Support Response:"
    2. Focus on feature education and best practices
    3. Include specific examples of usage
    4. Link to relevant documentation sections
    5. Suggest related features that might help
    
    Be educational and encouraging in tone.
    
    Input: """
}

# Test with different support tickets
tickets = [
    """Subject: Can't access my account
    Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error. 
    I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to 
    submit a report by end of day.
    - John""",
    
    """Subject: Unexpected charge on my card
    Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
    I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
    Thanks,
    Sarah""",
    
    """Subject: How to export data?
    Message: I need to export all my project data to Excel. I've looked through the docs but can't
    figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
    Best regards,
    Mike"""
]

print("Processing support tickets...\n")
for i, ticket in enumerate(tickets, 1):
    print(f"\nTicket {i}:")
    print("-" * 40)
    print(ticket)
    print("\nResponse:")
    print("-" * 40)
    response = await route(ticket, support_routes)
    print(response)
# Out:
# Processing support tickets...
#
#
# Ticket 1:
# ----------------------------------------
# Subject: Can't access my account
#     Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error.
#     I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to
#     submit a report by end of day.
#     - John
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
# John is experiencing a login issue where he receives an 'invalid password' error despite using the correct password. This is a typical issue that falls under the 'account' support team, as it involves user access and authentication problems. Given the urgency (needing to submit a report by end of day), this requires prompt attention from the account team.
#
# Selected route: account
# Account Support Response:
#
# Thank you for reaching out to us regarding your access issue, John. We understand the urgency of your situation and will do our best to assist you promptly.
#
# 1. Firstly, attempt to reset your password by using the 'Forgot Password' feature on the login page. You will need access to the email address associated with your account to receive the password reset link.
#
# 2. If you do not receive the reset email, please check your spam or junk folder. Ensure your email account is functioning correctly to avoid missing important communications.
#
# 3. In the event the reset link does not resolve the issue, or if you do not have access to your email, please contact our customer support team directly. For security purposes, be prepared to verify your identity. This may include providing information such as recent transactions, security questions, or any other confirmations related to your account.
#
# Security Tips:
# - Never share your password or account details with anyone.
# - Regularly update your password and use a strong, unique combination of characters.
# - Enable two-factor authentication if available, for an added layer of security.
#
# Please note, account verification and recovery can take up to 24 hours depending on the complexity of the situation and verification process. We appreciate your patience and understanding as we work to secure your account.
#
# Should you require further assistance, don’t hesitate to get in touch. Our team is here to ensure your account's safety and help you regain access promptly.
#
# Best regards,
# Account Security Team
#
# Ticket 2:
# ----------------------------------------
# Subject: Unexpected charge on my card
#     Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
#     I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
#     Thanks,
#     Sarah
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
# The user is inquiring about an unexpected charge on their credit card and is questioning their current billing plan. This situation involves understanding the billing details and potentially making a financial adjustment, which falls under the responsibilities of the billing support team. The user's message indicates a need for clarification and possibly correction of the billing amount, aligning with billing support functionalities.
#
# Selected route: billing
# Billing Support Response:
#
# Hello Sarah,
#
# Thank you for reaching out and bringing this to our attention. I understand that you're concerned about a $49.99 charge on your credit card when you expected to be charged $29.99.
#
# Upon reviewing your account, it appears that the charge of $49.99 is for the upgraded plan, which includes additional benefits and features compared to the $29.99 plan. This upgrade might have occurred accidentally, or perhaps during a recent promotional period, which sometimes results in automatic enrollment after the trial ends.
#
# As a next step, I will initiate a review of your account to confirm if there was an unintended change to your plan. You can expect this to be resolved within 3-5 business days. If it was indeed a mistake, we will adjust your billing and issue a refund for the difference to your credit card.
#
# In the meantime, if you'd like to revert to the $29.99 plan immediately, feel free to let us know, and we can expedite this process.
#
# If you decide to keep the upgraded plan, or after the issue is resolved, you have various payment options: you can continue with credit card payments, switch to direct debit, or pay via PayPal for best convenience.
#
# Please let me know if there is anything else I can assist you with.
#
# Best regards,
# [Your Name]
#
# Ticket 3:
# ----------------------------------------
# Subject: How to export data?
#     Message: I need to export all my project data to Excel. I've looked through the docs but can't
#     figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
#     Best regards,
#     Mike
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
# The user's query is related to exporting data, which is a technical function of the product. The user is having trouble finding this functionality in the documentation and needs assistance, but it is not related to billing, account details, or general product inquiries. Therefore, the technical support team is the most suitable team to handle this request, as they likely have detailed knowledge about data handling and can provide step-by-step guidance.
#
# Selected route: technical
# Technical Support Response:
#
# To export your project data to Excel, please follow these steps:
#
# 1. **Check System Requirements:**
#    - Ensure that you have Microsoft Excel installed on your system. Any version from Excel 2010 and later should work.
#    - Make sure your project management software allows for data export functionality.
#
# 2. **Procedure to Export Data:**
#    - **Step 1:** Log in to your project management tool using your credentials.
#    - **Step 2:** Navigate to the section where your projects are listed. This may be labeled as "Projects," "Dashboard," or "Reports," depending on the software you use.
#    - **Step 3:** Look for an "Export" or "Download" option. This is often found in a toolbar at the top or as a part of a dropdown menu beside the project or data you wish to export.
#    - **Step 4:** Select the export format. Choose "Excel" or ".xlsx" format if available.
#    - **Step 5:** Specify the data range if prompted. You can usually select specific date ranges or choose "All Data" to export everything.
#    - **Step 6:** Initiate the export by clicking on the "Export," "Download," or "Generate Report" button.
#    - **Step 7:** Once the file is ready, download the file to your computer.
#
# 3. **Common Workarounds:**
#    - If the "Export" option is not available, explore if there's a "Print to Excel" option via the Print menu.
#    - Check for third-party plugins or add-ons that facilitate Excel exports if your software does not natively support this feature.
#
# 4. **Escalation Path:**
#    - If you encounter any errors or the export option is non-existent, please contact your software's customer support team for advanced assistance. Provide them with your account details and any error messages or screenshots for quicker resolution.
#    - Additionally, check the software’s online community forums for user-shared solutions or direct your query to their technical support desk for further assistance.
#
# Please let us know if you require any additional help.
#
# Best regards,
# Technical Support Team
