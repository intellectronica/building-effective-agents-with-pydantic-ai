# %%
# %pip install pydantic-ai python-dotenv nest_asyncio
from IPython.display import clear_output ; clear_output()

from dotenv import load_dotenv ; load_dotenv(override=True)
import nest_asyncio ; nest_asyncio.apply()

import os
import asyncio
import random
from typing import List, Dict
from pprint import pprint, pformat

from pydantic import BaseModel, Field
from pydantic_ai import Agent

_ai_models = (
    [] + 
    (['openai:gpt-4o', 'openai:gpt-4o-mini'] if os.environ.get('OPENAI_API_KEY') else []) +
    (['gemini-1.5-pro', 'gemini-2.0-flash-exp'] if os.environ.get('GEMINI_API_KEY') else []) +
    (['claude-3-5-haiku-latest', 'claude-3-5-sonnet-latest'] if os.environ.get('ANTHROPIC_API_KEY') else [])
)
print(f"Available AI models: {pformat(_ai_models)}\n")

AI_MODEL = os.environ['AI_MODEL'] if os.environ.get('AI_MODEL') else random.choice(_ai_models)
print(f"Using AI model: {AI_MODEL}")
# Out:
# Available AI models: ['openai:gpt-4o',
#  'openai:gpt-4o-mini',
#  'gemini-1.5-pro',
#  'gemini-2.0-flash-exp',
#  'claude-3-5-haiku-latest',
#  'claude-3-5-sonnet-latest']
#
# Using AI model: openai:gpt-4o

# %%
async def chain(input: str, prompts: List[str]) -> str:
    """Chain multiple LLM calls sequentially, passing results between steps."""
    agent = Agent(AI_MODEL)
    result = input
    for i, prompt in enumerate(prompts, 1):
        print(f"\nStep {i}:")
        result = (await agent.run(f"{prompt}\nInput: {result}")).data
        print(result)
    return result

# %%
data_processing_steps = [
    """Extract only the numerical values and their associated metrics from the text.
    Format each as 'value: metric' on a new line.
    Example format:
    92: customer satisfaction
    45%: revenue growth""",
    
    """Convert all numerical values to percentages where possible.
    If not a percentage or points, convert to decimal (e.g., 92 points -> 92%).
    Keep one number per line.
    Example format:
    92%: customer satisfaction
    45%: revenue growth""",
    
    """Sort all lines in descending order by numerical value.
    Keep the format 'value: metric' on each line.
    Example:
    92%: customer satisfaction
    87%: employee satisfaction""",
    
    """Format the sorted data as a markdown table with columns:
    | Metric | Value |
    |:--|--:|
    | Customer Satisfaction | 92% |"""
]

report = """
Q3 Performance Summary:
Our customer satisfaction score rose to 92 points this quarter.
Revenue grew by 45% compared to last year.
Market share is now at 23% in our primary market.
Customer churn decreased to 5% from 8%.
New user acquisition cost is $43 per user.
Product adoption rate increased to 78%.
Employee satisfaction is at 87 points.
Operating margin improved to 34%.
"""

print("\nInput text:")
print(report)
formatted_result = await chain(report, data_processing_steps)
print(formatted_result)
# Out:
# Input text:
#
# Q3 Performance Summary:
# Our customer satisfaction score rose to 92 points this quarter.
# Revenue grew by 45% compared to last year.
# Market share is now at 23% in our primary market.
# Customer churn decreased to 5% from 8%.
# New user acquisition cost is $43 per user.
# Product adoption rate increased to 78%.
# Employee satisfaction is at 87 points.
# Operating margin improved to 34%.
# Step 1:
# 92: customer satisfaction
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# 43: new user acquisition cost
# 78%: product adoption rate
# 87: employee satisfaction
# 34%: operating margin
#
# Step 2:
# 92%: customer satisfaction
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# 43%: new user acquisition cost
# 78%: product adoption rate
# 87%: employee satisfaction
# 34%: operating margin
#
# Step 3:
# To sort the lines in descending order by numerical value while keeping the format 'value: metric,' follow these steps:
#
# 1. List the input lines:
#    - 92%: customer satisfaction
#    - 45%: revenue growth
#    - 23%: market share
#    - 5%: customer churn
#    - 43%: new user acquisition cost
#    - 78%: product adoption rate
#    - 87%: employee satisfaction
#    - 34%: operating margin
#
# 2. Identify and compare the numerical values in each line.
#
# 3. Sort the lines based on these numerical values in descending order.
#
# Here's the sorted output:
#
# ```
# 92%: customer satisfaction
# 87%: employee satisfaction
# 78%: product adoption rate
# 45%: revenue growth
# 43%: new user acquisition cost
# 34%: operating margin
# 23%: market share
# 5%: customer churn
# ```
#
# Step 4:
# Based on the sorted data, here is the markdown table with columns:
#
# ```markdown
# | Metric                      | Value |
# |:----------------------------|------:|
# | Customer Satisfaction       |   92% |
# | Employee Satisfaction       |   87% |
# | Product Adoption Rate       |   78% |
# | Revenue Growth              |   45% |
# | New User Acquisition Cost   |   43% |
# | Operating Margin            |   34% |
# | Market Share                |   23% |
# | Customer Churn              |    5% |
# ```
# Based on the sorted data, here is the markdown table with columns:
#
# ```markdown
# | Metric                      | Value |
# |:----------------------------|------:|
# | Customer Satisfaction       |   92% |
# | Employee Satisfaction       |   87% |
# | Product Adoption Rate       |   78% |
# | Revenue Growth              |   45% |
# | New User Acquisition Cost   |   43% |
# | Operating Margin            |   34% |
# | Market Share                |   23% |
# | Customer Churn              |    5% |
# ```

# %%
async def parallel(prompt: str, inputs: List[str]) -> List[str]:
    """Process multiple inputs concurrently with the same prompt."""
    agent = Agent(
        AI_MODEL,
        system_prompt=prompt,
    )
    results = await asyncio.gather(*[
        agent.run(input)
        for input in inputs
    ])
    return [result.data for result in results]

# %%
stakeholders = [
    """Customers:
    - Price sensitive
    - Want better tech
    - Environmental concerns""",
    
    """Employees:
    - Job security worries
    - Need new skills
    - Want clear direction""",
    
    """Investors:
    - Expect growth
    - Want cost control
    - Risk concerns""",
    
    """Suppliers:
    - Capacity constraints
    - Price pressures
    - Tech transitions"""
]

impact_results = await parallel(
    """Analyze how market changes will impact this stakeholder group.
    Provide specific impacts and recommended actions.
    Format with clear sections and priorities.""",
    stakeholders
)

for result in impact_results:
    print(result)
# Out:
# **Market Changes Impacting Customers**
#
# 1. **Inflation and Economic Turbulence:**
#    - **Impact:** Price-sensitive customers may experience additional stress as inflation continues to drive up the costs of goods, including tech products. Economic downturns could lead to reduced disposable income, causing customers to delay or reconsider purchases.
#    - **Recommended Action:** Companies should enhance their offerings by providing more value for less. This can include bundling services, offering flexible financing options, or increasing the length of warranties to reassure customers.
#
# 2. **Technological Advancements:**
#    - **Impact:** Customers with a desire for better tech will look for high-performance products at competitive prices. Rapid advancements can also result in quicker obsolescence of products, causing hesitation in purchasing decisions.
#    - **Recommended Action:** Businesses should focus on continuous innovation and frequent product updates, ensuring tech advancements are integrated into new models. Maintaining transparency about tech roadmaps can help customers feel more confident in their investments.
#
# 3. **Shift towards Sustainability:**
#    - **Impact:** With growing environmental concerns, customers are increasingly opting for eco-friendly products and brands that demonstrate sustainable practices. Preference for sustainable packaging, energy-efficient devices, and company transparency about their environmental impact may dominate purchasing decisions.
#    - **Recommended Action:** Invest in sustainability by improving product energy efficiency, using recyclable materials, minimizing waste, and obtaining relevant certifications. Marketing campaigns should prominently feature these initiatives to attract environmentally conscious customers.
#
# **Priority Action Plan**
#
# 1. **Introduce Pricing Strategies:**
#    - Initiatives such as loyalty programs, trade-in offers, or tiered pricing based on features can appeal to price-sensitive customers. Regular price reassessments in line with market conditions will also help stay competitive.
#
# 2. **Boost R&D for Tech Improvements:**
#    - Enhance R&D efforts to incorporate cutting-edge technology and improve product longevity. Collaborate with tech innovators and incorporate customer feedback into development cycles to ensure products meet current desires.
#
# 3. **Enhance Sustainability Practices and Communication:**
#    - Source sustainable materials and optimize supply chains to lower carbon footprints. Clearly communicate these efforts through marketing channels to build brand loyalty among environmentally aware customers.
#
# **Communication and Transparency:**
# Establish open channels of communication with customers to address concerns, provide updates about sustainable practices, and offer guidance on maximizing product longevity. Developing a customer-centric approach that listens and adapts to evolving needs is crucial in maintaining long-term relationships amidst market changes.
# **Employees: Market Changes Impact Analysis**
#
# **1. Job Security Concerns**
#
# *Impact:*
# Market changes, such as economic downturns, shifts towards automation, and the integration of artificial intelligence, are creating uncertainties in job security. Employees may worry about potential layoffs, restructuring, or the elimination of certain positions, particularly repetitive or low-skilled roles susceptible to automation.
#
# *Priority Actions:*
# - **Transparent Communication:** Maintain open communication regarding the state of the business, market trends, and potential impacts on employment. Regular updates can help alleviate uncertainty and build trust.
# - **Employment Stability Plans:** Develop contingency plans that might include temporary role adjustments or redeployments to other areas of the business rather than immediate lay-offs.
#
# **2. Need for New Skills**
#
# *Impact:*
# As industries evolve due to technological advancements and innovation, employees may find their current skill sets becoming obsolete. This necessitates a shift towards acquiring new skills, particularly in digital literacy, technology, and critical thinking, to stay competitive in the workforce.
#
# *Priority Actions:*
# - **Upskilling Programs:** Implement training sessions, workshops, and courses aimed at building skills needed for the future, like digital literacy, data analysis, and problem-solving.
# - **Encourage Continuous Learning:** Foster a culture of lifelong learning by providing resources such as online subscriptions, learning stipends, or access to training platforms.
# - **Career Development Plans:** Collaborate with employees to identify personal development goals aligned with future company needs and market trends.
#
# **3. Desire for Clear Direction**
#
# *Impact:*
# Employees need clarity and guidance from leadership amid market changes to understand company priorities and their roles within those goals. Uncertainty about company direction could lead to decreased morale and productivity.
#
# *Priority Actions:*
# - **Establish Clear Objectives:** Clearly outline short-term and long-term company goals and how each team contributes to these objectives.
# - **Leadership Engagement:** Encourage leaders to regularly engage with employees, offering insights into strategic decisions and how they impact day-to-day work.
# - **Vision Alignment:** Regularly revisit and reassess the company's vision in response to market changes and ensure all communication reflects this updated vision.
#
# **Conclusion:**
#
# Effectively navigating market changes requires strategic actions focused on transparency, skill development, and providing clear direction. By prioritizing these actions, companies can mitigate employees' concerns about job security, prepare them for future demands, and align them with the company's evolving goals. This approach will contribute to sustaining employee engagement and productivity despite external uncertainties.
# **Market Changes Impact on Investors**
#
# 1. **Economic Growth Slowdown**
#    - **Impact**: Slower-than-expected economic growth may lead to reduced revenue forecasts for companies, impacting stock prices negatively. Investors expecting high growth may face disappointment, leading to potential sell-offs.
#    - **Recommended Action**: Diversify the portfolio to include sectors that perform well in slower growth environments, such as consumer staples or utilities. Consider investing in companies with strong international growth prospects to offset domestic stagnation.
#
# 2. **Rising Interest Rates**
#    - **Impact**: Higher interest rates can depress equity valuations, increase borrowing costs, and reduce corporate profitability, adversely affecting investors’ returns.
#    - **Recommended Action**: Focus on companies with low debt levels and strong cash flows. Look for opportunities in financial sectors, such as banks, which can benefit from rising interest rates. Fixed-income securities might also become attractive as bond yields increase, demanding a re-evaluation of risk-return profiles in equities versus bonds.
#
# 3. **Inflationary Pressures**
#    - **Impact**: Inflation can erode real returns on investments and impact margins through increased operational costs. Companies unable to pass on these costs to consumers may see reduced profitability.
#    - **Recommended Action**: Invest in companies with strong pricing power or those in sectors less sensitive to inflationary pressures. Consider inflation-protected securities (e.g., TIPS) to safeguard fixed-income investments from inflation’s effects.
#
# 4. **Regulatory Changes**
#    - **Impact**: New regulations, especially in tech, healthcare, and energy sectors, can increase compliance costs and impact profitability. Investors may need to reassess risk exposure based on regulatory compliance risks.
#    - **Recommended Action**: Stay informed about upcoming regulatory changes and their potential impacts. Consider engaging with portfolio managers to reassess sector allocations strategically. Companies with savvy compliance strategies may become safer bets.
#
# 5. **Geopolitical Tensions**
#    - **Impact**: Heightened geopolitical tensions can introduce volatility and risk in markets, potentially shaking investor confidence and impacting certain sectors negatively (e.g., energy, defense).
#    - **Recommended Action**: Monitor global developments closely and consider geopolitical risk analysis as part of investment decision-making. Employ hedging strategies to mitigate potential impacts on affected investments.
#
# 6. **Technological Advances**
#    - **Impact**: Rapid technological shifts can create winners and losers in the market. Investors may see heightened volatility as tech disruptors challenge traditional business models.
#    - **Recommended Action**: Increase exposure to innovation-driven sectors and companies with a strong R&D focus. Engage in active management strategies to quickly adapt to tech-driven market changes.
#
# **Conclusion and Priority Actions for Investors**
#
# - **Diversification and Risk Management**: Given the current market volatility, focus on diversification across asset classes and geographies to manage risk effectively. Prioritize investments in stable, dividend-paying stocks to balance growth and income.
#
# - **Active Monitoring and Adaptation**: Stay proactive in monitoring market changes, economic indicators, and regulatory developments. Be prepared to adapt strategies promptly to safeguard investments.
#
# - **Strategic Engagement and Education**: Engage with financial advisors for tailored investment advice and participate in investor education initiatives to enhance understanding of market dynamics. This approach will help mitigate risk concerns and ensure alignment with financial goals.
# **Analysis of Market Changes Impacting Suppliers**
#
# Market changes are expected to have significant impacts on suppliers, specifically concerning capacity constraints, price pressures, and tech transitions. Below is an analysis of each factor along with recommended actions to mitigate negative impacts and take advantage of opportunities.
#
# ### 1. Capacity Constraints
#
# **Impact:**
# - Suppliers may struggle to meet burgeoning demand due to limited production capacities, which can lead to bottlenecks, delays in delivery schedules, and potential loss of business.
# - Capacity constraints could increase operational costs as suppliers might need to expedite shipments or pay overtime wages to meet deadlines.
#
# **Recommended Actions:**
# - **Invest in Expanding Capacity:** Suppliers should consider investing in new production facilities or upgrading existing ones to increase output efficiency and capacity.
# - **Improve Supply Chain Efficiency:** Optimize logistics and supply chain processes to reduce turnaround times and improve resource allocation.
# - **Collaborate with Other Suppliers:** Form strategic alliances to share resources and capacities to meet greater demand collaboratively.
#
# ### 2. Price Pressures
#
# **Impact:**
# - Rising raw material costs and intensified competition may squeeze margins, making it difficult for suppliers to maintain profitability.
# - Price pressure could lead to reduced bargaining power with buyers, forcing suppliers to accept lower prices.
#
# **Recommended Actions:**
# - **Diversify Supply Sources:** Identify alternative sources for raw materials that offer competitive pricing to reduce dependence on current suppliers.
# - **Implement Cost-Reduction Measures:** Streamline operations and adopt lean manufacturing techniques to reduce waste and improve cost efficiency.
# - **Value-Added Services:** Offer additional services (such as customization, faster delivery) to differentiate from competitors and justify premium pricing.
#
# ### 3. Tech Transitions
#
# **Impact:**
# - Suppliers who fail to adapt to new technologies may find themselves obsolete or unable to compete with more technologically advanced competitors.
# - Investment in new technologies can be capital-intensive and may strain financial resources, especially for smaller suppliers.
#
# **Recommended Actions:**
# - **Embrace Technological Advancements:** Invest in modern production technologies such as IoT and AI to improve operational efficiency and product quality.
# - **Retrain Workforce:** Implement training programs to enhance employees’ technological skills, ensuring they are equipped to handle new systems and processes.
# - **Explore Technological Partnerships:** Partner with tech firms to share the burden of R&D costs and leverage ongoing technological improvements.
#
# ### Prioritization of Actions
#
# 1. **Immediate Expansion of Capacity and Efficiency Measures:**
#    - Prioritize actions that directly address capacity issues and facilitate immediate improvements in production capabilities.
#
# 2. **Cost Management and Price Negotiation Strategies:**
#    - Focus on financial stability by managing costs effectively and leveraging negotiation skills to better cope with price pressures.
#
# 3. **Long-Term Technological Investments:**
#    - Develop a strategic roadmap for technological adoption, ensuring gradual investment and integration into existing operations without disrupting current capabilities.
#
# By addressing these prioritized actions, suppliers can better navigate the challenges posed by market changes, thus securing their competitive position and facilitating sustainable growth.

# %%
async def route(input: str, routes: Dict[str, str]) -> str:
    """Route input to specialized prompt using content classification."""
    # First determine appropriate route using LLM with chain-of-thought
    print(f"\nAvailable routes: {list(routes.keys())}")

    class RouteSelection(BaseModel):
        reasoning: str = Field(..., description=(
            'Brief explanation of why this ticket should be routed to a specific team. '
            'Consider key terms, user intent, and urgency level.'
        ))
        selection: str = Field(..., description='The chosen team name')
    
    route_response = await Agent(
        AI_MODEL,
        system_prompt=(
            'Analyze the input and select the most appropriate support team from these options: '
            f'{list(routes.keys())}'
        ),
        result_type=RouteSelection,
    ).run(input)
    reasoning = route_response.data.reasoning
    route_key = route_response.data.selection.strip().lower()
    
    print("Routing Analysis:")
    print(reasoning)
    print(f"\nSelected route: {route_key}")
    
    # Process input with selected specialized prompt
    return (await Agent(
        AI_MODEL,
        system_prompt=routes[route_key],
    ).run(input)).data

# %%
support_routes = {
    "billing": """You are a billing support specialist. Follow these guidelines:
    1. Always start with "Billing Support Response:"
    2. First acknowledge the specific billing issue
    3. Explain any charges or discrepancies clearly
    4. List concrete next steps with timeline
    5. End with payment options if relevant
    
    Keep responses professional but friendly.
    
    Input: """,
    
    "technical": """You are a technical support engineer. Follow these guidelines:
    1. Always start with "Technical Support Response:"
    2. List exact steps to resolve the issue
    3. Include system requirements if relevant
    4. Provide workarounds for common problems
    5. End with escalation path if needed
    
    Use clear, numbered steps and technical details.
    
    Input: """,
    
    "account": """You are an account security specialist. Follow these guidelines:
    1. Always start with "Account Support Response:"
    2. Prioritize account security and verification
    3. Provide clear steps for account recovery/changes
    4. Include security tips and warnings
    5. Set clear expectations for resolution time
    
    Maintain a serious, security-focused tone.
    
    Input: """,
    
    "product": """You are a product specialist. Follow these guidelines:
    1. Always start with "Product Support Response:"
    2. Focus on feature education and best practices
    3. Include specific examples of usage
    4. Link to relevant documentation sections
    5. Suggest related features that might help
    
    Be educational and encouraging in tone.
    
    Input: """
}

# Test with different support tickets
tickets = [
    """Subject: Can't access my account
    Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error. 
    I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to 
    submit a report by end of day.
    - John""",
    
    """Subject: Unexpected charge on my card
    Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
    I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
    Thanks,
    Sarah""",
    
    """Subject: How to export data?
    Message: I need to export all my project data to Excel. I've looked through the docs but can't
    figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
    Best regards,
    Mike"""
]

print("Processing support tickets...\n")
for i, ticket in enumerate(tickets, 1):
    print(f"\nTicket {i}:")
    print("-" * 40)
    print(ticket)
    print("\nResponse:")
    print("-" * 40)
    response = await route(ticket, support_routes)
    print(response)
# Out:
# Processing support tickets...
#
#
# Ticket 1:
# ----------------------------------------
# Subject: Can't access my account
#     Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error.
#     I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to
#     submit a report by end of day.
#     - John
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
# The user is experiencing login issues and believes they are using the correct password but cannot access their account. This suggests the problem is related to account access and authentication, rather than a technical problem with the website or billing. Since the user is specifically asking for help with account access and mentions an urgent deadline, the issue should be routed to the 'account' team who can provide support in resetting the password or troubleshooting the login issue.
#
# Selected route: account
# Account Support Response:
#
# Dear John,
#
# Thank you for reaching out to us regarding the difficulty you're experiencing accessing your account. Our primary concern is securing your account while facilitating a seamless recovery process.
#
# 1. **Account Verification**: Before we proceed, please verify your identity by confirming the email address or phone number associated with your account.
#
# 2. **Password Reset**:
#    - Navigate to the "Forgot Password" link on the login page.
#    - Follow the instructions to reset your password using the email or SMS we will send for verification.
#    - Choose a new, strong password that you have not used before. A strong password typically combines uppercase, lowercase letters, numbers, and special characters.
#
# 3. **Two-Factor Authentication**: If you haven't already, we highly recommend enabling two-factor authentication (2FA) for an additional layer of security.
#
# 4. **Security Tips & Warnings**:
#    - Ensure your device is free from malware by running a full security scan.
#    - Avoid entering your details on suspicious emails or websites to protect against phishing attacks.
#
# 5. **Resolution Time**: Following the above steps should resolve your issue promptly. If you continue to have access problems, please contact our support team with the verified information, and we will escalate the issue. Resolution typically takes up to 24 hours once escalated.
#
# Please get back to us if you have any further questions or need more assistance after following these steps.
#
# Sincerely,
# Account Support Team
#
# Ticket 2:
# ----------------------------------------
# Subject: Unexpected charge on my card
#     Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
#     I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
#     Thanks,
#     Sarah
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
# The user is inquiring about a charge on their credit card that they did not expect and is related to their plan. This falls under billing issues, as the user is questioning a financial transaction and the billing plan associated with the charge. The billing team is most equipped to handle matters related to charges and payment discrepancies.
#
# Selected route: billing
# Billing Support Response:
#
# Hello Sarah,
#
# Thank you for reaching out to us about this issue.
#
# I understand your concern regarding the unexpected charge of $49.99 on your credit card. After reviewing your account, it appears that the $49.99 charge is for an upgrade you made last month to a higher-tier plan, which includes additional features over the $29.99 plan.
#
# If you believe this upgrade was made in error, we can certainly review this further and either downgrade your plan or explore other options that might suit your needs better.
#
# Here are the next steps we can take:
# 1. Please reply with confirmation if you would like us to downgrade your plan back to the $29.99 option. We can process the downgrade and adjust next month’s billing to reflect this change.
# 2. If you did not intend to change plans, please let us know within the next 5 business days, and we will investigate further and potentially process a refund for the difference.
#
# For your convenience, here are the payment options available:
# - Credit card
# - Direct bank transfer
# - PayPal
#
# Please feel free to reach out with any further questions or clarifications needed.
#
# Best regards,
# [Your Name]
# Billing Support Team
#
# Ticket 3:
# ----------------------------------------
# Subject: How to export data?
#     Message: I need to export all my project data to Excel. I've looked through the docs but can't
#     figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
#     Best regards,
#     Mike
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
# Mike is asking for help on how to export his project data to Excel, which is a functionality-related query. This falls under technical support, as he is asking for a step-by-step process to perform a task using the product that requires technical assistance.
#
# Selected route: technical
# Technical Support Response:
#
# To export your project data to Excel, please follow these steps:
#
# 1. **Log in to the Platform**: Access the project management platform where your data is stored by opening your web browser and navigating to the login page. Enter your credentials.
#
# 2. **Navigate to the Project Section**: Once logged in, locate and click on the 'Projects' or equivalent section in your dashboard where all your projects are listed.
#
# 3. **Select the Project**: Click on the specific project you wish to export data from. If you want to export data from multiple projects, you may need to repeat this process for each one.
#
# 4. **Access Export Options**: Within the project view, look for an 'Export' button or menu option. This is typically found near the project data list or under a 'More Options' dropdown menu.
#
# 5. **Choose Export Format**: Select 'Excel' or '.xlsx' as the export format from the options provided.
#
# 6. **Select Data Fields** (if applicable): Some platforms allow selecting specific data fields or dates if you prefer not to export all information. Adjust these settings according to your needs.
#
# 7. **Initiate Export**: Click on the 'Export' button to initiate the data export process. Wait for the process to complete. This may take a few moments depending on the volume of data.
#
# 8. **Download the File**: Once the export is complete, the system will typically provide a download link for the Excel file. Click on the link to download the file to your local machine.
#
# **System Requirements**: Ensure that you have Microsoft Excel or compatible spreadsheet software capable of opening .xlsx files installed on your computer.
#
# **Workarounds for Common Issues**:
# - If the export button is not visible, clear your browser cache and cookies and refresh the page.
# - Try using a different web browser if you encounter compatibility issues.
# - Ensure that pop-ups are enabled for the platform's website, as the export file may be blocked as a pop-up.
#
# **Escalation Path**: If you encounter technical difficulties or the export feature is not functioning as described, please contact our support team via email at support@example.com, or call 1-800-SUPPORT for further assistance. Be sure to include any error messages and details about what you've already tried.
#
# Feel free to reach out if you have any more questions or need additional support.
