# %%
# %pip install -r requirements.txt
from IPython.display import clear_output ; clear_output()
# Out:
# Available AI models:
# ['openai:gpt-4o',
#  'openai:gpt-4o-mini',
#  'gemini-1.5-pro',
#  'gemini-2.0-flash-exp',
#  'claude-3-5-haiku-latest',
#  'claude-3-5-sonnet-latest']
# Using AI model: gemini-1.5-pro

# %%
from util import initialize
AI_MODEL = initialize()

import asyncio
from typing import List, Dict
from pprint import pprint, pformat

from pydantic import BaseModel, Field
from pydantic_ai import Agent

# %%
async def chain(input: str, prompts: List[str]) -> str:
    """Chain multiple LLM calls sequentially, passing results between steps."""
    agent = Agent(AI_MODEL)
    result = input
    for i, prompt in enumerate(prompts, 1):
        print(f"\nStep {i}:")
        result = (await agent.run(f"{prompt}\nInput: {result}")).data
        print(result)
    return result

# %%
data_processing_steps = [
    """Extract only the numerical values and their associated metrics from the text.
    Format each as 'value: metric' on a new line.
    Example format:
    92: customer satisfaction
    45%: revenue growth""",
    
    """Convert all numerical values to percentages where possible.
    If not a percentage or points, convert to decimal (e.g., 92 points -> 92%).
    Keep one number per line.
    Example format:
    92%: customer satisfaction
    45%: revenue growth""",
    
    """Sort all lines in descending order by numerical value.
    Keep the format 'value: metric' on each line.
    Example:
    92%: customer satisfaction
    87%: employee satisfaction""",
    
    """Format the sorted data as a markdown table with columns:
    | Metric | Value |
    |:--|--:|
    | Customer Satisfaction | 92% |"""
]

report = """
Q3 Performance Summary:
Our customer satisfaction score rose to 92 points this quarter.
Revenue grew by 45% compared to last year.
Market share is now at 23% in our primary market.
Customer churn decreased to 5% from 8%.
New user acquisition cost is $43 per user.
Product adoption rate increased to 78%.
Employee satisfaction is at 87 points.
Operating margin improved to 34%.
"""

print("\nInput text:")
print(report)
formatted_result = await chain(report, data_processing_steps)
print(formatted_result)
# Out:
# Input text:
#
# Q3 Performance Summary:
# Our customer satisfaction score rose to 92 points this quarter.
# Revenue grew by 45% compared to last year.
# Market share is now at 23% in our primary market.
# Customer churn decreased to 5% from 8%.
# New user acquisition cost is $43 per user.
# Product adoption rate increased to 78%.
# Employee satisfaction is at 87 points.
# Operating margin improved to 34%.
#
#
# Step 1:
# 92: points
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# $43: new user acquisition cost
# 78%: product adoption rate
# 87: points
# 34%: operating margin
#
#
# Step 2:
# 92%
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# $43: new user acquisition cost
# 78%: product adoption rate
# 87%
# 34%: operating margin
#
#
# Step 3:
# 92%:
# 87%:
# 78%: product adoption rate
# 45%: revenue growth
# 34%: operating margin
# 23%: market share
# 5%: customer churn
#
#
# Step 4:
# | Metric | Value |
# |:--|--:|
# | Customer Satisfaction | 92% |
# | Product Adoption Rate | 78% |
# | Revenue Growth | 45% |
# | Operating Margin | 34% |
# | Market Share | 23% |
# | Customer Churn | 5% |
#
# | Metric | Value |
# |:--|--:|
# | Customer Satisfaction | 92% |
# | Product Adoption Rate | 78% |
# | Revenue Growth | 45% |
# | Operating Margin | 34% |
# | Market Share | 23% |
# | Customer Churn | 5% |

# %%
async def parallel(prompt: str, inputs: List[str]) -> List[str]:
    """Process multiple inputs concurrently with the same prompt."""
    agent = Agent(
        AI_MODEL,
        system_prompt=prompt,
    )
    results = await asyncio.gather(*[
        agent.run(input)
        for input in inputs
    ])
    return [result.data for result in results]

# %%
stakeholders = [
    """Customers:
    - Price sensitive
    - Want better tech
    - Environmental concerns""",
    
    """Employees:
    - Job security worries
    - Need new skills
    - Want clear direction""",
    
    """Investors:
    - Expect growth
    - Want cost control
    - Risk concerns""",
    
    """Suppliers:
    - Capacity constraints
    - Price pressures
    - Tech transitions"""
]

impact_results = await parallel(
    """Analyze how market changes will impact this stakeholder group.
    Provide specific impacts and recommended actions.
    Format with clear sections and priorities.""",
    stakeholders
)

for result in impact_results:
    print(result)
# Out:
# ## Impact of Market Changes on Price-Sensitive, Tech-Savvy, Environmentally Conscious Customers
#
# **Market Changes Considered:**  General increases in prices (inflation), rapid technological advancements, growing awareness and concern for environmental sustainability.
#
# **I. Primary Impact:  Value Perception Shift**
#
# * **Increased Prices & Price Sensitivity:** Rising prices across the board will significantly impact this customer group's purchasing decisions.  They will be more discerning about where they spend their money, prioritizing value for their dollar.  Simply increasing prices without a corresponding increase in perceived value (through better technology or demonstrable sustainability) will lead to customer churn.
# * **Rapid Technological Advancements:** This group is interested in the latest technology.  Competitors offering superior tech features will quickly attract these customers.  Falling behind the technology curve will make products less appealing, even if they are priced competitively.
# * **Growing Environmental Concerns:**  This group is increasingly aware of the environmental impact of their purchases. They are more likely to choose products and services from companies with demonstrable commitments to sustainability, even if it means paying a slight premium. Ignoring environmental concerns will negatively impact brand perception and loyalty.
#
# **II. Recommended Actions (Prioritized)**
#
# **High Priority:**
#
# 1. **Demonstrate Value Enhancement:**  Focus on communicating how product improvements justify any price increases. Highlight advancements in technology, improved features, or added services that directly benefit the customer.  Quantify these benefits whenever possible (e.g., "20% faster processing speed," "30% more energy efficient").
# 2. **Embrace Sustainable Practices:** Implement and clearly communicate environmentally friendly practices throughout the product lifecycle (from sourcing to packaging and disposal).  Consider certifications (e.g., B Corp, Fair Trade) to build credibility and trust.  Offer transparency in your supply chain and environmental impact.
#
# **Medium Priority:**
#
# 3. **Invest in Technology & Innovation:**  Continuously improve product technology to stay ahead of the competition.  Explore features that align with both customer needs and environmental concerns (e.g., energy-efficient designs, recycled materials).  Communicate these advancements clearly to highlight the value proposition.
# 4. **Targeted Value-Based Pricing Strategies:** Offer tiered pricing options to cater to different budget levels while still providing access to core features.  Consider bundling products or services to provide greater value at a perceived lower cost.  Explore subscription models or loyalty programs to incentivize repeat purchases.
#
# **Low Priority (but still important):**
#
# 5. **Monitor Competitor Activities:** Keep a close eye on competitor offerings, pricing strategies, and sustainability initiatives.  Identify areas where you can differentiate and offer a superior value proposition.
# 6. **Gather Customer Feedback:**  Actively solicit and analyze customer feedback to understand their evolving needs and concerns related to price, technology, and sustainability. Use this information to inform product development and marketing strategies.
#
#
# **III. Potential Negative Impacts if No Action is Taken:**
#
# * **Customer Churn:**  Loss of customers to competitors offering better value, newer technology, or stronger sustainability credentials.
# * **Decreased Market Share:**  Inability to attract new customers due to outdated technology and lack of focus on environmental responsibility.
# * **Negative Brand Perception:**  Erosion of brand image and reputation due to perceived price gouging and disregard for environmental concerns.
# * **Reduced Profitability:**  Lower sales volume and increased customer acquisition costs due to a shrinking customer base.
#
# ## Impact of Market Changes on Employees
#
# **Stakeholder Group:** Employees
#
# **Primary Concerns:** Job security, skill gaps, and lack of clear direction.
#
# **Market Changes (Assumed, Please Specify if Different):**  This analysis assumes a rapidly evolving market influenced by technological advancements, increased competition, and shifting consumer demands.  It's crucial to define the *specific* market changes impacting your organization for a more accurate analysis.
#
#
# **I. High Priority Impacts & Actions:**
#
# * **Impact 1: Increased Risk of Redundancy:** Automation, outsourcing, or restructuring due to market shifts may lead to job losses or role changes.  This fuels job security worries and decreases morale.
#     * **Action 1: Transparency and Communication:**  Openly communicate about the company's strategy for navigating market changes.  Be upfront about potential impacts on roles and provide clear timelines wherever possible.
#     * **Action 2: Reskilling and Upskilling Programs:** Invest in training programs to equip employees with the skills needed for emerging roles within the company. This demonstrates commitment to their future and enhances their employability.
#     * **Action 3:  Outplacement Services:** If layoffs are unavoidable, provide support like resume writing assistance, career counseling, and networking opportunities to help affected employees transition to new jobs.
#
# * **Impact 2: Skill Gaps Widen:**  Existing employee skills may become obsolete as new technologies and processes emerge. This impacts productivity and limits career progression.
#     * **Action 1: Skills Gap Analysis:** Conduct a thorough assessment to identify current and future skill requirements. This will inform targeted training and development initiatives.
#     * **Action 2:  Mentorship and Coaching Programs:** Pair experienced employees with those needing to develop specific skills.  This fosters knowledge transfer and supports individual growth.
#     * **Action 3:  External Training Opportunities:**  Provide access to online courses, certifications, and industry conferences to help employees acquire in-demand skills.
#
#
# **II. Medium Priority Impacts & Actions:**
#
# * **Impact 3:  Uncertainty and Decreased Morale:**  Rapid market changes create uncertainty about the future, leading to anxiety, decreased motivation, and reduced productivity.
#     * **Action 1:  Regular Town Hall Meetings:**  Hold regular forums for open Q&A with leadership to address employee concerns and provide updates on the company's response to market changes.
#     * **Action 2:  Reinforce Company Values and Vision:**  Remind employees of the company's mission and long-term goals to provide a sense of stability and purpose amidst change.
#     * **Action 3:  Employee Recognition Programs:**  Acknowledge and reward employees who adapt to change, demonstrate new skills, and contribute to the company's success.
#
#
# **III. Low Priority Impacts & Actions (Still Important, Address After High & Medium):**
#
# * **Impact 4: Difficulty Attracting and Retaining Talent:**  A company perceived as unstable or lacking opportunities for growth may struggle to attract and retain skilled employees.
#     * **Action 1:  Employer Branding:**  Highlight the company's commitment to employee development and its efforts to navigate market changes effectively.
#     * **Action 2: Competitive Compensation and Benefits:** Review and adjust compensation and benefits packages to remain competitive and attract top talent.
#     * **Action 3:  Flexible Work Arrangements:** Offer flexible work options to improve work-life balance and appeal to a wider range of candidates.
#
#
#
# **Key Considerations:**
#
# * **Customization:** These actions are general recommendations.  Tailor them to your specific organization, industry, and the nature of the market changes you face.
# * **Employee Involvement:**  Engage employees in the change process by seeking their input and feedback.  This fosters buy-in and increases the likelihood of successful adaptation.
# * **Continuous Monitoring and Evaluation:** Regularly assess the effectiveness of implemented actions and make adjustments as needed based on employee feedback and market dynamics.
#
# ## Impact of Market Changes on Investors
#
# **Stakeholder Group:** Investors
#
# **Core Needs:** Return on investment, growth, stability, risk mitigation.
#
# **Potential Market Changes & Impacts:**
#
# **1. Increased Competition:**
#
# * **Impact:**  Reduced market share, pricing pressure, slower growth than anticipated, potentially impacting dividends and share value. Increased risk of business failure.
# * **Recommended Actions (High Priority):**
#     * **Diversify investments:** Don't rely solely on one company or sector.
#     * **Scrutinize company competitive strategy:**  Ensure the company has a robust plan to address competitive pressures, including innovation, differentiation, and cost optimization.
#     * **Demand transparency:** Request clear communication from company leadership about competitive challenges and strategic responses.
#
#
# **2. Economic Downturn:**
#
# * **Impact:** Decreased consumer spending, reduced company revenues and profits, lower stock valuations, potential dividend cuts. Increased risk of loan defaults if the company carries significant debt.
# * **Recommended Actions (High Priority):**
#     * **Rebalance portfolio:** Shift towards more defensive investments (e.g., utilities, consumer staples) and potentially increase cash reserves.
#     * **Assess company financial health:**  Review balance sheets and cash flow statements to evaluate the company's ability to weather an economic downturn.
#     * **Consider hedging strategies:** Explore options like put options to protect against significant downside risk.
#
#
# **3. Technological Disruption:**
#
# * **Impact:**  Existing products or services becoming obsolete, requiring significant investment to adapt. This can lead to decreased profitability or even business failure if not addressed effectively. Early adoption can lead to substantial growth opportunities.
# * **Recommended Actions (Medium Priority):**
#     * **Analyze company's technological adaptability:**  Assess their ability to innovate, adapt to new technologies, and invest in research and development.
#     * **Invest in disruptive technologies:**  Consider investing in companies at the forefront of technological change.
#     * **Monitor industry trends:** Stay informed about technological advancements and their potential impact on existing investments.
#
#
# **4. Regulatory Changes:**
#
# * **Impact:** Increased compliance costs, restrictions on operations, or changes to market dynamics. This can affect profitability and growth prospects.
# * **Recommended Actions (Medium Priority):**
#     * **Assess regulatory risk:**  Understand the potential impact of new or changing regulations on the companies in your portfolio.
#     * **Engage with companies on regulatory matters:** Encourage transparency and proactive engagement with regulators.
#     * **Support industry associations:** Participate in shaping regulatory frameworks that promote innovation and sustainable growth.
#
#
# **5. Inflationary Pressures:**
#
# * **Impact:** Increased input costs for businesses, potentially squeezing profit margins. May lead to price increases, impacting consumer demand and potentially slowing economic growth. This can lead to lower returns on investments.
# * **Recommended Actions (Low Priority):**
#     * **Invest in inflation-hedged assets:** Consider investments in commodities, real estate, or inflation-linked bonds.
#     * **Evaluate company pricing power:**  Assess the ability of companies to pass on increased costs to consumers without significantly impacting demand.
#     * **Monitor central bank policies:**  Stay informed about monetary policy decisions and their potential impact on inflation and interest rates.
#
#
# **General Recommendations for all market changes:**
#
# * **Maintain open communication with company management.**
# * **Diversify investments across sectors and asset classes.**
# * **Continuously monitor market conditions and adjust investment strategies accordingly.**
# * **Seek professional financial advice.**
#
# ## Impact of Market Changes on Suppliers
#
# **Stakeholder Group:** Suppliers
#
# **Market Changes:** Capacity Constraints, Price Pressures, Tech Transitions
#
# **Overall Impact:**  Suppliers face a complex and challenging environment.  While some may benefit from increased demand due to capacity constraints, they also face squeezed margins from price pressures and the need to invest in potentially costly technological transitions.  Those who can adapt quickly and strategically will be best positioned for success.
#
# **Specific Impacts:**
#
# * **Capacity Constraints:**
#     * **Positive Impact:** Increased demand for existing products/services can lead to higher sales volumes for suppliers able to meet the demand.
#     * **Negative Impact:** Difficulty meeting increased demand can damage supplier reputation and lead to lost contracts. Existing capacity may become a bottleneck, limiting growth potential.
#
# * **Price Pressures:**
#     * **Negative Impact:**  Rising input costs (raw materials, labor, energy) coupled with customer pressure to maintain or lower prices will squeeze profit margins. This can impact suppliers' ability to invest in innovation or expansion.
#     * **Mixed Impact:** Suppliers with strong negotiating power or differentiated offerings may be able to resist price pressures more effectively.
#
# * **Tech Transitions:**
#     * **Positive Impact:**  Suppliers who adopt new technologies can improve efficiency, develop new products/services, and gain a competitive advantage.
#     * **Negative Impact:**  Significant investment in new technologies is often required, creating financial strain.  Suppliers who fail to adapt risk becoming obsolete.
#
#
# **Recommended Actions (Prioritized):**
#
# **High Priority:**
#
# 1. **Optimize Existing Capacity:** Implement lean manufacturing principles, improve supply chain efficiency, and explore short-term capacity expansion options to maximize output from existing resources.
#
# 2. **Strategically Manage Pricing:** Analyze cost structures, identify opportunities for cost reduction, and explore value-based pricing strategies to mitigate margin compression.  Develop strong negotiation strategies with customers.
#
# 3. **Assess Technological Landscape:** Conduct a thorough analysis of emerging technologies relevant to the industry and evaluate their potential impact on the business.  Identify key technologies for investment.
#
#
# **Medium Priority:**
#
# 4. **Develop Strategic Partnerships:** Collaborate with other suppliers, customers, or research institutions to share resources, gain access to new technologies, and mitigate risks associated with technological transitions.
#
# 5. **Invest in Innovation:** Allocate resources to research and development to create new products/services that differentiate the supplier's offerings and create value for customers.
#
# 6. **Enhance Supply Chain Resilience:** Diversify sourcing, develop alternative supply routes, and build stronger relationships with key suppliers to mitigate risks associated with supply chain disruptions.
#
#
#
# **Low Priority (but Important for Long-Term Success):**
#
# 7. **Develop Workforce Skills:** Invest in training and development programs to ensure employees have the skills needed to operate new technologies and adapt to changing market conditions.
#
# 8. **Monitor Market Trends:** Continuously monitor market dynamics, competitor activities, and technological advancements to anticipate future changes and proactively adapt the business strategy.
#
#
# By implementing these recommendations, suppliers can navigate the challenges and capitalize on the opportunities presented by these market changes.

# %%
async def route(input: str, routes: Dict[str, str]) -> str:
    """Route input to specialized prompt using content classification."""
    # First determine appropriate route using LLM with chain-of-thought
    print(f"\nAvailable routes: {list(routes.keys())}")

    class RouteSelection(BaseModel):
        reasoning: str = Field(..., description=(
            'Brief explanation of why this ticket should be routed to a specific team. '
            'Consider key terms, user intent, and urgency level.'
        ))
        selection: str = Field(..., description='The chosen team name')
    
    route_response = await Agent(
        AI_MODEL,
        system_prompt=(
            'Analyze the input and select the most appropriate support team from these options: '
            f'{list(routes.keys())}'
        ),
        result_type=RouteSelection,
    ).run(input)
    reasoning = route_response.data.reasoning
    route_key = route_response.data.selection.strip().lower()
    
    print("Routing Analysis:")
    print(reasoning)
    print(f"\nSelected route: {route_key}")
    
    # Process input with selected specialized prompt
    return (await Agent(
        AI_MODEL,
        system_prompt=routes[route_key],
    ).run(input)).data

# %%
support_routes = {
    "billing": """You are a billing support specialist. Follow these guidelines:
    1. Always start with "Billing Support Response:"
    2. First acknowledge the specific billing issue
    3. Explain any charges or discrepancies clearly
    4. List concrete next steps with timeline
    5. End with payment options if relevant
    
    Keep responses professional but friendly.
    
    Input: """,
    
    "technical": """You are a technical support engineer. Follow these guidelines:
    1. Always start with "Technical Support Response:"
    2. List exact steps to resolve the issue
    3. Include system requirements if relevant
    4. Provide workarounds for common problems
    5. End with escalation path if needed
    
    Use clear, numbered steps and technical details.
    
    Input: """,
    
    "account": """You are an account security specialist. Follow these guidelines:
    1. Always start with "Account Support Response:"
    2. Prioritize account security and verification
    3. Provide clear steps for account recovery/changes
    4. Include security tips and warnings
    5. Set clear expectations for resolution time
    
    Maintain a serious, security-focused tone.
    
    Input: """,
    
    "product": """You are a product specialist. Follow these guidelines:
    1. Always start with "Product Support Response:"
    2. Focus on feature education and best practices
    3. Include specific examples of usage
    4. Link to relevant documentation sections
    5. Suggest related features that might help
    
    Be educational and encouraging in tone.
    
    Input: """
}

# Test with different support tickets
tickets = [
    """Subject: Can't access my account
    Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error. 
    I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to 
    submit a report by end of day.
    - John""",
    
    """Subject: Unexpected charge on my card
    Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
    I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
    Thanks,
    Sarah""",
    
    """Subject: How to export data?
    Message: I need to export all my project data to Excel. I've looked through the docs but can't
    figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
    Best regards,
    Mike"""
]

print("Processing support tickets...\n")
for i, ticket in enumerate(tickets, 1):
    print(f"\nTicket {i}:")
    print("-" * 40)
    print(ticket)
    print("\nResponse:")
    print("-" * 40)
    response = await route(ticket, support_routes)
    print(response)
# Out:
# Processing support tickets...
#
#
# Ticket 1:
# ----------------------------------------
# Subject: Can't access my account
#     Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error.
#     I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to
#     submit a report by end of day.
#     - John
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
# The user is experiencing a login issue, which is technical in nature.  The urgency is high due to a deadline.
#
# Selected route: technical
# Technical Support Response:
#
# We understand you are experiencing difficulty accessing your account due to an "invalid password" error. Please follow these steps to resolve the issue:
#
# 1. **Password Recovery:**
#     a. Navigate to the login page.
#     b. Click on the "Forgot Password" or "Reset Password" link.
#     c. Enter your registered email address or username.
#     d. Follow the instructions in the password reset email sent to your registered email address. This email usually contains a link that will allow you to reset your password.  Make sure you check your spam or junk folder if you do not see the email.
#
# 2. **Check Caps Lock and Num Lock:**
#     a. Ensure that the Caps Lock key on your keyboard is off. Passwords are case-sensitive.
#     b. If your password contains numbers, verify that the Num Lock key is on if you are using the numeric keypad.
#
# 3. **Browser Cache and Cookies:**
#     a. Sometimes, old cached data can interfere with login. Clear your browser's cache and cookies.  You can usually find these options in your browser's Settings or History.
#     b. Try logging in again after clearing cache and cookies.
#     c. Alternatively try incognito/private browsing mode or a different web browser.
#
# 4. **Verify Account Status (If applicable):**
#     a.  If you are logging in to a corporate or organization account, your account might be temporarily locked or disabled. Contact your system administrator or IT department to verify the status of your account and unlock it if necessary.
#
# 5. **Check for Service Outages/Maintenance (If applicable):**
#     a. Check the service provider’s status page or official social media channels for announcements regarding any ongoing outages or scheduled maintenance activities that may be affecting login access.
#
# System Requirements:
# Ensure that your web browser is up-to-date for optimal performance and security.
#
# Workarounds:
# If you are unable to reset your password via email,  and account status and service availability have been confirmed, please proceed to the escalation path below.
#
# Escalation Path:
# If the above steps do not resolve the login issue, please contact our support team directly via phone at [Phone Number] or create a support ticket at [Support Ticket URL] providing the following information:
#
# * Your username or registered email address.
# * The time and date of your last successful login (if applicable).
# * Any error messages received in addition to the "invalid password" error.
# * The operating system and web browser you are using.
#
# We will be happy to further assist you in regaining access to your account.
#
#
# Ticket 2:
# ----------------------------------------
# Subject: Unexpected charge on my card
#     Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
#     I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
#     Thanks,
#     Sarah
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
# The user is questioning an unexpected charge on their credit card, which is a billing concern.
#
# Selected route: billing
# Billing Support Response:
#
# Hello Sarah,
#
# Thank you for reaching out to us regarding the unexpected $49.99 charge on your credit card. We understand your concern about the discrepancy between this charge and your expected $29.99 plan cost.
#
# Let's clarify this for you.  It's possible that the $49.99 charge reflects an upgrade to our premium plan, which offers additional features like [mention specific premium features]. Alternatively, it could be a one-time charge for a service add-on or a prorated charge due to a recent change in your subscription.
#
# Here are the next steps we'll take:
#
# 1. **Within 24 hours:** We will review your account history to determine the exact nature of the $49.99 charge and identify whether it was applied correctly.
# 2. **Within 48 hours:**  We'll send you a detailed explanation of the charge, specifying the service it covers and the date it was applied. If the charge is incorrect, we will immediately issue a refund to your credit card. If the charge is for a premium plan you didn't intentionally subscribe to, we'll gladly adjust your plan back to the $29.99 level and process a refund for the price difference.
#
# We appreciate your patience while we investigate this matter. We want to ensure you're only charged for the services you've authorized.  Once we have completed our review, we will contact you via email with our findings.
#
# If you have any further questions in the meantime, please don't hesitate to reply to this email or call us at [Phone Number].
#
#
# Thank you,
#
# The Billing Support Team
#
#
# Ticket 3:
# ----------------------------------------
# Subject: How to export data?
#     Message: I need to export all my project data to Excel. I've looked through the docs but can't
#     figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
#     Best regards,
#     Mike
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
# The user is asking about how to export data. This is a product usage question.
#
# Selected route: product
# Product Support Response:
#
# Hi Mike,
#
# Thanks for reaching out!  It's great you're looking to export your project data.  We definitely support bulk exporting to Excel (and other formats too!). I'd be happy to walk you through the process. It's easier than you might think.
#
# Here's a breakdown of how to export your project data in bulk:
#
# 1. **Navigate to the Export Section:** In your project view, locate the "Export" button. It's typically in the top right corner of the data table or in a dedicated "Actions" menu.  [See our documentation on locating the Export button](hypothetical_link_to_export_button_location).
#
# 2. **Choose "Export All":**  In the export menu, you'll see several options. Select "Export All" to export all of your project's data. You can also filter the data before exporting if you only need a subset.
#
# 3. **Select Excel as your Format:** The export menu allows you to choose different file formats.  Select "Excel (.xlsx)" or "CSV (.csv)" for compatibility with Excel. If you're working with very large datasets, CSV might be a better choice for performance.
#
# 4. **Customize your Export (Optional):** Depending on the features available in your plan, you might have options to customize your export.  For example, you can often:
#
#     * **Choose specific columns:** Export only the data fields relevant to your analysis.  This helps keep your files smaller and easier to manage.
#     * **Apply existing filters:** If you've filtered your project data view, you can preserve these filters in the export.
#     * **Sort data:** Choose the order of your data based on a specific column (e.g., date, name).
#
#     [Learn more about customizing exports here](hypothetical_link_to_customizing_exports).
#
# 5. **Click "Export":** Once you've made your selections, click the "Export" button to start the process. You'll receive a notification or a download link when the export is complete.
#
#
# **Example:** Imagine you have a project tracking sales leads.  You want to export all leads generated in the last quarter.  You would filter your project view by date, select "Export All," choose the "Excel" format, and click export.  This would generate an Excel file containing all the information on your filtered leads.
#
# We also have other export related features you might find useful:
#
# * **Scheduled Exports:** If you need regular exports of your data (e.g., a weekly sales report), you can set up scheduled exports. [See our documentation on scheduled exports](hypothetical_link_to_scheduled_exports).
# * **API Access:** For more complex integrations or automated workflows, our API allows programmatic access to export data.  [Learn more about our API](hypothetical_link_to_api_docs).
#
#
# If you encounter any problems during the export process or have any further questions, don't hesitate to reach out to us.  We're here to help!
#
# Best regards,
#
# The Product Support Team
