# %% [markdown]
# # Building Effective Agents (with Pydantic AI)
# ## Basic Workflows

# %%
# %pip install -r requirements.txt
from IPython.display import clear_output ; clear_output()

# %%
from util import initialize, show
AI_MODEL = initialize()

import asyncio
from typing import List, Dict

from pydantic import BaseModel, Field
from pydantic_ai import Agent
# Out:
# Available AI models:
# ['openai:gpt-4o',
#  'openai:gpt-4o-mini',
#  'gemini-1.5-pro',
#  'gemini-2.0-flash-exp',
#  'claude-3-5-haiku-latest',
#  'claude-3-5-sonnet-latest']
#
# Using AI model: openai:gpt-4o

# %% [markdown]
# ### Workflow: Prompt Chaining

# %%
async def chain(input: str, prompts: List[str]) -> str:
    """Chain multiple LLM calls sequentially, passing results between steps."""
    agent = Agent(AI_MODEL)
    result = input
    for i, prompt in enumerate(prompts, 1):
        agent = Agent(AI_MODEL, system_prompt=prompt)
        result = (await agent.run(f"nInput:\n{result}")).data
        show(result, title=f"Step {i}")
    return result

# %%
data_processing_steps = [
    """Extract only the numerical values and their associated metrics from the text.
    Format each as 'value: metric' on a new line.
    Example format:
    92: customer satisfaction
    45%: revenue growth""",
    
    """Convert all numerical values to percentages where possible.
    If not a percentage or points, convert to decimal (e.g., 92 points -> 92%).
    Keep one number per line.
    Example format:
    92%: customer satisfaction
    45%: revenue growth""",
    
    """Sort all lines in descending order by numerical value.
    Keep the format 'value: metric' on each line.
    Example:
    92%: customer satisfaction
    87%: employee satisfaction""",
    
    """Format the sorted data as a markdown table with columns:
    | Metric | Value |
    |:--|--:|
    | Customer Satisfaction | 92% |"""
]

report = """
Q3 Performance Summary:
Our customer satisfaction score rose to 92 points this quarter.
Revenue grew by 45% compared to last year.
Market share is now at 23% in our primary market.
Customer churn decreased to 5% from 8%.
New user acquisition cost is $43 per user.
Product adoption rate increased to 78%.
Employee satisfaction is at 87 points.
Operating margin improved to 34%.
""".strip()

show(report, title="Input text")
formatted_result = await chain(report, data_processing_steps)
show(formatted_result, title="Result")
# Out:
# Input text
# ----------
#
# Q3 Performance Summary:
# Our customer satisfaction score rose to 92 points this quarter.
# Revenue grew by 45% compared to last year.
# Market share is now at 23% in our primary market.
# Customer churn decreased to 5% from 8%.
# New user acquisition cost is $43 per user.
# Product adoption rate increased to 78%.
# Employee satisfaction is at 87 points.
# Operating margin improved to 34%.
#
#
# Step 1
# ------
#
# 92: customer satisfaction
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# $43: new user acquisition cost
# 78%: product adoption rate
# 87: employee satisfaction
# 34%: operating margin
#
#
# Step 2
# ------
#
# 92%: customer satisfaction
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# 43: new user acquisition cost
# 78%: product adoption rate
# 87%: employee satisfaction
# 34%: operating margin
#
#
# Step 3
# ------
#
# 92%: customer satisfaction
# 87%: employee satisfaction
# 78%: product adoption rate
# 45%: revenue growth
# 34%: operating margin
# 23%: market share
# 5%: customer churn
# 43: new user acquisition cost
#
#
# Step 4
# ------
#
# | Metric                  | Value |
# |:------------------------|------:|
# | Customer Satisfaction   |   92% |
# | Employee Satisfaction   |   87% |
# | Product Adoption Rate   |   78% |
# | Revenue Growth          |   45% |
# | New User Acquisition Cost | 43   |
# | Operating Margin        |   34% |
# | Market Share            |   23% |
# | Customer Churn          |    5% |
#
#
# Result
# ------
#
# | Metric                  | Value |
# |:------------------------|------:|
# | Customer Satisfaction   |   92% |
# | Employee Satisfaction   |   87% |
# | Product Adoption Rate   |   78% |
# | Revenue Growth          |   45% |
# | New User Acquisition Cost | 43   |
# | Operating Margin        |   34% |
# | Market Share            |   23% |
# | Customer Churn          |    5% |

# %% [markdown]
# ### Workflow: Routing

# %%
class RouteSelection(BaseModel):
    reasoning: str = Field(..., description=(
        'Brief explanation of why this ticket should be routed '
        'to a specific team. Consider key terms, user intent, '
        'and urgency level.'
    ))
    selection: str = Field(..., description='The chosen team name')


async def route(input: str, routes: Dict[str, str]) -> str:
    """Route input to specialized prompt using content classification."""

    # First, determine appropriate route using LLM with chain-of-thought
    show(f"{list(routes.keys())}", title="Available Routes")
    
    routing_agent = Agent(
        AI_MODEL,
        system_prompt=(
            'Analyze the input and select the most appropriate support team '
            f'from these options: {list(routes.keys())}'
        ),
        result_type=RouteSelection,
    )
    route_response = await routing_agent.run(input)
    reasoning = route_response.data.reasoning
    route_key = route_response.data.selection.strip().lower()
    
    show(reasoning, title="Routing Analysis")
    show(f"{route_key}", title="Selected Route")
    
    # Process input with selected specialized prompt
    worker_agent = Agent(AI_MODEL, system_prompt=routes[route_key])
    return (await worker_agent.run(input)).data

# %%
support_routes = {
    "billing": """You are a billing support specialist. Follow these guidelines:
    1. Always start with "Billing Support Response:"
    2. First acknowledge the specific billing issue
    3. Explain any charges or discrepancies clearly
    4. List concrete next steps with timeline
    5. End with payment options if relevant
    
    Keep responses professional but friendly.""",
    
    "technical": """You are a technical support engineer. Follow these guidelines:
    1. Always start with "Technical Support Response:"
    2. List exact steps to resolve the issue
    3. Include system requirements if relevant
    4. Provide workarounds for common problems
    5. End with escalation path if needed
    
    Use clear, numbered steps and technical details.""",
    
    "account": """You are an account security specialist. Follow these guidelines:
    1. Always start with "Account Support Response:"
    2. Prioritize account security and verification
    3. Provide clear steps for account recovery/changes
    4. Include security tips and warnings
    5. Set clear expectations for resolution time
    
    Maintain a serious, security-focused tone.""",
    
    "product": """You are a product specialist. Follow these guidelines:
    1. Always start with "Product Support Response:"
    2. Focus on feature education and best practices
    3. Include specific examples of usage
    4. Link to relevant documentation sections
    5. Suggest related features that might help
    
    Be educational and encouraging in tone."""
}

# Test with different support tickets
tickets = [
    """Subject: Can't access my account
    Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error. 
    I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to 
    submit a report by end of day.
    - John""",
    
    """Subject: Unexpected charge on my card
    Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
    I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
    Thanks,
    Sarah""",
    
    """Subject: How to export data?
    Message: I need to export all my project data to Excel. I've looked through the docs but can't
    figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
    Best regards,
    Mike"""
]

print("Processing support tickets...\n")
for i, ticket in enumerate(tickets, 1):
    show(ticket, title=f"Ticket {i}")
    response = await route(ticket, support_routes)
    show(response, title=f"Response {i}")
# Out:
# Processing support tickets...
#
#
# Ticket 1
# --------
#
# Subject: Can't access my account
#     Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error.
#     I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to
#     submit a report by end of day.
#     - John
#
#
# Available Routes
# ----------------
#
# ['billing', 'technical', 'account', 'product']
#
#
# Routing Analysis
# ----------------
#
# The user is experiencing issues accessing their account and needs urgent assistance to submit a report. The problem is related to login credentials, which typically falls under account management support rather than technical issues with the website or application itself. Hence, the account support team is best equipped to handle password and access-related problems.
#
#
# Selected Route
# --------------
#
# account
#
#
# Response 1
# ----------
#
# Account Support Response:
#
# To address your issue with accessing your account, please follow these steps to regain access promptly and securely:
#
# 1. **Password Reset**: Visit the login page of the account service and click on "Forgot Password." Follow the instructions to reset your password. Ensure that you choose a strong password containing a mix of uppercase letters, lowercase letters, numbers, and symbols.
#
# 2. **Email Verification**: Check your registered email account inbox and spam folders for a password reset link. Clicking this link will guide you through the process of creating a new password.
#
# 3. **Update Security Information**: Once access is restored, please review and update your account security settings, such as ensuring your recovery email and phone number are current.
#
# 4. **Two-Factor Authentication**: Enable two-factor authentication if it is supported by the service to add an additional layer of security to your account.
#
# **Security Tips and Warnings**:
# - Avoid using the same password across multiple sites.
# - Be cautious of any phishing emails that may ask for personal information or credentials.
#
# We aim to resolve such cases typically within 24 hours of receiving a report. If you continue to experience issues after following these steps, please contact our support team immediately with details of any error messages received during the process.
#
# Your account security is our top priority. Thank you for your understanding and cooperation.
#
#
#
#
# Ticket 2
# --------
#
# Subject: Unexpected charge on my card
#     Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
#     I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
#     Thanks,
#     Sarah
#
#
# Available Routes
# ----------------
#
# ['billing', 'technical', 'account', 'product']
#
#
# Routing Analysis
# ----------------
#
# The user is concerned about a discrepancy in billing charges and requests clarification and adjustment for the unexpected charge. The keyword 'charge' indicates a financial transaction-related issue, specifically linked to the billing aspect of the services. Therefore, the billing team is best equipped to handle inquiries about charges, pricing plans, and necessary adjustments.
#
#
# Selected Route
# --------------
#
# billing
#
#
# Response 2
# ----------
#
# Billing Support Response:
#
# Hello Sarah,
#
# Thank you for reaching out about the unexpected charge on your card. Let’s address the specifics of your billing issue.
#
# Upon examination, the $49.99 charge is for the upgraded membership plan that offers additional features compared to the $29.99 plan. It appears there may have been an unintentional switch or misunderstanding regarding your subscription.
#
# Here are the next steps to resolve this:
# 1. We will investigate further to confirm whether this change was requested. This should take about 1-2 business days.
# 2. If it turns out the switch was unintended, we will promptly adjust your account back to the $29.99 plan and refund the difference of $20.00. This adjustment should reflect in your account within 5-7 business days following our confirmation.
#
# In the meantime, if you have any immediate concerns or require further assistance, feel free to contact our support team directly.
#
# For payment options, you may continue using your current card details, and any adjustments will be processed automatically.
#
# Thank you for your patience and understanding.
#
# Best regards,
# Billing Support Team
#
#
# Ticket 3
# --------
#
# Subject: How to export data?
#     Message: I need to export all my project data to Excel. I've looked through the docs but can't
#     figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
#     Best regards,
#     Mike
#
#
# Available Routes
# ----------------
#
# ['billing', 'technical', 'account', 'product']
#
#
# Routing Analysis
# ----------------
#
# The user's query is about exporting data, which is a technical task. The user is looking for guidance on performing a bulk export of project data to Excel. This type of query typically falls under the expertise of a technical support team because it involves understanding the software's functionality and processes for data management, which are more technical in nature.
#
#
# Selected Route
# --------------
#
# technical
#
#
# Response 3
# ----------
#
# Technical Support Response:
#
# To export all your project data to Excel, please follow these steps:
#
# 1. **Login to Your Account:**
#    - Ensure you are logged into the platform where your project data is stored with appropriate permissions to view and export data.
#
# 2. **Navigate to the Project Dashboard:**
#    - Go to the section or module of the application where your project data is located.
#
# 3. **Locate the Export Option:**
#    - Look for an "Export" or "Download" button. This is often found within a settings menu or as an option on the toolbar.
#
# 4. **Select Data for Export:**
#    - If the platform allows filtering, select the data range or categories you wish to export. Ensure "All Data" is selected if you wish to do a bulk export.
#
# 5. **Choose Export Format:**
#    - When prompted, select "Excel" or ".xlsx" as the output format. Some platforms may offer a CSV option as well, which can be opened in Excel.
#
# 6. **Initiate the Export:**
#    - Click the "Export" or "Download" button to start the data export process.
#
# 7. **Check for Download:**
#    - Once the process is complete, your file should automatically download. Check your browser's download folder for the Excel file.
#
# System Requirements:
# - Ensure you have Microsoft Excel or a compatible application to open and edit .xlsx files.
#
# Common Problems and Workarounds:
# - **Export Button Not Visible:** This might be due to limited permissions. Confirm you have the necessary access rights.
# - **Browser Blocks Download:** Check browser settings or disable any extensions that might block downloads.
# - **Large Data Volume:** If the data volume is too large, consider exporting in batches, if the platform allows.
#
# Escalation Path:
# - If you continue to experience issues or if there is no bulk export feature available, please contact our support team directly at [Support Contact Email/Number]. Provide details of the platform version you are using for personalized assistance.

# %% [markdown]
# ### Workflow: Parallelization

# %%
async def parallel(prompt: str, inputs: List[str]) -> List[str]:
    """Process multiple inputs concurrently with the same prompt."""
    agent = Agent(AI_MODEL, system_prompt=prompt)
    results = await asyncio.gather(*[
        agent.run(input)
        for input in inputs
    ])
    return [result.data for result in results]

# %%
stakeholders = [
    """Customers:
    - Price sensitive
    - Want better tech
    - Environmental concerns""",
    
    """Employees:
    - Job security worries
    - Need new skills
    - Want clear direction""",
    
    """Investors:
    - Expect growth
    - Want cost control
    - Risk concerns""",
    
    """Suppliers:
    - Capacity constraints
    - Price pressures
    - Tech transitions"""
]

impact_results = await parallel(
    """Analyze how market changes will impact this stakeholder group.
    Provide specific impacts and recommended actions.
    Format with clear sections and priorities.""",
    stakeholders
)

for stakeholder, result in zip(stakeholders, impact_results):
    show(result, stakeholder.split(':')[0])
# Out:
# Customers
# ---------
#
# ### Market Changes Impact on Customers
#
# **1. Price Sensitivity**
#
# **Impacts:**
# - **Inflation and Rising Costs:** As inflation continues to affect the economy, prices of goods, including tech products, may increase. This will directly impact price-sensitive customers who may reduce spending or switch to cheaper alternatives.
# - **Shift to Affordable Brands:** High prices could push customers towards brands or retailers that offer competitive pricing, discounts, or value-added services.
#
# **Recommended Actions:**
# - **Dynamic Pricing Strategies:** Implement dynamic pricing models that adjust in real-time based on demand, ensuring competitive pricing.
# - **Promotions and Discounts:** Regularly offer promotions and discounts to attract price-sensitive customers and maintain loyalty.
# - **Bundle Offers:** Create product bundles that offer more value for money, encouraging upsell opportunities.
#
# **2. Desire for Better Technology**
#
# **Impacts:**
# - **Demand for Innovation:** Customers will continually seek out the latest technology advancements, pushing companies to innovate frequently.
# - **Increased Competition:** With technological advancement speeding up, competitors will constantly strive to release improved versions, leading to rapid market shifts.
#
# **Recommended Actions:**
# - **R&D Investment:** Increase investment in research and development to stay ahead of technology trends and provide cutting-edge products.
# - **Product Updates:** Implement a consistent schedule of product updates and upgrades to retain customer interest and meet evolving expectations.
# - **Customer Feedback Integration:** Actively gather and integrate customer feedback to tailor future technology solutions that meet their specific needs.
#
# **3. Environmental Concerns**
#
# **Impacts:**
# - **Demand for Sustainable Products:** Customers are increasingly prioritizing eco-friendly products, influencing purchasing decisions.
# - **Brand Reputation:** Companies not aligning with environmental values may face backlash, impacting reputation and sales.
#
# **Recommended Actions:**
# - **Eco-Friendly Materials:** Invest in sustainable materials and production processes to develop environmentally friendly products.
# - **Transparency and Communication:** Be transparent about sustainability efforts and communicate them effectively to enhance brand value and customer trust.
# - **Eco-Incentives:** Offer incentives like trade-in programs or discounts for recycling old tech products to encourage sustainable practices.
#
# ### Priorities
#
# 1. **Address Price Sensitivity First:**
#    - Implement competitive pricing models as this is a decisive factor for customer retention.
#
# 2. **Focus on Technological Innovation:**
#    - Prioritize research and development to maintain a competitive edge with the latest tech advancements.
#
# 3. **Enhance Environmental Efforts:**
#    - Ensure sustainable practices are integrated within the brand’s ethos and communicated clearly to align with growing environmental concerns.
#
# By addressing these key impacts with the recommended actions, companies can effectively retain and grow their customer base amidst changing market dynamics.
#
#
# Employees
# ---------
#
# **Market Changes and Their Impacts on Employees**
#
# 1. **Technological Advancements**
#    - **Impact**: Emergence of new technologies can lead to workforce automation, causing job security concerns among employees. These advancements necessitate upskilling to thrive in the evolving market environment.
#    - **Recommended Actions**:
#      - **Upskilling and Reskilling Programs**: Implement regular training sessions to equip employees with new skills relevant to emerging technologies. Encourage continuous learning to help employees stay competitive.
#      - **Communication**: Clearly communicate technological changes and how they will impact job roles. Transparency will help alleviate job security worries.
#
# 2. **Economic Fluctuations**
#    - **Impact**: Economic downturns or rapid growth can result in organizational restructuring, affecting job stability. In times of expansion, employees might be overwhelmed with increased workloads, while downturns might lead to layoffs.
#    - **Recommended Actions**:
#      - **Job Security Assurance**: Develop plans that prioritize job security, such as flex-work or salary adjustments, during economic downturns.
#      - **Workload Management**: Deploy strategies to manage increased workloads effectively during growth phases, such as hiring temporary workers or implementing collaborative tools.
#
# 3. **Evolving Consumer Preferences**
#    - **Impact**: Changes in consumer preferences require companies to pivot their strategies quickly, potentially altering job requirements and expectations.
#    - **Recommended Actions**:
#      - **Flexibility and Adaptability Training**: Encourage a culture of adaptability where employees are trained to adjust to changing job requirements swiftly.
#      - **Feedback Mechanisms**: Establish regular feedback sessions to gather employee insights on coping with changes in consumer demands and involve them in the decision-making process to foster a sense of ownership and direction.
#
# **Setting Priorities**
#
# 1. **Immediate Actions**
#    - Initiate comprehensive upskilling programs to align employee capabilities with technological changes.
#    - Communicate a clear company vision and how each employee fits into that future.
#
# 2. **Short-term Actions (6-12 months)**
#    - Establish a task force to regularly assess the impact of market changes and adjust workforce strategies accordingly.
#    - Create platforms for employee feedback and concerns to be heard and addressed promptly.
#
# 3. **Long-term Actions (1-3 years)**
#    - Develop an employee-first policy framework that prioritizes job security and employee well-being.
#    - Continuously evaluate and update training programs to ensure they stay relevant to market needs.
#
# **Conclusion**
# Market changes pose significant challenges and opportunities for employees, particularly concerning job security, skill development, and the need for clear direction. By prioritizing immediate communication, continuous upskilling, and establishing a culture of flexibility, companies can mitigate some of these impacts and better prepare their workforce for future changes.
#
#
# Investors
# ---------
#
# **Market Changes Analysis for Investors**
#
# **1. Expected Growth:**
#
# **Impact:**
# - Market growth will be a critical factor for investors, expecting businesses to capture higher market shares and generate increased revenues. Investors will likely evaluate companies based on their adaptability to evolving market conditions and their ability to innovate, enter new markets, or expand product lines to drive growth.
#
# **Recommended Actions:**
# - **Invest in Innovation:** Companies should prioritize R&D to create new products or services that align with emerging market trends.
# - **Market Expansion:** Explore opportunities in untapped or developing markets that show significant growth potential.
# - **Strategic Partnerships:** Form alliances or partnerships that can enhance market presence or add to technological capabilities.
#
# **2. Cost Control:**
#
# **Impact:**
# - Investors will remain cautious of companies unable to manage their costs effectively, particularly in a volatile market where input costs can be unpredictable. A failure to control costs can lead to diminished profit margins and impact investor confidence negatively.
#
# **Recommended Actions:**
# - **Operational Efficiency:** Implement cost-reduction strategies without compromising quality, such as automating processes or optimizing supply chains.
# - **Sustainability Initiatives:** Adopt sustainable practices that not only cut costs in the long term but also appeal to environmentally-conscious stakeholders.
# - **Regular Audits:** Conduct regular financial audits to identify areas where expenses can be minimized.
#
# **3. Risk Concerns:**
#
# **Impact:**
# - Market volatility, geopolitical tensions, or unexpected economic downturns could heighten investors' risk concerns. Investors will be more focused on the stability and resilience of their investments in uncertain market conditions.
#
# **Recommended Actions:**
# - **Diversification:** Advise companies to diversify their product offerings and operational regions to spread risks.
# - **Risk Management Practices:** Develop comprehensive risk management frameworks that allow for quick response to emerging threats.
# - **Transparent Communication:** Maintain open lines of communication with investors regarding potential risks and the strategies in place to mitigate them.
#
# **Priorities for Investors:**
#
# **1. Growth Initiatives:** Seek opportunities where firms can demonstrate clear pathways to sustainable growth, capitalizing on technology and new markets.
#
# **2. Cost Management Strategies:** Prioritize investments in companies that show strong financial discipline and innovative cost management.
#
# **3. Risk Mitigation Plans:** Focus on businesses with robust risk management strategies to ensure long-term stability in turbulent markets.
#
# By aligning investment strategies with these changing market dynamics, investors can better position themselves to capitalize on opportunities while mitigating potential risks.
#
#
# Suppliers
# ---------
#
# **Impacts on Suppliers**
#
# 1. **Capacity Constraints**
#    - *Impact:* As market demands shift, suppliers facing capacity constraints may struggle to meet increased orders or fluctuating demands. This can lead to delayed delivery times, strained relationships with clients, and potential loss of business to more agile competitors.
#    - *Recommended Actions:*
#      - **Investment in Infrastructure:** Evaluate current production capabilities and invest in expanding facilities or upgrading machinery to increase output.
#      - **Flexible Workforce Management:** Implement strategies such as cross-training employees to tackle bottlenecks and adopting scalable workforce solutions like temporary staffing during peak times.
#      - **Supply Chain Diversification:** Explore options for diversifying supply sources to bolster capacity and mitigate risks associated with single-source dependencies.
#
# 2. **Price Pressures**
#    - *Impact:* Suppliers may face intensified price pressures due to global economic conditions, increased competition, or bargaining power shifts favoring buyers.
#    - *Recommended Actions:*
#      - **Cost Optimization:** Conduct a thorough review of the production process to identify areas for cost reduction, such as energy conservation or waste management improvements.
#      - **Value Proposition Enhancement:** Focus on differentiation by improving product quality, customer service, or adding unique features to justify premium pricing.
#      - **Collaborative Relationships:** Foster closer partnerships with key clients to negotiate longer-term contracts that provide stability and predictable pricing.
#
# 3. **Tech Transitions**
#    - *Impact:* Rapid technological advancements and transitions can render existing processes or products obsolete, impacting suppliers who fail to adapt quickly.
#    - *Recommended Actions:*
#      - **R&D Investment:** Allocate resources towards research and development to stay ahead in tech trends and integrate innovative solutions into product offerings.
#      - **Digital Transformation:** Implement digital tools and platforms to streamline operations, improve data analytics capabilities, and enhance decision-making processes.
#      - **Partnerships and Alliances:** Engage in strategic collaborations with tech firms or other industry players to leverage new technologies and accelerate adoption.
#
# **Priorities for Implementation**
#
# 1. **Capacity Enhancement (Immediate Priority)**
#    - Evaluate and take quick action to overcome capacity limitations, as an inability to fulfill orders will directly impact revenue and competitive positioning.
#
# 2. **Cost Management and Price Strategy (Short-term Priority)**
#    - Immediate assessment and fine-tuning of cost structures are crucial to navigate current price pressures and maintain profitability.
#
# 3. **Technology and Innovation (Long-term Priority)**
#    - While technological upgrades may not yield immediate results, initiating steps towards digital transformation and innovation is critical for long-term competitiveness and relevance in evolving markets.
#
# By addressing these key areas, suppliers can better navigate the dynamic market landscape and position themselves for sustained growth and stability despite external pressures.
