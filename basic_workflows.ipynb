# %%
# %pip install pydantic-ai python-dotenv nest_asyncio
from IPython.display import clear_output ; clear_output()

from dotenv import load_dotenv ; load_dotenv()
import nest_asyncio ; nest_asyncio.apply()

# %%
import asyncio
from typing import List, Dict

from pydantic import BaseModel, Field
from pydantic_ai import Agent

AI_MODEL = 'openai:gpt-4o'

# %%
async def chain(input: str, prompts: List[str]) -> str:
    """Chain multiple LLM calls sequentially, passing results between steps."""
    agent = Agent(AI_MODEL)
    result = input
    for i, prompt in enumerate(prompts, 1):
        print(f"\nStep {i}:")
        result = (await agent.run(f"{prompt}\nInput: {result}")).data
        print(result)
    return result

# %%
data_processing_steps = [
    """Extract only the numerical values and their associated metrics from the text.
    Format each as 'value: metric' on a new line.
    Example format:
    92: customer satisfaction
    45%: revenue growth""",
    
    """Convert all numerical values to percentages where possible.
    If not a percentage or points, convert to decimal (e.g., 92 points -> 92%).
    Keep one number per line.
    Example format:
    92%: customer satisfaction
    45%: revenue growth""",
    
    """Sort all lines in descending order by numerical value.
    Keep the format 'value: metric' on each line.
    Example:
    92%: customer satisfaction
    87%: employee satisfaction""",
    
    """Format the sorted data as a markdown table with columns:
    | Metric | Value |
    |:--|--:|
    | Customer Satisfaction | 92% |"""
]

report = """
Q3 Performance Summary:
Our customer satisfaction score rose to 92 points this quarter.
Revenue grew by 45% compared to last year.
Market share is now at 23% in our primary market.
Customer churn decreased to 5% from 8%.
New user acquisition cost is $43 per user.
Product adoption rate increased to 78%.
Employee satisfaction is at 87 points.
Operating margin improved to 34%.
"""

print("\nInput text:")
print(report)
formatted_result = await chain(report, data_processing_steps)
print(formatted_result)
# Out:
# Input text:
#
# Q3 Performance Summary:
# Our customer satisfaction score rose to 92 points this quarter.
# Revenue grew by 45% compared to last year.
# Market share is now at 23% in our primary market.
# Customer churn decreased to 5% from 8%.
# New user acquisition cost is $43 per user.
# Product adoption rate increased to 78%.
# Employee satisfaction is at 87 points.
# Operating margin improved to 34%.
#
#
# Step 1:
# 92: customer satisfaction
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# 43: new user acquisition cost
# 78%: product adoption rate
# 87: employee satisfaction
# 34%: operating margin
#
# Step 2:
# 92%: customer satisfaction
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# 43%: new user acquisition cost
# 78%: product adoption rate
# 87%: employee satisfaction
# 34%: operating margin
#
# Step 3:
# Here is the sorted list in descending order by numerical value:
#
# ```
# 92%: customer satisfaction
# 87%: employee satisfaction
# 78%: product adoption rate
# 45%: revenue growth
# 43%: new user acquisition cost
# 34%: operating margin
# 23%: market share
# 5%: customer churn
# ```
#
# Step 4:
# Here is the markdown table with the sorted data:
#
# ```markdown
# | Metric                      | Value |
# |:----------------------------|------:|
# | Customer Satisfaction       |   92% |
# | Employee Satisfaction       |   87% |
# | Product Adoption Rate       |   78% |
# | Revenue Growth              |   45% |
# | New User Acquisition Cost   |   43% |
# | Operating Margin            |   34% |
# | Market Share                |   23% |
# | Customer Churn              |    5% |
# ```
# Here is the markdown table with the sorted data:
#
# ```markdown
# | Metric                      | Value |
# |:----------------------------|------:|
# | Customer Satisfaction       |   92% |
# | Employee Satisfaction       |   87% |
# | Product Adoption Rate       |   78% |
# | Revenue Growth              |   45% |
# | New User Acquisition Cost   |   43% |
# | Operating Margin            |   34% |
# | Market Share                |   23% |
# | Customer Churn              |    5% |
# ```

# %%
async def parallel(prompt: str, inputs: List[str]) -> List[str]:
    """Process multiple inputs concurrently with the same prompt."""
    agent = Agent(
        AI_MODEL,
        system_prompt=prompt,
    )
    results = await asyncio.gather(*[
        agent.run(input)
        for input in inputs
    ])
    return [result.data for result in results]

# %%
stakeholders = [
    """Customers:
    - Price sensitive
    - Want better tech
    - Environmental concerns""",
    
    """Employees:
    - Job security worries
    - Need new skills
    - Want clear direction""",
    
    """Investors:
    - Expect growth
    - Want cost control
    - Risk concerns""",
    
    """Suppliers:
    - Capacity constraints
    - Price pressures
    - Tech transitions"""
]

impact_results = await parallel(
    """Analyze how market changes will impact this stakeholder group.
    Provide specific impacts and recommended actions.
    Format with clear sections and priorities.""",
    stakeholders
)

for result in impact_results:
    print(result)
# Out:
# Market Changes and Impacts on Customers
#
# 1. Price Fluctuations
#    - **Impact**: Price-sensitive customers are highly affected by changes in raw material costs, production, and distribution expenses, potentially leading to higher product prices. These customers might reduce consumption or switch to cheaper alternatives if prices increase significantly.
#    - **Recommended Actions**:
#      - Offer discounts, loyalty programs, or bundling options to maintain customer affordability.
#      - Enhance transparency in pricing to build trust and explain any necessary price increases.
#
# 2. Advancements in Technology
#    - **Impact**: Customers' desire for better technology means they expect continuous innovation and enhancements in product features. Companies not keeping up with technological trends may lose market share.
#    - **Recommended Actions**:
#      - Invest in R&D to ensure offerings are in line with technological advancements.
#      - Regularly update product lines and incorporate customer feedback to align with technological expectations.
#
# 3. Environmental Concerns
#    - **Impact**: Growing environmental awareness is influencing customer purchasing decisions, with a preference for sustainable and eco-friendly products.
#    - **Recommended Actions**:
#      - Develop and market products with eco-friendly materials and sustainable practices.
#      - Educate customers on your company’s commitment to environmental responsibility through transparent reporting and communication.
#
# 4. Increased Competition
#    - **Impact**: As markets grow more competitive, customers have more alternatives making it easier to switch to brands that offer better value or align more closely with their values.
#    - **Recommended Actions**:
#      - Differentiate your product by highlighting unique selling points such as sustainability, technological innovation, or superior customer service.
#      - Continuously monitor competitors' strategies to ensure competitive pricing and quality offerings.
#
# Prioritized Actions
#
# 1. **Innovation & Technology Enhancement**:
#    - Prioritize investment in technology as it's a key driver for customer satisfaction and differentiation.
#
# 2. **Sustainability Initiatives**:
#    - Focus on sustainability to meet customer demands and potentially access new segments committed to environmental responsibility.
#
# 3. **Competitive Pricing Strategies**:
#    - Formulate effective pricing strategies that consider customer sensitivity to price while ensuring profitability.
#
# By aligning business strategies with these prioritized actions, companies can mitigate negative impacts and capitalize on emerging opportunities presented by market changes.
# **Market Changes**
#
# 1. **Technological Advancements**: Automation and AI integration are transforming industries, leading to process optimization and, potentially, a reduction in manpower requirements.
#
# 2. **Economic Volatility**: Fluctuations in the economic climate can influence company stability, often resulting in reorganization or downsizing.
#
# 3. **Shift to Remote Work**: Many companies are embracing remote or hybrid work models, which have altered traditional workflows and skill requirements.
#
# 4. **Industry-Specific Trends**: Industries, particularly those in tech, retail, and manufacturing, are experiencing paradigm shifts due to emerging technologies and consumer demands.
#
# ---
#
# **Impact on Employees**
#
# 1. **Job Security Worries**
#    - With automation on the rise, positions susceptible to mechanization may be reduced.
#    - Economic instability can lead to job cuts, particularly in non-critical business areas.
#    - Remote work can result in concerns over job visibility and performance metrics.
#
# 2. **Need for New Skills**
#    - Employees must adapt to new technology; reskilling in areas like data analytics, AI, and digital tools is necessary.
#    - Mastery of remote work technologies and maintaining productivity in a virtual environment are essential.
#
# 3. **Desire for Clear Direction**
#    - Uncertainty due to market changes requires transparent communication from leadership.
#    - Employees desire clear guidance on personal professional development in line with company goals.
#
# ---
#
# **Recommended Actions**
#
# 1. **Enhance Job Security**
#    - **Priority**: High
#    - **Actions**:
#      - Communicate openly about market challenges and how the company plans to address them.
#      - Develop retention strategies focused on employee engagement and value demonstration.
#      - Consider opportunities for job reallocation within the organization to mitigate potential job losses due to automation.
#
# 2. **Facilitate Skill Development**
#    - **Priority**: High
#    - **Actions**:
#      - Invest in training programs focused on current and emerging technologies.
#      - Encourage enrollment in online courses, workshops, and certifications.
#      - Implement mentorship programs pairing tech-savvy employees with those in need of upskilling.
#
# 3. **Provide Clear Direction**
#    - **Priority**: Medium
#    - **Actions**:
#      - Regularly update employees on business goals, strategic priorities, and how market changes could influence company direction.
#      - Establish clear pathways for career advancement within the evolving business landscape.
#      - Leverage digital communication tools to ensure consistent and clear messaging across remote teams.
#
# 4. **Support Remote Work Transition**
#    - **Priority**: Medium
#    - **Actions**:
#      - Provide resources and support for effective remote working setups.
#      - Foster a culture that values results over physical presence, adjusting performance metrics to suit remote work.
#      - Encourage regular check-ins and virtual team-building activities to maintain team cohesion.
#
# By addressing these concerns through strategic actions, companies can not only alleviate employee concerns but also enhance their workforce’s adaptability to ongoing market changes.
# **Analysis of Market Changes and Impacts on Investors**
#
# **1. Market Growth Trends**
#
# **Impact:** Investors expect growth, and market changes such as technological advancements, regulatory shifts, and economic cycles can greatly influence the growth prospects of the companies they invest in. Market expansion in sectors like renewable energy, technology, and healthcare can offer new growth opportunities.
#
# **Recommended Actions:**
# - **Diversification:** Encourage investment in diverse industries and geographies to capitalize on various growth opportunities and offset risks associated with a single market.
# - **Investment in Innovation:** Support companies that are investing in R&D and innovation, as these are typically positioned to achieve sustainable long-term growth.
# - **Trend Analysis:** Regularly update investors on market trends and their potential impacts on portfolio companies to ensure timely decision-making and strategy adjustments.
#
# **2. Cost Control Measures**
#
# **Impact:** Cost control is a primary concern for investors, as it directly affects profitability and ROI. Market changes such as inflation, supply chain disruptions, or rising labor costs can challenge cost management efforts.
#
# **Recommended Actions:**
# - **Efficiency Audits:** Advocate for regular efficiency audits of portfolio companies to identify potential cost-saving measures.
# - **Technology Adoption:** Push for incorporating technology such as automation and AI in operations to enhance efficiency and reduce overhead costs.
# - **Lean Operations:** Encourage companies to adopt lean operational strategies to minimize waste and enhance the value proposition.
#
# **3. Risk Management and Concerns**
#
# **Impact:** Investors are increasingly concerned about various risks including economic downturns, regulatory changes, and geopolitical tensions. Uncertainties like these can lead to market volatility and affect investment stability.
#
# **Recommended Actions:**
# - **Risk Assessment Tools:** Implement comprehensive risk assessment and management tools to continuously monitor and mitigate potential risks.
# - **Hedging Strategies:** Utilize hedging strategies to protect against market volatility and currency fluctuations.
# - **Transparent Communication:** Maintain open communication channels to keep investors informed about potential risks and mitigation strategies, enhancing trust and confidence.
#
# **Prioritization and Strategic Focus Areas**
#
# **Immediate Focus:**
# - Enhance investor communications to ensure they are aware of how changing market dynamics might impact their investments.
# - Conduct portfolio reviews to ensure diversification and alignment with growth sectors.
#
# **Short-term Actions:**
# - Monitor cost structures within invested companies to address inflation and supply chain challenges swiftly.
# - Develop and implement new risk management frameworks to mitigate foreseeable market threats.
#
# **Long-term Strategy:**
# - Invest in market research and trend analysis to anticipate future growth opportunities and position investments accordingly.
# - Cultivate partnerships with emerging tech and sustainable businesses to align with future market evolutions.
#
# By addressing these areas promptly and effectively, investors can navigate market changes with confidence, optimizing both growth potential and risk management in the evolving economic landscape.
# **Analysis: Impact of Market Changes on Suppliers**
#
# **1. Capacity Constraints**
#
# **Impact:**
# - **Reduced Efficiency**: Suppliers may struggle to meet the demand, leading to delayed deliveries, which can affect their reputation and customer satisfaction.
# - **Increased Operating Costs**: Need to invest in expanding capacity or optimizing current operations may lead to increased expenditure.
# - **Bottleneck Risk**: Potential for becoming a bottleneck in the supply chain, influencing downstream operations and relationships with partners.
#
# **Recommended Actions:**
# - **Capacity Expansion**: Invest in scaling production capabilities by adding machinery, hiring more staff, or exploring partnerships to distribute load.
# - **Optimization Programs**: Implement lean manufacturing techniques or explore just-in-time (JIT) inventory systems to enhance efficiency.
# - **Forecasting and Planning**: Enhance demand forecasting methods to better plan for production schedules and workforce needs.
#
# **2. Price Pressures**
#
# **Impact:**
# - **Margin Squeeze**: Pressure to maintain competitive pricing could reduce profit margins.
# - **Supply Chain Tensions**: Potential conflicts with buyers seeking lower prices, leading to strained relationships.
# - **Supplier Selection Criteria**: Buyers may prioritize suppliers with lower prices, impacting long-term contracts and deal renewals.
#
# **Recommended Actions:**
# - **Cost Management**: Analyze cost structures to identify areas to reduce expenses without compromising quality.
# - **Value Proposition**: Strengthen unique selling propositions such as quality, delivery speed, or customer service to justify premium pricing.
# - **Negotiation Practices**: Enhance negotiation strategies with buyers, focusing on long-term value rather than short-term pricing.
#
# **3. Tech Transitions**
#
# **Impact:**
# - **Adaptation Costs**: Initial cost investments in new technologies can be high, potentially affecting financial stability.
# - **Competitive Advantage**: Suppliers who transition smoothly can differentiate themselves in the market with increased efficiency and quality.
# - **Skill Gaps**: Existing workforce may require training, impacting both time and financial resources.
#
# **Recommended Actions:**
# - **Adopt Emerging Technologies**: Invest in digital tools such as IoT sensors, AI-driven analytics, and automation to optimize the supply chain.
# - **Training Programs**: Implement continuous learning initiatives to upskill the workforce, ensuring they are well-versed in new technologies.
# - **Strategic Partnerships**: Collaborate with tech partners or consultants to facilitate a smoother transition and reduce implementation risks.
#
# **Priority Recommendations for Suppliers:**
#
# 1. **Immediate Action**: Focus on capacity optimization to prevent operational bottlenecks and ensure demand can be met effectively. Prioritize this to maintain customer satisfaction and operational efficiency.
#
# 2. **Short-term Action**: Implement cost management strategies to cope with price pressures. This should involve a detailed review of financials and cost-cutting opportunities without compromising on quality.
#
# 3. **Long-term Strategy**: Begin gradual tech transitions by starting with pilot programs to test technologies before full-scale implementation. Prioritize training and partnerships to maximize the benefits of new technologies and improve competitive positioning over time.

# %%
async def route(input: str, routes: Dict[str, str]) -> str:
    """Route input to specialized prompt using content classification."""
    # First determine appropriate route using LLM with chain-of-thought
    print(f"\nAvailable routes: {list(routes.keys())}")

    class RouteSelection(BaseModel):
        reasoning: str = Field(..., description=(
            'Brief explanation of why this ticket should be routed to a specific team. '
            'Consider key terms, user intent, and urgency level.'
        ))
        selection: str = Field(..., description='The chosen team name')
    
    route_response = await Agent(
        AI_MODEL,
        system_prompt=(
            'Analyze the input and select the most appropriate support team from these options: '
            f'{list(routes.keys())}'
        ),
        result_type=RouteSelection,
    ).run(input)
    reasoning = route_response.data.reasoning
    route_key = route_response.data.selection.strip().lower()
    
    print("Routing Analysis:")
    print(reasoning)
    print(f"\nSelected route: {route_key}")
    
    # Process input with selected specialized prompt
    return (await Agent(
        AI_MODEL,
        system_prompt=routes[route_key],
    ).run(input)).data

# %%
support_routes = {
    "billing": """You are a billing support specialist. Follow these guidelines:
    1. Always start with "Billing Support Response:"
    2. First acknowledge the specific billing issue
    3. Explain any charges or discrepancies clearly
    4. List concrete next steps with timeline
    5. End with payment options if relevant
    
    Keep responses professional but friendly.
    
    Input: """,
    
    "technical": """You are a technical support engineer. Follow these guidelines:
    1. Always start with "Technical Support Response:"
    2. List exact steps to resolve the issue
    3. Include system requirements if relevant
    4. Provide workarounds for common problems
    5. End with escalation path if needed
    
    Use clear, numbered steps and technical details.
    
    Input: """,
    
    "account": """You are an account security specialist. Follow these guidelines:
    1. Always start with "Account Support Response:"
    2. Prioritize account security and verification
    3. Provide clear steps for account recovery/changes
    4. Include security tips and warnings
    5. Set clear expectations for resolution time
    
    Maintain a serious, security-focused tone.
    
    Input: """,
    
    "product": """You are a product specialist. Follow these guidelines:
    1. Always start with "Product Support Response:"
    2. Focus on feature education and best practices
    3. Include specific examples of usage
    4. Link to relevant documentation sections
    5. Suggest related features that might help
    
    Be educational and encouraging in tone.
    
    Input: """
}

# Test with different support tickets
tickets = [
    """Subject: Can't access my account
    Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error. 
    I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to 
    submit a report by end of day.
    - John""",
    
    """Subject: Unexpected charge on my card
    Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
    I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
    Thanks,
    Sarah""",
    
    """Subject: How to export data?
    Message: I need to export all my project data to Excel. I've looked through the docs but can't
    figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
    Best regards,
    Mike"""
]

print("Processing support tickets...\n")
for i, ticket in enumerate(tickets, 1):
    print(f"\nTicket {i}:")
    print("-" * 40)
    print(ticket)
    print("\nResponse:")
    print("-" * 40)
    response = await route(ticket, support_routes)
    print(response)
# Out:
# Processing support tickets...
#
#
# Ticket 1:
# ----------------------------------------
# Subject: Can't access my account
#     Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error.
#     I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to
#     submit a report by end of day.
#     - John
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
# The user's issue pertains to trouble accessing their account due to a login error ('invalid password' error). This indicates a problem related to account access or login credentials, which falls under the responsibility of the account support team. The urgency is high as the user needs access to submit a report by the end of the day.
#
# Selected route: account
# Account Support Response:
#
# Thank you for reaching out, John. We understand the urgency of your request and are here to help you regain access to your account while ensuring its security.
#
# 1. **Password Reset**: Please initiate a password reset by selecting 'Forgot Password?' on the login page. Follow the instructions sent to your registered email. Ensure the email is from our official domain to avoid phishing attempts.
#
# 2. **Email Verification**: If you do not receive the password reset email within 10 minutes, check your spam/junk folder. If it's not there, it’s possible that your account might be linked to a different email address. Verify and try again.
#
# 3. **Two-factor Authentication (2FA)**: If your account has 2FA enabled, be prepared to enter the verification code sent to your registered device. Ensure your device is secure to prevent unauthorized access.
#
# 4. **Account Verification**: Should you still be unable to access your account after resetting your password, please contact our support team via the secure contact form on our website. Be ready to provide any requested information to verify your identity, such as answering security questions or providing proof of identity.
#
# 5. **Resolution Time**: Under normal circumstances, these steps should allow you to regain account access within 30 minutes to an hour. If your case requires further investigation, expect a resolution within 24 hours.
#
# **Security Tips**:
# - Always use a strong, unique password for each of your accounts.
# - Regularly update your passwords and enable 2FA for additional security.
# - Be wary of phishing emails and ensure communication is through our official channels.
#
# Please prioritize these steps to resolve the issue swiftly. If you face any further issues, do not hesitate to reach out to us for immediate assistance. Your account security is our top priority.
#
# Ticket 2:
# ----------------------------------------
# Subject: Unexpected charge on my card
#     Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
#     I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
#     Thanks,
#     Sarah
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
# The user is inquiring about an unexpected charge on her credit card, and she mentions being on a specific plan. This relates to the billing aspect of the services, as it is about a financial transaction and not related to any technical, account, or product issue. The billing team is best suited to handle inquiries about charges, plan discrepancies, and potential adjustments.
#
# Selected route: billing
# Billing Support Response:
#
# Hello Sarah,
#
# Thank you for reaching out regarding the unexpected charge on your credit card. Let's address this issue together.
#
# It seems you were charged $49.99, which is indeed above the monthly fee for the $29.99 plan. This discrepancy may have occurred due to a recent upgrade or an oversight if a plan change was not meant to take place. I apologize for any inconvenience this might have caused.
#
# I will immediately initiate a review of your account to confirm the plan you are subscribed to and ensure that the billed amount aligns with the $29.99 plan. This review typically takes about 2 business days. If we find that the higher charge was incorrect, we will process an adjustment to refund the $20 difference promptly.
#
# In the meantime, should you need to update your payment details or have any further questions, feel free to reach out directly. If the charge is to be refunded, it will reflect back on your credit card within 5-7 business days after the adjustment is processed.
#
# Once again, we apologize for the confusion and are committed to resolving this for you swiftly. For your convenience, payment options remain the same: you can continue with your preferred credit card on file, or update it if needed through your account management page.
#
# Best regards,
#
# [Your Name]
# Billing Support Team
#
# Ticket 3:
# ----------------------------------------
# Subject: How to export data?
#     Message: I need to export all my project data to Excel. I've looked through the docs but can't
#     figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
#     Best regards,
#     Mike
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
# The user is inquiring about exporting data, a functionality-related issue, and is seeking guidance on how to perform a bulk export to Excel. This type of query is usually handled by the technical team, as it involves understanding the features of the product and providing step-by-step instructions.
#
# Selected route: technical
# Technical Support Response:
#
# To export your project data to Excel, please follow these steps:
#
# 1. **Access the Data Export Feature:**
#    - Ensure you are logged into your project management software.
#    - Navigate to the main dashboard or the specific project you want to export.
#
# 2. **Initiate the Export Process:**
#    - Look for an 'Export' or 'Download' option, typically found under the 'File' or 'More' menu.
#    - Select 'Export' and choose 'Excel' as the file format from the available options.
#
# 3. **Select Data for Export:**
#    - If prompted, specify whether you wish to export all data or select specific datasets or reports.
#    - Ensure that you select all necessary datasets or project elements to be included in the export.
#
# 4. **Configure Export Settings:**
#    - Some systems allow customization of the data layout or the columns to be included.
#    - Verify these settings to ensure all required data is included in a readable format.
#
# 5. **Start the Export:**
#    - Confirm your selections and begin the export process by clicking on a button typically labeled 'Export', 'Download', or 'Save'.
#
# 6. **Download the File:**
#    - Once the export is complete, a download link or file will be generated. Save this to your local machine.
#
# **System Requirements:**
# - Ensure you have the necessary permissions to export data within your project management software.
# - Make sure your Excel version can handle large datasets if you are exporting large quantities of data (Excel 2016 or later is recommended).
#
# **Common Problems and Workarounds:**
# - If the export option is not visible, check user documentation for role-based permissions, or consult your system administrator to ensure appropriate rights.
# - If the exported file is too large, consider exporting data in smaller sets.
# - Should you encounter format compatibility issues, try exporting to .csv format and then import to Excel, which often resolves format alignment issues.
#
# **Escalation Path:**
# - If these steps do not resolve your issue, please contact the technical support team of your specific project management software. Provide details of the problem and any error messages you encounter for faster assistance.
