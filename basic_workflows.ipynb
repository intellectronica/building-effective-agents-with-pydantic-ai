# %%
# %pip install -r requirements.txt
from IPython.display import clear_output ; clear_output()

# %%
from util import initialize, show
AI_MODEL = initialize()

import asyncio
from typing import List, Dict

from pydantic import BaseModel, Field
from pydantic_ai import Agent
# Out:
# Available AI models:
# ['openai:gpt-4o',
#  'openai:gpt-4o-mini',
#  'gemini-1.5-pro',
#  'gemini-2.0-flash-exp',
#  'claude-3-5-haiku-latest',
#  'claude-3-5-sonnet-latest']
# Using AI model: openai:gpt-4o

# %% [markdown]
# ### Workflow: Prompt Chaining

# %%
async def chain(input: str, prompts: List[str]) -> str:
    """Chain multiple LLM calls sequentially, passing results between steps."""
    agent = Agent(AI_MODEL)
    result = input
    for i, prompt in enumerate(prompts, 1):
        agent = Agent(AI_MODEL, system_prompt=prompt)
        result = (await agent.run(f"nInput:\n{result}")).data
        show(result, title=f"Step {i}")
    return result

# %%
data_processing_steps = [
    """Extract only the numerical values and their associated metrics from the text.
    Format each as 'value: metric' on a new line.
    Example format:
    92: customer satisfaction
    45%: revenue growth""",
    
    """Convert all numerical values to percentages where possible.
    If not a percentage or points, convert to decimal (e.g., 92 points -> 92%).
    Keep one number per line.
    Example format:
    92%: customer satisfaction
    45%: revenue growth""",
    
    """Sort all lines in descending order by numerical value.
    Keep the format 'value: metric' on each line.
    Example:
    92%: customer satisfaction
    87%: employee satisfaction""",
    
    """Format the sorted data as a markdown table with columns:
    | Metric | Value |
    |:--|--:|
    | Customer Satisfaction | 92% |"""
]

report = """
Q3 Performance Summary:
Our customer satisfaction score rose to 92 points this quarter.
Revenue grew by 45% compared to last year.
Market share is now at 23% in our primary market.
Customer churn decreased to 5% from 8%.
New user acquisition cost is $43 per user.
Product adoption rate increased to 78%.
Employee satisfaction is at 87 points.
Operating margin improved to 34%.
""".strip()

show(report, title="Input text")
formatted_result = await chain(report, data_processing_steps)
show(formatted_result, title="Result")
# Out:
# Input text
# ----------
#
# Q3 Performance Summary:
# Our customer satisfaction score rose to 92 points this quarter.
# Revenue grew by 45% compared to last year.
# Market share is now at 23% in our primary market.
# Customer churn decreased to 5% from 8%.
# New user acquisition cost is $43 per user.
# Product adoption rate increased to 78%.
# Employee satisfaction is at 87 points.
# Operating margin improved to 34%.
#
#
# Step 1
# ------
#
# 92: customer satisfaction
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# $43: new user acquisition cost
# 78%: product adoption rate
# 87: employee satisfaction
# 34%: operating margin
#
#
# Step 2
# ------
#
# 92%: customer satisfaction
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# 78%: product adoption rate
# 87%: employee satisfaction
# 34%: operating margin
#
#
# Step 3
# ------
#
# 92%: customer satisfaction
# 87%: employee satisfaction
# 78%: product adoption rate
# 45%: revenue growth
# 34%: operating margin
# 23%: market share
# 5%: customer churn
#
#
# Step 4
# ------
#
# | Metric               | Value |
# |:---------------------|------:|
# | Customer Satisfaction | 92%   |
# | Employee Satisfaction | 87%   |
# | Product Adoption Rate | 78%   |
# | Revenue Growth        | 45%   |
# | Operating Margin      | 34%   |
# | Market Share          | 23%   |
# | Customer Churn        | 5%    |
#
#
# Result
# ------
#
# | Metric               | Value |
# |:---------------------|------:|
# | Customer Satisfaction | 92%   |
# | Employee Satisfaction | 87%   |
# | Product Adoption Rate | 78%   |
# | Revenue Growth        | 45%   |
# | Operating Margin      | 34%   |
# | Market Share          | 23%   |
# | Customer Churn        | 5%    |

# %% [markdown]
# ### Workflow: Routing

# %%
class RouteSelection(BaseModel):
    reasoning: str = Field(..., description=(
        'Brief explanation of why this ticket should be routed '
        'to a specific team. Consider key terms, user intent, '
        'and urgency level.'
    ))
    selection: str = Field(..., description='The chosen team name')


async def route(input: str, routes: Dict[str, str]) -> str:
    """Route input to specialized prompt using content classification."""

    # First, determine appropriate route using LLM with chain-of-thought
    show(f"{list(routes.keys())}", title="Available Routes")
    
    routing_agent = Agent(
        AI_MODEL,
        system_prompt=(
            'Analyze the input and select the most appropriate support team '
            f'from these options: {list(routes.keys())}'
        ),
        result_type=RouteSelection,
    )
    route_response = await routing_agent.run(input)
    reasoning = route_response.data.reasoning
    route_key = route_response.data.selection.strip().lower()
    
    show(reasoning, title="Routing Analysis")
    show(f"{route_key}", title="Selected Route")
    
    # Process input with selected specialized prompt
    worker_agent = Agent(AI_MODEL, system_prompt=routes[route_key])
    return (await worker_agent.run(input)).data

# %%
support_routes = {
    "billing": """You are a billing support specialist. Follow these guidelines:
    1. Always start with "Billing Support Response:"
    2. First acknowledge the specific billing issue
    3. Explain any charges or discrepancies clearly
    4. List concrete next steps with timeline
    5. End with payment options if relevant
    
    Keep responses professional but friendly.""",
    
    "technical": """You are a technical support engineer. Follow these guidelines:
    1. Always start with "Technical Support Response:"
    2. List exact steps to resolve the issue
    3. Include system requirements if relevant
    4. Provide workarounds for common problems
    5. End with escalation path if needed
    
    Use clear, numbered steps and technical details.""",
    
    "account": """You are an account security specialist. Follow these guidelines:
    1. Always start with "Account Support Response:"
    2. Prioritize account security and verification
    3. Provide clear steps for account recovery/changes
    4. Include security tips and warnings
    5. Set clear expectations for resolution time
    
    Maintain a serious, security-focused tone.""",
    
    "product": """You are a product specialist. Follow these guidelines:
    1. Always start with "Product Support Response:"
    2. Focus on feature education and best practices
    3. Include specific examples of usage
    4. Link to relevant documentation sections
    5. Suggest related features that might help
    
    Be educational and encouraging in tone."""
}

# Test with different support tickets
tickets = [
    """Subject: Can't access my account
    Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error. 
    I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to 
    submit a report by end of day.
    - John""",
    
    """Subject: Unexpected charge on my card
    Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
    I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
    Thanks,
    Sarah""",
    
    """Subject: How to export data?
    Message: I need to export all my project data to Excel. I've looked through the docs but can't
    figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
    Best regards,
    Mike"""
]

print("Processing support tickets...\n")
for i, ticket in enumerate(tickets, 1):
    show(ticket, title=f"Ticket {i}")
    response = await route(ticket, support_routes)
    show(response, title=f"Response {i}")
# Out:
# Processing support tickets...
#
#
# Ticket 1
# --------
#
# Subject: Can't access my account
#     Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error.
#     I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to
#     submit a report by end of day.
#     - John
#
#
# Available Routes
# ----------------
#
# ['billing', 'technical', 'account', 'product']
#
#
# Routing Analysis
# ----------------
#
# The user is having trouble logging into their account and suspects an issue with their password, even though they believe it is correct. This situation typically falls under the 'account' category, as it involves access and authentication issues related to a specific user. The urgency of the matter accentuates the necessity for immediate assistance with account recovery or password reset.
#
#
# Selected Route
# --------------
#
# account
#
#
# Response 1
# ----------
#
# Account Support Response:
#
# To ensure the security of your account, please follow the steps below to regain access:
#
# 1. **Password Reset**: Start by resetting your password through the 'Forgot Password?' link on the login page. Ensure you use a strong, unique password that you haven't used before.
#
# 2. **Email Verification**: After requesting a password reset, check your email for a verification link or code. Follow the instructions provided to complete the password reset process.
#
# 3. **Secure Your Devices**: Scan your devices for malware or viruses using reputable security software, as unauthorized access might be causing repeated login issues.
#
# 4. **Enable Two-Factor Authentication**: Once back in your account, activate two-factor authentication for added security, if not already in use.
#
# Resolution of Password Reset:
# - Typically, the password reset and account access should be resolved within a few minutes upon receiving the email. If you do not receive a password reset email within 15 minutes, check your spam or junk folder.
#
# Security Tips and Warnings:
# - Do not use the same password across multiple sites.
# - Be wary of phishing attempts asking for your login details.
# - Always verify the authenticity of the links you click, especially those claiming to be from our account recovery team.
#
# If further assistance is needed, or if you do not receive a password reset email, please contact our support team directly for verification of your identity. Expect additional verification steps to ensure your account's security, which may take up to 24 hours.
#
# Your urgency is understood, and we aim to resolve this issue promptly while maintaining the highest level of security for your account.
#
# Thank you for your patience and understanding.
#
#
# Ticket 2
# --------
#
# Subject: Unexpected charge on my card
#     Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
#     I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
#     Thanks,
#     Sarah
#
#
# Available Routes
# ----------------
#
# ['billing', 'technical', 'account', 'product']
#
#
# Routing Analysis
# ----------------
#
# The user's query is about an unexpected charge that appears to be related to billing. Sarah mentions a charge on her credit card and wants an explanation and possibly an adjustment, which falls under the scope of billing issues. Key terms include 'charge', 'credit card', and 'plan', indicating billing concerns.
#
#
# Selected Route
# --------------
#
# billing
#
#
# Response 2
# ----------
#
# Billing Support Response:
#
# Hello Sarah,
#
# Thank you for reaching out to us regarding the unexpected charge on your card. I understand your concern about being billed $49.99 instead of the expected $29.99.
#
# Upon reviewing your account, it appears that you were recently upgraded to the premium plan, which is priced at $49.99. This upgrade may have been selected as a promotional offer or during a recent plan change. If this upgrade was in error, we can certainly address this for you.
#
# To resolve this issue, we will:
# 1. Verify your selected plan and any recent changes made on your account within the next 24 hours.
# 2. If the upgrade was a mistake, we will process a refund of the $20 difference and adjust your plan back to the $29.99 tier.
#
# You will receive an email update on the status of this issue within 2 business days.
#
# For any payments, you can continue using your current stored credit card, or if necessary, update your payment method through your online account portal.
#
# Thank you for your patience as we work to resolve this matter.
#
# Best regards,
# The Billing Support Team
#
#
# Ticket 3
# --------
#
# Subject: How to export data?
#     Message: I need to export all my project data to Excel. I've looked through the docs but can't
#     figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
#     Best regards,
#     Mike
#
#
# Available Routes
# ----------------
#
# ['billing', 'technical', 'account', 'product']
#
#
# Routing Analysis
# ----------------
#
# The user's query is related to exporting data from a product to Excel, which is typically a technical issue. It involves using software functionality correctly, which falls under the scope of product technical support. Therefore, the technical support team is best suited to assist with this request.
#
#
# Selected Route
# --------------
#
# technical
#
#
# Response 3
# ----------
#
# Technical Support Response:
#
# To export your project data to Excel, follow these exact steps:
#
# 1. **Log In to Your Application:**
#    - Open your application and log in with your credentials.
#
# 2. **Navigate to the Project Data Section:**
#    - Locate the section within your application where your project data is stored. This might typically be under "Reports," "Data Management," or a similar heading.
#
# 3. **Select the Data for Export:**
#    - If there is an option to select specific projects, choose the projects you wish to export. If you want to export all data, look for a "Select All" option.
#
# 4. **Access the Export Function:**
#    - Look for an "Export" button or menu item. This is often represented as a CSV or Excel icon.
#    - Click on it to proceed.
#
# 5. **Choose Export Format:**
#    - When prompted, select "Excel" as the desired export format. Some systems may require you to choose between .xlsx or .xls, with .xlsx being the more modern and preferred format.
#
# 6. **Confirm Export Settings:**
#    - Verify any additional settings, such as including headers or defining date ranges, to ensure all your data is included in the export.
#
# 7. **Execute the Export:**
#    - Click on "Export" or "Download" to start the process. A file will be generated and downloaded to your default download location.
#
# ### System Requirements:
#
# - Ensure that your application supports exporting to Excel. Typically, this requires using an updated version of the software.
# - Your computer must have Excel or a compatible spreadsheet application to open .xlsx files.
#
# ### Common Problems and Workarounds:
#
# - **The Export Button is Not Visible:**
#   - Ensure you have the necessary permissions to export data. Contact your system administrator if permissions need adjusting.
#
# - **Export Fails or Timeouts:**
#   - Try exporting smaller batches if your datasets are large.
#   - Check your internet connection for stability.
#
# - **Data Does Not Appear as Expected:**
#   - Make sure you have selected the correct fields and applied any necessary filters.
#   - Check if there are updates or patches available for your application.
#
# ### Escalation Path:
#
# If the above steps do not resolve your issue or if you encounter technical errors during the process, please escalate the issue by contacting our support team at support@example.com or calling our helpline at 1-800-555-1234. Provide them with details of the error and your system information.
#
# Best regards,
# Technical Support Team

# %% [markdown]
# ### Workflow: Parallelization

# %%
async def parallel(prompt: str, inputs: List[str]) -> List[str]:
    """Process multiple inputs concurrently with the same prompt."""
    agent = Agent(AI_MODEL, system_prompt=prompt)
    results = await asyncio.gather(*[
        agent.run(input)
        for input in inputs
    ])
    return [result.data for result in results]

# %%
stakeholders = [
    """Customers:
    - Price sensitive
    - Want better tech
    - Environmental concerns""",
    
    """Employees:
    - Job security worries
    - Need new skills
    - Want clear direction""",
    
    """Investors:
    - Expect growth
    - Want cost control
    - Risk concerns""",
    
    """Suppliers:
    - Capacity constraints
    - Price pressures
    - Tech transitions"""
]

impact_results = await parallel(
    """Analyze how market changes will impact this stakeholder group.
    Provide specific impacts and recommended actions.
    Format with clear sections and priorities.""",
    stakeholders
)

for stakeholder, result in zip(stakeholders, impact_results):
    show(result, stakeholder.split(':')[0])
# Out:
# Customers
# ---------
#
# **Market Changes and Impact on Customers**
#
# 1. **Rising Material and Production Costs**
#    - **Impact:** Increased prices for end products, affecting price-sensitive customers.
#    - **Recommended Actions:**
#      - Focus on cost-effective sourcing and production strategies.
#      - Develop budget-friendly product lines to maintain appeal to price-sensitive customers.
#      - Implement promotional strategies like discounts or loyalty programs.
#
# 2. **Advancements in Technology**
#    - **Impact:** Customers demand cutting-edge technology in products.
#    - **Recommended Actions:**
#      - Invest in research and development to keep up with technological innovations.
#      - Collaborate with tech companies to integrate the latest tech upgrades.
#      - Launch regular updates or new models incorporating advanced technologies.
#
# 3. **Increased Focus on Environmental Sustainability**
#    - **Impact:** Heightened customer preference for eco-friendly products.
#    - **Recommended Actions:**
#      - Transition to sustainable materials and production processes.
#      - Obtain certifications for eco-friendly practices to build trust.
#      - Enhance marketing narratives to communicate green initiatives clearly.
#
# **Section 1: Price Sensitivity**
# - **Priority:** High
#   - Customers' purchasing decisions are significantly influenced by price changes.
#   - Immediate focus on keeping products affordable is crucial to retain this customer segment.
#
# **Section 2: Demand for Better Technology**
# - **Priority:** Medium
#   - Continuous improvement to meet technology expectations should be a strategic priority.
#   - Investments should be balanced with cost-containment strategies to prevent price hikes.
#
# **Section 3: Environmental Concerns**
# - **Priority:** High
#   - As environmental issues become more prominent, meeting this demand can differentiate a company from competitors.
#   - Long-term strategic focus on sustainability is necessary to align with consumer values and ensure brand loyalty.
#
# **Conclusion**
# For this stakeholder group of customers, prioritizing affordability, technology improvements, and sustainability will be key to maintaining market competitiveness and customer satisfaction. Implementing these recommended actions can help navigate the changing market landscape effectively.
#
#
# Employees
# ---------
#
# Market Changes Impacting Employees:
#
# 1. **Technological Advancements**
#    - **Impact**: Automation and artificial intelligence (AI) are transforming industries, potentially leading to the displacement of certain job roles and the creation of new ones. Employees may face job security concerns as technology could replace or alter traditional tasks.
#    - **Recommended Actions**:
#      - **Upskilling and Reskilling**: Implement comprehensive training programs to help employees gain skills in high-demand areas such as data analysis, cybersecurity, and AI operation.
#      - **Career Pathways**: Develop clear career progression tracks that incorporate these new skills to help employees envision their future within the company.
#      - **Communication Plan**: Regularly update employees on how technology will impact their specific roles and what support will be available for transition.
#
# 2. **Economic Fluctuations**
#    - **Impact**: Economic downturns or shifts in consumer demand may lead to budget constraints, restructuring, or layoffs. Employees will be concerned about job security and financial stability.
#    - **Recommended Actions**:
#      - **Transparent Communication**: Maintain open lines of communication about the company's financial health and the potential impact on employment.
#      - **Job Sharing Programs**: Consider implementing job-sharing schemes to retain talent during downturns while managing costs.
#      - **Financial Planning Support**: Offer workshops or resources to help employees manage personal finances in uncertain times.
#
# 3. **Regulatory Changes**
#    - **Impact**: New laws and regulations, particularly in areas like environmental standards or labor laws, can affect operational processes, job roles, and company priorities.
#    - **Recommended Actions**:
#      - **Informed Workforce**: Provide training sessions on new regulations that affect their roles and the overall impact on business operations.
#      - **Policy Adaptation**: Engage employees in discussions on adapting internal policies and procedures to comply with new regulations.
#      - **Feedback Mechanism**: Establish channels for employees to voice concerns or suggestions related to regulatory changes.
#
# 4. **Market Globalization**
#    - **Impact**: Global competition and opportunities may require employees to adapt to more culturally diverse environments and possibly new market dynamics.
#    - **Recommended Actions**:
#      - **Cultural Competency Training**: Offer training programs to help employees understand and effectively engage with global markets.
#      - **Role Flexibility**: Encourage lateral role moves to build well-rounded employees capable of adapting to various market demands.
#      - **International Exposure**: Create opportunities for employees to participate in international projects or exchanges to broaden their skills and perspectives.
#
# Priority Recommendations:
#
# 1. **Comprehensive Training and Upskilling**: Focus on equipping employees with skills aligned with technological and market trends to alleviate job security concerns and prepare them for future roles.
# 2. **Enhanced Communication**: Prioritize transparent and regular updates about market impacts and company strategies to build trust and provide clear direction.
# 3. **Supportive Mechanisms during Economic Changes**: Implement measures such as financial planning assistance and job-sharing programs to support employees during market fluctuations.
#
# By addressing these priorities, the company can foster a resilient workforce capable of navigating the evolving market landscape while boosting employee confidence and engagement.
#
#
# Investors
# ---------
#
# **Market Changes Impacting Investors**
#
# 1. **Technological Advancements**
#    - **Impact**: The rapid pace of technological innovations can lead to significant opportunities for growth in sectors such as artificial intelligence, renewable energy, and internet of things. Conversely, it can also render existing technologies obsolete, impacting companies heavily invested in such areas.
#    - **Recommended Action**: Investors should focus on diversifying their portfolios to include technology-driven companies with proven track records of innovation while monitoring for potential disruptions in established sectors.
#
# 2. **Economic Shifts**
#    - **Impact**: Economic changes such as inflation, interest rate fluctuations, and global economic slowdown can affect profitability margins and, consequently, shareholder returns. Cost control becomes crucial in these times to preserve profit margins.
#    - **Recommended Action**: Prioritize investments in companies that demonstrate strong cost control measures. Additionally, consider industries that are more resilient to economic downturns, such as essentials and utilities.
#
# 3. **Regulatory Changes**
#    - **Impact**: Changes in regulatory frameworks, particularly those related to environmental, social, and governance (ESG) criteria, can affect company operations, increase costs, and shift market dynamics.
#    - **Recommended Action**: Invest in organizations proactively adapting to regulatory standards, especially those that are focusing on sustainability and transparency in their operations. Engage with companies to understand their ESG policies and initiatives.
#
# 4. **Geopolitical Tensions**
#    - **Impact**: Increased geopolitical uncertainties can lead to market volatility and risk exposure, particularly in industries like energy and technology that are subject to international trade regulations.
#    - **Recommended Action**: Maintain a keen awareness of global political dynamics and assess the geographic diversity of portfolio holdings. Invest in multinational companies that have well-distributed operational bases to mitigate risks associated with geopolitical instability.
#
# 5. **Consumer Behavior Trends**
#    - **Impact**: Shifts in consumer behavior, especially post-pandemic, such as the acceleration of e-commerce and demand for digital services, necessitate adaptation in business models. Companies that fail to adjust may face declining growth prospects.
#    - **Recommended Action**: Identify and invest in companies that are leading or rapidly adapting to new consumer trends, particularly those embracing e-commerce and digital transformation strategies.
#
# **Priority Actions for Investors**
#
# 1. **Diversification and Innovation Focus**
#    - Diversify portfolios with a mix of emerging industries and technology innovators to capture growth potential while mitigating risks associated with technological obsolescence.
#
# 2. **Cost Efficiency Emphasis**
#    - Give precedence to investments in companies with established track records of cost control and fiscal discipline, especially in navigating economic uncertainties.
#
# 3. **Active Risk Management**
#    - Develop strategies for active risk management by investing in derivatives or defensive sectors to hedge against market volatility and geopolitical risks.
#
# 4. **Stakeholder Engagement**
#    - Actively engage with companies on ESG initiatives to ensure compliance with upcoming regulations and to minimize the potential impact of regulatory changes.
#
# By implementing these strategic actions, investors can better position themselves to capitalize on growth opportunities while effectively managing potential risks in a rapidly shifting market landscape.
#
#
# Suppliers
# ---------
#
# **Market Changes Impacting Suppliers**
#
# 1. **Capacity Constraints**
#
#    **Impacts:**
#    - Suppliers may struggle to meet the growing demand from clients due to limited production capabilities.
#    - Increased lead times and potential for backlog orders, resulting in potential loss of business and reputation damage.
#    - Greater strain on workforce, potentially leading to operational inefficiencies and increased overtime costs.
#
#    **Recommended Actions:**
#    - **Expand Capacity:** Invest in expanding production facilities or infrastructure to align with market demand.
#    - **Workforce Optimization:** Implement workforce training programs or hire additional staff to enhance production efficiency.
#    - **Supply Chain Diversification:** Collaborate with additional upstream suppliers to ensure a steady flow of raw materials.
#
# 2. **Price Pressures**
#
#    **Impacts:**
#    - Compressed profit margins as price competition intensifies and customers demand lower prices.
#    - Increased bargaining power for larger customers, potentially demanding more concessions.
#    - Difficulty in passing cost increases onto customers, impacting overall profitability.
#
#    **Recommended Actions:**
#    - **Cost Management:** Conduct thorough cost audits to identify and eliminate inefficiencies in operations.
#    - **Value Proposition Enhancement:** Differentiate products through quality improvements or added services to justify premium pricing.
#    - **Strategic Pricing:** Implement dynamic pricing models to respond rapidly to market changes and competitive pressures.
#
# 3. **Tech Transitions**
#
#    **Impacts:**
#    - Necessity to invest in new technologies to remain competitive, which may require significant capital expenditure.
#    - Potential disruption during the transition phase as teams adapt to new processes and systems.
#    - Challenges in integrating new technology with existing systems, potentially leading to operational interruptions.
#
#    **Recommended Actions:**
#    - **Invest in Innovation:** Prioritize R&D to stay ahead of technological advancements in the industry.
#    - **Partnerships and Alliances:** Collaborate with tech firms or industry partners to access cutting-edge technology and expertise.
#    - **Training Programs:** Implement comprehensive training for the workforce to maximize the benefits of new technological systems.
#
# **Prioritization of Actions:**
#
# 1. **Immediate Action:**
#    - Address capacity constraints by initiating workforce optimization and forming strategic supplier partnerships.
#    - Conduct an immediate cost management review to alleviate current price pressures.
#
# 2. **Medium-Term Focus:**
#    - Invest in capacity expansion to sustain long-term growth and adapt to market demands.
#    - Develop comprehensive training programs and partnerships to ease tech transitions.
#
# 3. **Long-Term Strategy:**
#    - Emphasize ongoing investment in innovation to maintain a competitive edge and anticipate future market shifts.
#    - Continuously refine pricing and value proposition strategies to mitigate economic fluctuations and maintain profitability.
