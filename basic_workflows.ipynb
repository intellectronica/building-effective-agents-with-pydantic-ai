# %%
# %pip install -r requirements.txt
from IPython.display import clear_output ; clear_output()

# %%
from util import initialize
AI_MODEL = initialize()

import asyncio
from typing import List, Dict
from pprint import pprint, pformat

from pydantic import BaseModel, Field
from pydantic_ai import Agent
# Out:
# Available AI models:
# ['openai:gpt-4o',
#  'openai:gpt-4o-mini',
#  'gemini-1.5-pro',
#  'gemini-2.0-flash-exp',
#  'claude-3-5-haiku-latest',
#  'claude-3-5-sonnet-latest']
# Using AI model: openai:gpt-4o

# %%
async def chain(input: str, prompts: List[str]) -> str:
    """Chain multiple LLM calls sequentially, passing results between steps."""
    agent = Agent(AI_MODEL)
    result = input
    for i, prompt in enumerate(prompts, 1):
        print(f"\nStep {i}:")
        result = (await agent.run(f"{prompt}\nInput: {result}")).data
        print(result)
    return result

# %%
data_processing_steps = [
    """Extract only the numerical values and their associated metrics from the text.
    Format each as 'value: metric' on a new line.
    Example format:
    92: customer satisfaction
    45%: revenue growth""",
    
    """Convert all numerical values to percentages where possible.
    If not a percentage or points, convert to decimal (e.g., 92 points -> 92%).
    Keep one number per line.
    Example format:
    92%: customer satisfaction
    45%: revenue growth""",
    
    """Sort all lines in descending order by numerical value.
    Keep the format 'value: metric' on each line.
    Example:
    92%: customer satisfaction
    87%: employee satisfaction""",
    
    """Format the sorted data as a markdown table with columns:
    | Metric | Value |
    |:--|--:|
    | Customer Satisfaction | 92% |"""
]

report = """
Q3 Performance Summary:
Our customer satisfaction score rose to 92 points this quarter.
Revenue grew by 45% compared to last year.
Market share is now at 23% in our primary market.
Customer churn decreased to 5% from 8%.
New user acquisition cost is $43 per user.
Product adoption rate increased to 78%.
Employee satisfaction is at 87 points.
Operating margin improved to 34%.
"""

print("\nInput text:")
print(report)
formatted_result = await chain(report, data_processing_steps)
print(formatted_result)
# Out:
# Input text:
#
# Q3 Performance Summary:
# Our customer satisfaction score rose to 92 points this quarter.
# Revenue grew by 45% compared to last year.
# Market share is now at 23% in our primary market.
# Customer churn decreased to 5% from 8%.
# New user acquisition cost is $43 per user.
# Product adoption rate increased to 78%.
# Employee satisfaction is at 87 points.
# Operating margin improved to 34%.
#
#
# Step 1:
# 92: customer satisfaction
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# 43: new user acquisition cost
# 78%: product adoption rate
# 87: employee satisfaction
# 34%: operating margin
#
# Step 2:
# 92%: customer satisfaction
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# 43%: new user acquisition cost
# 78%: product adoption rate
# 87%: employee satisfaction
# 34%: operating margin
#
# Step 3:
# Here is the list sorted in descending order by numerical value:
#
# ```
# 92%: customer satisfaction
# 87%: employee satisfaction
# 78%: product adoption rate
# 45%: revenue growth
# 43%: new user acquisition cost
# 34%: operating margin
# 23%: market share
# 5%: customer churn
# ```
#
# Step 4:
# Here is the data formatted as a markdown table:
#
# ```markdown
# | Metric                    | Value |
# |:--------------------------|------:|
# | Customer Satisfaction     |   92% |
# | Employee Satisfaction     |   87% |
# | Product Adoption Rate     |   78% |
# | Revenue Growth            |   45% |
# | New User Acquisition Cost |   43% |
# | Operating Margin          |   34% |
# | Market Share              |   23% |
# | Customer Churn            |    5% |
# ```
# Here is the data formatted as a markdown table:
#
# ```markdown
# | Metric                    | Value |
# |:--------------------------|------:|
# | Customer Satisfaction     |   92% |
# | Employee Satisfaction     |   87% |
# | Product Adoption Rate     |   78% |
# | Revenue Growth            |   45% |
# | New User Acquisition Cost |   43% |
# | Operating Margin          |   34% |
# | Market Share              |   23% |
# | Customer Churn            |    5% |
# ```

# %%
async def parallel(prompt: str, inputs: List[str]) -> List[str]:
    """Process multiple inputs concurrently with the same prompt."""
    agent = Agent(
        AI_MODEL,
        system_prompt=prompt,
    )
    results = await asyncio.gather(*[
        agent.run(input)
        for input in inputs
    ])
    return [result.data for result in results]

# %%
stakeholders = [
    """Customers:
    - Price sensitive
    - Want better tech
    - Environmental concerns""",
    
    """Employees:
    - Job security worries
    - Need new skills
    - Want clear direction""",
    
    """Investors:
    - Expect growth
    - Want cost control
    - Risk concerns""",
    
    """Suppliers:
    - Capacity constraints
    - Price pressures
    - Tech transitions"""
]

impact_results = await parallel(
    """Analyze how market changes will impact this stakeholder group.
    Provide specific impacts and recommended actions.
    Format with clear sections and priorities.""",
    stakeholders
)

for result in impact_results:
    print(result)
# Out:
# ### Introduction
# The market dynamics are constantly evolving, and the key changes such as rising technological advancements, environmental regulations, and fluctuating prices significantly impact customers. Customers today are increasingly price-sensitive, demand better tech, and are concerned about the environmental footprint of their purchases. This analysis will explore how these market changes will impact this stakeholder group and provide recommended actions to cater to their needs effectively.
#
# ### Impacts on Customers
#
# #### Price Sensitivity
# 1. **Rising Costs:** Fluctuations in supply chain costs, raw material prices, and inflation may lead to increased product prices. This can be a significant concern for price-sensitive customers who prioritize affordability.
# 2. **Discount and Loyalty Programs:** Price sensitivity drives customers towards brands that offer competitive pricing, discounts, and loyalty rewards.
#
# #### Demand for Better Tech
# 1. **Innovative Products:** Customers expect cutting-edge technology in products, driven by rapid technological advancements. Companies that fail to innovate may lose these customers to competitors who offer newer, more efficient products.
# 2. **Smart Features:** The demand for smart technology, such as IoT-enabled features and AI capabilities, is growing. Products lacking these features might be perceived as obsolete.
#
# #### Environmental Concerns
# 1. **Sustainable Practices:** Customers are increasingly aware of the environmental impact of their purchases. They prefer brands that practice sustainability, use eco-friendly materials, and reduce carbon footprints.
# 2. **Regulatory Compliance:** There is pressure on companies to comply with environmental regulations. This can influence the availability or modification of certain products.
#
# ### Recommended Actions
#
# #### Addressing Price Sensitivity
# 1. **Cost-Effective Solutions:** Focus on optimizing production and supply chain efficiencies to offer competitive pricing without compromising quality.
# 2. **Flexible Payment Plans:** Implement installment payment options or financing plans to make high-quality tech products more accessible to price-sensitive customers.
#
# #### Meeting the Demand for Better Technology
# 1. **Innovation and R&D:** Invest in research and development to produce innovative products that meet or exceed current tech standards, ensuring competitive differentiation.
# 2. **Regular Upgrades:** Launch regular product upgrades and updates that incorporate the latest technologies.
#
# #### Satisfying Environmental Concerns
# 1. **Eco-Friendly Products:** Develop and promote products with eco-friendly materials and sustainable production processes.
# 2. **Transparent Reporting:** Communicate sustainability efforts transparently through annual reports and marketing campaigns to build trust and loyalty.
#
# ### Priorities
#
# 1. **Sustainability Initiatives:** Given the increasing environmental concerns, priority should be given to implementing sustainable practices across the value chain.
# 2. **Innovation in Products:** Quickly follow evolving tech trends and continuously innovate to keep product offerings fresh and aligned with market expectations.
# 3. **Competitive Pricing Strategies:** Develop pricing strategies that maintain competitive edge while providing value to customers, ensuring retention of price-sensitive consumers.
#
# ### Conclusion
# Market changes will likely have a profound impact on this group of price-sensitive customers who demand better technology and have environmental concerns. By focusing on competitive pricing strategies, continuous innovation, and sustainability, businesses can not only mitigate these impacts but also leverage them as opportunities for growth and customer loyalty.
# ### Impact of Market Changes on Employees
#
# #### 1. Job Security Worries
#
# **Impact:**
# - Economic shifts and technological advancements can lead to operational restructuring or even downsizing to maintain competitiveness.
# - Employees may face increased anxiety regarding their job stability, potentially affecting morale and productivity.
#
# **Recommended Actions:**
# - **Transparent Communication:** Regularly update employees about market trends, company performance, and how these factors might influence job security.
# - **Job Security Programs:** Implement measures such as job-sharing, reduced hours, or voluntary leave options to manage staffing without layoffs.
# - **Employee Support Services:** Enhance support programs, such as counseling or financial planning workshops, to assist employees during uncertain times.
#
# **Priority:** High. Addressing job security is crucial to maintaining employee trust and productivity.
#
# #### 2. Need for New Skills
#
# **Impact:**
# - As market demands evolve, employees may find their current skill sets less relevant, necessitating retraining or upskilling.
# - The introduction of new technologies or business models can widen the skills gap if not proactively managed.
#
# **Recommended Actions:**
# - **Training Programs:** Develop comprehensive training and development programs focused on in-demand skills and emerging technologies.
# - **Upskilling Incentives:** Provide incentives, such as certifications or bonuses, to encourage employees to pursue skill development.
# - **Role Adaptability:** Encourage cross-functional roles and flexible job descriptions that allow employees to develop a diverse set of skills.
#
# **Priority:** Medium. While immediate actions may not be necessary, proactive skill development is essential for long-term success and competitiveness.
#
# #### 3. Desire for Clear Direction
#
# **Impact:**
# - Employees are likely to feel uncertain and disengaged if the company's vision and business strategy are not clearly communicated.
# - A lack of direction can hinder teamwork and alignment with organizational goals.
#
# **Recommended Actions:**
# - **Vision Communication:** Regularly communicate the company's strategic vision, objectives, and how market changes are being addressed.
# - **Feedback Mechanisms:** Establish channels for employees to provide feedback and suggestions on strategic initiatives.
# - **Leadership Alignment:** Ensure that all levels of management are aligned with and actively communicate the strategic vision to their teams.
#
# **Priority:** High. Clear direction is critical to employee engagement and organizational alignment.
#
# ### Summary of Priorities
#
# 1. **Job Security Worries (High Priority):** Immediate actions needed to maintain trust and productivity.
# 2. **Desire for Clear Direction (High Priority):** Ongoing communication and alignment are essential for engagement and strategic effectiveness.
# 3. **Need for New Skills (Medium Priority):** Implement proactive measures to facilitate long-term employee development and adaptability.
#
# By addressing these priority areas effectively, organizations can mitigate the negative impacts of market changes on employees, fostering a resilient and agile workforce.
# ### Analysis of Market Changes and Their Impact on Investors
#
# #### 1. Market Trends and Expectations
# - **Potential Interest Rate Changes:** As central banks adjust interest rates in response to economic conditions, the cost of borrowing could rise. This impacts corporate earnings as companies may face higher financing costs.
# - **Inflationary Pressures:** Persistent inflation may erode profit margins, prompting investors to be cautious about growth projections.
# - **Technological Advancements:** Rapid technological changes provide opportunities for growth but can also result in obsolete investments.
# - **Geopolitical Tensions:** Ongoing geopolitical instability may increase market volatility, affecting investor sentiment and risk assessments.
#
# #### 2. Specific Impacts on Investors
#
# ##### a. **Growth Expectations**
# - **Impact:** Higher operational costs and interest expenses could squeeze profit margins, potentially slowing down company growth.
# - **Recommended Action:** Investors should diversify their portfolios into sectors with robust growth potential under current economic conditions, such as technology and green energy.
#
# ##### b. **Cost Control**
# - **Impact:** Persistent inflation continues to pressure operational costs, making cost control a priority for businesses.
# - **Recommended Action:** Evaluate investment opportunities in companies with a strong track record of cost management and operational efficiency. Encourage businesses to adopt innovative solutions to improve efficiency.
#
# ##### c. **Risk Concerns**
# - **Impact:** Market volatility driven by geopolitical issues and economic dilemmas increases investment risk.
# - **Recommended Action:** Investors should consider hedging strategies and increased investment in stable, recession-resistant sectors like healthcare and consumer staples.
#
# #### 3. Priority Actions for Investors
#
# ##### Priority 1: Portfolio Diversification
# - **Strategy:** Leverage diversification to mitigate risks. Balance investments between high-growth sectors and stable, dividend-yielding stocks to optimize risk-reward profiles.
#
# ##### Priority 2: Focus on Cost Management
# - **Strategy:** Prioritize investments in companies that demonstrate strong cost management amidst inflation. Focus on businesses implementing automation and sustainable resource management practices.
#
# ##### Priority 3: Risk Management and Assessment
# - **Strategy:** Conduct thorough risk assessments of current geopolitical climates and interest rates impacts. Use financial instruments like options or bonds to hedge against market volatility.
#
# ##### Priority 4: Stay Informed on Technological Trends
# - **Strategy:** Keep abreast of technological advancements and disruptions. Invest in innovation leaders that utilize new technologies like artificial intelligence to disrupt traditional industries positively.
#
# ##### Priority 5: Engagement with Investee Companies
# - **Strategy:** Actively engage with companies to ensure transparency and adaptability to market changes. Encourage strategic planning for uncertain market scenarios.
#
# #### Conclusion
# Investors should be vigilant of the changing market dynamics and adopt a strategic approach to navigate growth concerns, cost pressures, and heightened risks. By diversifying investments, focusing on efficient operations, and hedging against volatility, investors can better protect and potentially grow their portfolios. Keeping informed and engaged will provide the agility needed to adapt to rapid market changes.
# ### Analysis of Market Changes Impacting Suppliers
#
# Suppliers are facing significant market changes that can have considerable impacts on their operations and strategic decision-making. The primary issues to consider are capacity constraints, price pressures, and tech transitions. Here's a detailed analysis of these changes and recommended actions suppliers should take:
#
# ---
#
# ### 1. Capacity Constraints
#
# #### Impact:
# - **Supply Chain Bottlenecks**: Capacity constraints can lead to delays in fulfilling orders, causing bottlenecks in the supply chain. This can damage supplier reputation and erode customer trust.
# - **Limited Growth Potential**: Inability to scale operations efficiently limits opportunities for market expansion and revenue growth.
# - **Increased Operational Costs**: Need for overtime labor, expedited shipping, or investment in additional resources can increase operational costs.
#
# #### Recommended Actions:
# - **Invest in Capacity Expansion**: Evaluate opportunities to invest in new facilities or upgrade existing ones to increase capacity. This might include automation or reconfiguring layouts for efficiency.
# - **Strengthen Supplier Relationships**: Build strong partnerships with alternative suppliers to provide flexibility and buffers against capacity limits.
# - **Demand Forecasting**: Implement advanced demand forecasting tools to better anticipate market needs and adjust production schedules accordingly.
#
# ---
#
# ### 2. Price Pressures
#
# #### Impact:
# - **Reduced Profit Margins**: Increased competition and customer demands for lower prices can squeeze profit margins.
# - **Higher Cost of Raw Materials**: Fluctuating prices for raw materials can increase production costs unpredictably.
# - **Increased Competition**: Price pressures may intensify competition as companies vie for market share by offering lower prices.
#
# #### Recommended Actions:
# - **Cost Optimization**: Conduct a thorough review of production processes to find efficiencies and reduce waste. Consider lean manufacturing practices.
# - **Diversification of Offerings**: Expand product lines to include higher-margin products or services to balance lower-margin offerings.
# - **Renegotiate Contracts**: Engage in proactive negotiations with customers and suppliers to lock in favorable pricing agreements and terms.
#
# ---
#
# ### 3. Tech Transitions
#
# #### Impact:
# - **Innovation Gaps**: Suppliers failing to adopt new technologies may find themselves lagging behind competitors that leverage advanced technologies for efficiency and quality improvements.
# - **Training and Development Needs**: The workforce may require extensive training to effectively utilize new technologies, leading to short-term disruptions.
# - **Initial Investment Costs**: Significant upfront investments in technology can strain financial resources, especially for smaller suppliers.
#
# #### Recommended Actions:
# - **Invest in R&D**: Allocate resources for research and development to stay ahead of technological advancements and integrate them into processes effectively.
# - **Partnerships with Tech Firms**: Collaborate with technology companies to gain access to cutting-edge innovations and expertise.
# - **Upskilling Workforce**: Initiate training programs to equip employees with skills necessary for operating new technologies and enhance overall productivity.
#
# ---
#
# ### Prioritization of Actions
#
# 1. **Immediate Focus**: Address capacity constraints by investing in capacity expansion and strengthening supplier relationships to prevent operational bottlenecks.
#
# 2. **Short-Term Initiatives**: Implement cost optimization strategies to alleviate price pressures, while also renegotiating contracts to secure better pricing structures.
#
# 3. **Long-Term Strategy**: Invest in research and development for tech transitions, partnering with tech firms for gradual integration, and begin workforce upskilling to equip employees for future challenges.
#
# By prioritizing these actions, suppliers can better navigate the evolving market landscape and safeguard their operational and financial stability.

# %%
async def route(input: str, routes: Dict[str, str]) -> str:
    """Route input to specialized prompt using content classification."""
    # First determine appropriate route using LLM with chain-of-thought
    print(f"\nAvailable routes: {list(routes.keys())}")

    class RouteSelection(BaseModel):
        reasoning: str = Field(..., description=(
            'Brief explanation of why this ticket should be routed to a specific team. '
            'Consider key terms, user intent, and urgency level.'
        ))
        selection: str = Field(..., description='The chosen team name')
    
    route_response = await Agent(
        AI_MODEL,
        system_prompt=(
            'Analyze the input and select the most appropriate support team from these options: '
            f'{list(routes.keys())}'
        ),
        result_type=RouteSelection,
    ).run(input)
    reasoning = route_response.data.reasoning
    route_key = route_response.data.selection.strip().lower()
    
    print("Routing Analysis:")
    print(reasoning)
    print(f"\nSelected route: {route_key}")
    
    # Process input with selected specialized prompt
    return (await Agent(
        AI_MODEL,
        system_prompt=routes[route_key],
    ).run(input)).data

# %%
support_routes = {
    "billing": """You are a billing support specialist. Follow these guidelines:
    1. Always start with "Billing Support Response:"
    2. First acknowledge the specific billing issue
    3. Explain any charges or discrepancies clearly
    4. List concrete next steps with timeline
    5. End with payment options if relevant
    
    Keep responses professional but friendly.
    
    Input: """,
    
    "technical": """You are a technical support engineer. Follow these guidelines:
    1. Always start with "Technical Support Response:"
    2. List exact steps to resolve the issue
    3. Include system requirements if relevant
    4. Provide workarounds for common problems
    5. End with escalation path if needed
    
    Use clear, numbered steps and technical details.
    
    Input: """,
    
    "account": """You are an account security specialist. Follow these guidelines:
    1. Always start with "Account Support Response:"
    2. Prioritize account security and verification
    3. Provide clear steps for account recovery/changes
    4. Include security tips and warnings
    5. Set clear expectations for resolution time
    
    Maintain a serious, security-focused tone.
    
    Input: """,
    
    "product": """You are a product specialist. Follow these guidelines:
    1. Always start with "Product Support Response:"
    2. Focus on feature education and best practices
    3. Include specific examples of usage
    4. Link to relevant documentation sections
    5. Suggest related features that might help
    
    Be educational and encouraging in tone.
    
    Input: """
}

# Test with different support tickets
tickets = [
    """Subject: Can't access my account
    Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error. 
    I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to 
    submit a report by end of day.
    - John""",
    
    """Subject: Unexpected charge on my card
    Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
    I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
    Thanks,
    Sarah""",
    
    """Subject: How to export data?
    Message: I need to export all my project data to Excel. I've looked through the docs but can't
    figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
    Best regards,
    Mike"""
]

print("Processing support tickets...\n")
for i, ticket in enumerate(tickets, 1):
    print(f"\nTicket {i}:")
    print("-" * 40)
    print(ticket)
    print("\nResponse:")
    print("-" * 40)
    response = await route(ticket, support_routes)
    print(response)
# Out:
# Processing support tickets...
#
#
# Ticket 1:
# ----------------------------------------
# Subject: Can't access my account
#     Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error.
#     I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to
#     submit a report by end of day.
#     - John
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
# The user is facing an issue with logging into their account and mentions receiving an 'invalid password' error. This indicates a problem with account access credentials or account status. The urgency of needing to submit a report by end of day makes this a high-priority issue, needing prompt attention. Hence, this issue is best handled by the 'account' support team, which deals with login and account access problems.
#
# Selected route: account
# Account Support Response:
#
# Dear John,
#
# Thank you for reaching out regarding your account access issue. We understand the urgency and will assist you in regaining access securely.
#
# 1. **Password Reset**: To begin the recovery process, please initiate a password reset. Visit the login page, click on "Forgot Password," and follow the prompts. Ensure you have access to the email or phone number associated with your account.
#
# 2. **Check Email**: After requesting a password reset, check your email inbox (including spam/junk folders) for a password reset link. This link is usually sent within 10-15 minutes.
#
# 3. **Secure Connection**: When resetting your password, ensure you are on a trusted device and secure network to avoid unauthorized interception of your credentials.
#
# 4. **Strong Password**: Choose a new password that is strong and unique: a mix of uppercase and lowercase letters, numbers, and symbols. Avoid reusing previous passwords or common phrases.
#
# 5. **Two-Factor Authentication (2FA)**: If not already enabled, consider activating 2FA once access is restored. This provides an additional layer of security by requiring a second form of verification upon login.
#
# 6. **Contact Support**: If you're still unable to access your account after the password reset, please contact our support team directly through our secure help portal. Be prepared to verify your identity for further assistance.
#
# The typical resolution time is within 24 hours. However, initiating the password reset is often the quickest step to regain access.
#
# Security Tip: Be cautious of phishing attempts. Our team will never ask you for your password or personal information via email or phone.
#
# We hope these steps assist you promptly. Thank you for your patience and understanding.
#
# Best regards,
# Account Security Team
#
# Ticket 2:
# ----------------------------------------
# Subject: Unexpected charge on my card
#     Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
#     I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
#     Thanks,
#     Sarah
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
# The customer, Sarah, is inquiring about an unexpected charge on her credit card and believes she was charged more than her subscribed plan. This issue is related to billing and payment, which falls under the purview of the billing support team. They are the most appropriate team to handle and clarify issues regarding charges, plan discrepancies, and adjustments.
#
# Selected route: billing
# Billing Support Response:
#
# Hello Sarah,
#
# Thank you for reaching out to us regarding the unexpected charge on your credit card. Let's look into this billing discrepancy for you.
#
# The charge of $49.99 on your account may be due to an upgrade or a recent promotion ending that you might not have intentionally subscribed to. Our records show that the $29.99 plan was the previous option, but if any changes were made or additional features added, this could result in the increased billing amount.
#
# Here's what we can do next:
#
# 1. I will review your account details and plan history to verify any changes or upgrades. This will take approximately 1-2 business days.
# 2. If it turns out to be an error, we will process a credit adjustment of $20 to your account, so you are billed correctly for the $29.99 plan.
# 3. I will send you a confirmation email once this is resolved or if we need any additional information from you.
#
# To ensure no future discrepancies, please review your chosen plan from your account settings. You have the option to revert back to the $29.99 plan if an upgrade is detected.
#
# For payment, if there’s any adjustment needed, the revised amount will be reflected in your next billing cycle either as a deduction or a refund, depending on your payment method.
#
# Thank you for your patience as we resolve this issue. Please don't hesitate to reach out if you have further questions.
#
# Best regards,
#
# Billing Support Team
#
# Ticket 3:
# ----------------------------------------
# Subject: How to export data?
#     Message: I need to export all my project data to Excel. I've looked through the docs but can't
#     figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
#     Best regards,
#     Mike
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
# The user is inquiring about exporting project data to Excel, which indicates a technical issue related to product functionality. This type of question is best addressed by the technical support team, as it involves providing guidance on features and functions within the software.
#
# Selected route: technical
# Technical Support Response:
#
# To export your project data to Excel, please follow these steps:
#
# 1. **Access Project Data:**
#    - Log into the application where your project data is stored.
#    - Navigate to the "Projects" section from the main menu.
#
# 2. **Select Data for Export:**
#    - Locate the specific project or projects whose data you want to export.
#    - Ensure you have the necessary permissions to export data. If permissions are needed, contact your system administrator.
#
# 3. **Initiate Export Process:**
#    - Find and click on the "Export" button or option. This is typically located in the toolbar above your data list or under the "More options" menu (often represented with three dots or a gear icon).
#
# 4. **Choose Export Format:**
#    - When prompted, select "Excel" as the desired export format.
#    - Some systems may give you an option to select additional fields to include, or to filter which data exactly you want to export. Make sure to review these settings to include all necessary details.
#
# 5. **Adjust Export Settings:**
#    - If applicable, configure any additional settings such as the date range or data filters.
#    - Confirm your selections and click on "Continue" or "Export".
#
# 6. **Download the Export File:**
#    - Once the export is complete, a download link or pop-up will appear.
#    - Click the link to download your file. It should have a ".xlsx" extension.
#
# **System Requirements:**
# - Ensure your web browser is up-to-date for compatibility with your application.
# - Excel or any software capable of opening .xlsx files should be installed on your computer.
#
# **Common Problems and Workarounds:**
# - If you do not see the export option, ensure your user role has the correct permissions.
# - If the export button is unresponsive, clear your browser cache or try a different browser.
# - Some systems might limit the amount of data exported per operation. If you hit a data limit, try exporting in batches.
#
# **Escalation Path:**
# - If the issue persists or you encounter an error during the export process, please contact your IT department or the technical support team of the application provider for further assistance. Provide them with the steps you've taken and any error messages received for quicker resolution.
#
# Feel free to reach out if you need additional help!
