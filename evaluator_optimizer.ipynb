# %%
# %pip install pydantic-ai python-dotenv nest_asyncio
from IPython.display import clear_output ; clear_output()

from dotenv import load_dotenv ; load_dotenv(override=True)
import nest_asyncio ; nest_asyncio.apply()

import os
import random
from pprint import pprint
from typing import List, Dict
from pprint import pprint, pformat

from pydantic import BaseModel, Field
from pydantic_ai import Agent

_ai_models = (
    [] + 
    (['openai:gpt-4o', 'openai:gpt-4o-mini'] if os.environ.get('OPENAI_API_KEY') else []) +
    (['gemini-1.5-pro', 'gemini-2.0-flash-exp'] if os.environ.get('GEMINI_API_KEY') else []) +
    (['claude-3-5-haiku-latest', 'claude-3-5-sonnet-latest'] if os.environ.get('ANTHROPIC_API_KEY') else [])
)
print(f"Available AI models: {pformat(_ai_models)}\n")

AI_MODEL = os.environ['AI_MODEL'] if os.environ.get('AI_MODEL') else random.choice(_ai_models)
print(f"Using AI model: {AI_MODEL}")
# Out:
# Available AI models: ['openai:gpt-4o',
#  'openai:gpt-4o-mini',
#  'gemini-1.5-pro',
#  'gemini-2.0-flash-exp',
#  'claude-3-5-haiku-latest',
#  'claude-3-5-sonnet-latest']
#
# Using AI model: claude-3-5-sonnet-latest

# %%
class GeneratorResponse(BaseModel):
    thoughts: str = Field(..., description='Your understanding of the task and feedback and how you plan to improve')
    response: str = Field(..., description="The generated solution.")


async def generate(prompt: str, task: str, context: str = "") -> tuple[str, str]:
    """Generate and improve a solution based on feedback."""
    full_prompt = f"{prompt}\n{context}\nTask: {task}" if context else f"{prompt}\nTask: {task}"
    response = (await Agent(AI_MODEL, result_type=GeneratorResponse).run(full_prompt)).data
    thoughts = response.thoughts
    result = response.response
    
    print("\n=== GENERATION START ===")
    print(f"Thoughts:\n{thoughts}\n")
    print(f"Generated:\n{result}")
    print("=== GENERATION END ===\n")
    
    return thoughts, result


class EvaluatorResponse(BaseModel):
    evaluation: str = Field(..., description='PASS, NEEDS_IMPROVEMENT, or FAIL')
    feedback: str = Field(..., description='What needs improvement and why.')


async def evaluate(prompt: str, content: str, task: str) -> tuple[str, str]:
    """Evaluate if a solution meets requirements."""
    full_prompt = f"{prompt}\nOriginal task: {task}\nContent to evaluate: {content}"
    response = (await Agent(AI_MODEL, result_type=EvaluatorResponse).run(full_prompt)).data
    evaluation = response.evaluation
    feedback = response.feedback
    
    print("=== EVALUATION START ===")
    print(f"Status: {evaluation}")
    print(f"Feedback: {feedback}")
    print("=== EVALUATION END ===\n")
    
    return evaluation, feedback


async def loop(task: str, evaluator_prompt: str, generator_prompt: str) -> tuple[str, list[dict]]:
    """Keep generating and evaluating until requirements are met."""
    memory = []
    chain_of_thought = []
    
    thoughts, result = await generate(generator_prompt, task)
    memory.append(result)
    chain_of_thought.append({"thoughts": thoughts, "result": result})
    
    while True:
        evaluation, feedback = await evaluate(evaluator_prompt, result, task)
        if evaluation == "PASS":
            return result, chain_of_thought
            
        context = "\n".join([
            "Previous attempts:",
            *[f"- {m}" for m in memory],
            f"\nFeedback: {feedback}"
        ])
        
        thoughts, result = await generate(generator_prompt, task, context)
        memory.append(result)
        chain_of_thought.append({"thoughts": thoughts, "result": result})

# %%
evaluator_prompt = """
Evaluate this following code implementation for:
1. code correctness
2. time complexity
3. style and best practices

You should be evaluating only and not attemping to solve the task.
Only output "PASS" if all criteria are met and you have no further suggestions for improvements."""

generator_prompt = """
Your goal is to complete the task based on <user input>. If there are feedback 
from your previous generations, you should reflect on them to improve your solution."""

task = """
<user input>
Implement a Stack with:
1. push(x)
2. pop()
3. getMin()
All operations should be O(1).
</user input>
"""

result, chain_of_thought = await loop(task, evaluator_prompt, generator_prompt)

print("=== FINAL RESULT ===")
print(result)

print("\n=== CHAIN OF THOUGHT ===")
pprint(chain_of_thought)
# Out:
# === GENERATION START ===
# Thoughts:
# For this task, I need to implement a Stack data structure with push, pop, and getMin operations, all with O(1) time complexity. The challenging part is maintaining the minimum value in O(1) time.
#
# To achieve O(1) for all operations including getMin():
# 1. We'll use two stacks:
#    - main_stack: stores all elements
#    - min_stack: keeps track of minimums
# 2. The min_stack will store elements in a way that its top always has the current minimum
# 3. Push: When pushing, we'll compare with min_stack's top and push to min_stack if needed
# 4. Pop: When popping, we'll also pop from min_stack if the popped value equals min_stack's top
# 5. GetMin: Simply return min_stack's top
#
# This approach ensures all operations remain O(1) while correctly maintaining the minimum value.
#
# Generated:
# class MinStack:
#     def __init__(self):
#         self.main_stack = []  # Main stack to store all elements
#         self.min_stack = []   # Stack to track minimums
#
#     def push(self, x: int) -> None:
#         self.main_stack.append(x)
#
#         # If min_stack is empty or x is smaller/equal to current min,
#         # add to min_stack
#         if not self.min_stack or x <= self.min_stack[-1]:
#             self.min_stack.append(x)
#
#     def pop(self) -> None:
#         if not self.main_stack:
#             return
#
#         # If popped element is the current minimum,
#         # remove it from min_stack too
#         if self.main_stack[-1] == self.min_stack[-1]:
#             self.min_stack.pop()
#
#         self.main_stack.pop()
#
#     def getMin(self) -> int:
#         if not self.min_stack:
#             return None
#         return self.min_stack[-1]
#
# # Example usage:
# # stack = MinStack()
# # stack.push(3)
# # stack.push(2)
# # stack.push(5)
# # print(stack.getMin())  # Output: 2
# # stack.pop()
# # stack.pop()
# # print(stack.getMin())  # Output: 3
# === GENERATION END ===
#
# === EVALUATION START ===
# Status: NEEDS_IMPROVEMENT
# Feedback: The implementation has several areas that could be improved:
#
# 1. Code Correctness:
# - The solution is mostly correct but has some edge cases that aren't properly handled:
#   - pop() should handle empty stack case by raising an exception rather than silently returning
#   - getMin() returns None for empty stack, but should raise an exception to be consistent with standard stack behavior
#
# 2. Time Complexity:
# - The implementation correctly achieves O(1) for all operations as required
# - Space complexity is O(n) which is optimal for this problem
#
# 3. Style and Best Practices:
# - Missing type hints for self.main_stack and self.min_stack in __init__
# - Missing docstrings for class and methods
# - Missing proper error handling for edge cases
# - The pop() operation could be more concise by combining the checks
# - Comments are good but could be more professional/descriptive
# - Example usage should be removed from implementation or moved to a separate test file
#
# Recommendations:
# - Add proper exception handling
# - Add complete type hints
# - Add docstrings
# - Consider adding validity checks for input values
# - Consider adding helper methods for common checks
# - Consider adding a top() or peek() method for completeness
# === EVALUATION END ===
#
#
# === GENERATION START ===
# Thoughts:
# Based on the feedback, I'll improve the solution by:
# 1. Adding proper exception handling with custom error messages
# 2. Adding complete type hints including List[int] for stacks
# 3. Adding comprehensive docstrings for class and methods
# 4. Making code more professional with better error handling
# 5. Adding a top() method for completeness
# 6. Making pop() implementation more concise
#
# The core logic is working correctly with O(1) time complexity for all operations. The main improvements are around code quality, documentation, and robustness.
#
# Generated:
# from typing import List, Optional
#
# class MinStack:
#     """A stack data structure that supports constant time push, pop, and minimum element retrieval.
#
#     This implementation maintains two internal stacks:
#     - A main stack for all elements
#     - A minimum stack that keeps track of minimums at each state
#
#     All operations (push, pop, getMin) are guaranteed to run in O(1) time complexity.
#     """
#
#     def __init__(self) -> None:
#         """Initialize an empty MinStack."""
#         self.main_stack: List[int] = []  # Stores all elements
#         self.min_stack: List[int] = []   # Tracks minimum elements
#
#     def push(self, x: int) -> None:
#         """Push an element onto the stack.
#
#         Args:
#             x: The integer to be pushed onto the stack
#         """
#         self.main_stack.append(x)
#         # Update min_stack if empty or x is not greater than current minimum
#         if not self.min_stack or x <= self.min_stack[-1]:
#             self.min_stack.append(x)
#
#     def pop(self) -> None:
#         """Remove the top element from the stack.
#
#         Raises:
#             IndexError: If the stack is empty
#         """
#         if not self.main_stack:
#             raise IndexError("pop from empty stack")
#
#         # If top element is current minimum, update min_stack
#         if self.main_stack[-1] == self.min_stack[-1]:
#             self.min_stack.pop()
#         self.main_stack.pop()
#
#     def top(self) -> int:
#         """Return the top element without removing it.
#
#         Returns:
#             The top element of the stack
#
#         Raises:
#             IndexError: If the stack is empty
#         """
#         if not self.main_stack:
#             raise IndexError("top from empty stack")
#         return self.main_stack[-1]
#
#     def getMin(self) -> int:
#         """Return the minimum element in the stack.
#
#         Returns:
#             The minimum element in the stack
#
#         Raises:
#             IndexError: If the stack is empty
#         """
#         if not self.min_stack:
#             raise IndexError("getMin from empty stack")
#         return self.min_stack[-1]
# === GENERATION END ===
#
# === EVALUATION START ===
# Status: PASS
# Feedback: The implementation meets all criteria perfectly:
#
# 1. Code Correctness:
# - Correctly implements all required operations: push(), pop(), and getMin()
# - Properly maintains two stacks to track both elements and minimums
# - Handles edge cases appropriately with proper error handling
# - Implementation is bug-free and logically sound
#
# 2. Time Complexity:
# - All operations (push, pop, getMin) are O(1) as required
# - Space complexity is O(n), which is optimal for this problem
# - The auxiliary min_stack's space usage is optimized by only pushing new minimums
#
# 3. Style and Best Practices:
# - Excellent documentation with clear docstrings following standard format
# - Proper type hints used throughout
# - Clear variable naming that reflects purpose
# - Good error handling with appropriate exceptions
# - Clean code organization and consistent formatting
# - Clear comments explaining the logic
# - Good separation of concerns between operations
#
# The implementation is exemplary with no improvements needed.
# === EVALUATION END ===
#
# === FINAL RESULT ===
# from typing import List, Optional
#
# class MinStack:
#     """A stack data structure that supports constant time push, pop, and minimum element retrieval.
#
#     This implementation maintains two internal stacks:
#     - A main stack for all elements
#     - A minimum stack that keeps track of minimums at each state
#
#     All operations (push, pop, getMin) are guaranteed to run in O(1) time complexity.
#     """
#
#     def __init__(self) -> None:
#         """Initialize an empty MinStack."""
#         self.main_stack: List[int] = []  # Stores all elements
#         self.min_stack: List[int] = []   # Tracks minimum elements
#
#     def push(self, x: int) -> None:
#         """Push an element onto the stack.
#
#         Args:
#             x: The integer to be pushed onto the stack
#         """
#         self.main_stack.append(x)
#         # Update min_stack if empty or x is not greater than current minimum
#         if not self.min_stack or x <= self.min_stack[-1]:
#             self.min_stack.append(x)
#
#     def pop(self) -> None:
#         """Remove the top element from the stack.
#
#         Raises:
#             IndexError: If the stack is empty
#         """
#         if not self.main_stack:
#             raise IndexError("pop from empty stack")
#
#         # If top element is current minimum, update min_stack
#         if self.main_stack[-1] == self.min_stack[-1]:
#             self.min_stack.pop()
#         self.main_stack.pop()
#
#     def top(self) -> int:
#         """Return the top element without removing it.
#
#         Returns:
#             The top element of the stack
#
#         Raises:
#             IndexError: If the stack is empty
#         """
#         if not self.main_stack:
#             raise IndexError("top from empty stack")
#         return self.main_stack[-1]
#
#     def getMin(self) -> int:
#         """Return the minimum element in the stack.
#
#         Returns:
#             The minimum element in the stack
#
#         Raises:
#             IndexError: If the stack is empty
#         """
#         if not self.min_stack:
#             raise IndexError("getMin from empty stack")
#         return self.min_stack[-1]
#
# === CHAIN OF THOUGHT ===
# [{'result': 'class MinStack:\n'
#             '    def __init__(self):\n'
#             '        self.main_stack = []  # Main stack to store all elements\n'
#             '        self.min_stack = []   # Stack to track minimums\n'
#             '\n'
#             '    def push(self, x: int) -> None:\n'
#             '        self.main_stack.append(x)\n'
#             '        \n'
#             '        # If min_stack is empty or x is smaller/equal to current '
#             'min,\n'
#             '        # add to min_stack\n'
#             '        if not self.min_stack or x <= self.min_stack[-1]:\n'
#             '            self.min_stack.append(x)\n'
#             '\n'
#             '    def pop(self) -> None:\n'
#             '        if not self.main_stack:\n'
#             '            return\n'
#             '        \n'
#             '        # If popped element is the current minimum,\n'
#             '        # remove it from min_stack too\n'
#             '        if self.main_stack[-1] == self.min_stack[-1]:\n'
#             '            self.min_stack.pop()\n'
#             '            \n'
#             '        self.main_stack.pop()\n'
#             '\n'
#             '    def getMin(self) -> int:\n'
#             '        if not self.min_stack:\n'
#             '            return None\n'
#             '        return self.min_stack[-1]\n'
#             '\n'
#             '# Example usage:\n'
#             '# stack = MinStack()\n'
#             '# stack.push(3)\n'
#             '# stack.push(2)\n'
#             '# stack.push(5)\n'
#             '# print(stack.getMin())  # Output: 2\n'
#             '# stack.pop()\n'
#             '# stack.pop()\n'
#             '# print(stack.getMin())  # Output: 3',
#   'thoughts': 'For this task, I need to implement a Stack data structure with '
#               'push, pop, and getMin operations, all with O(1) time '
#               'complexity. The challenging part is maintaining the minimum '
#               'value in O(1) time.\n'
#               '\n'
#               'To achieve O(1) for all operations including getMin():\n'
#               "1. We'll use two stacks:\n"
#               '   - main_stack: stores all elements\n'
#               '   - min_stack: keeps track of minimums\n'
#               '2. The min_stack will store elements in a way that its top '
#               'always has the current minimum\n'
#               "3. Push: When pushing, we'll compare with min_stack's top and "
#               'push to min_stack if needed\n'
#               "4. Pop: When popping, we'll also pop from min_stack if the "
#               "popped value equals min_stack's top\n"
#               "5. GetMin: Simply return min_stack's top\n"
#               '\n'
#               'This approach ensures all operations remain O(1) while '
#               'correctly maintaining the minimum value.'},
#  {'result': 'from typing import List, Optional\n'
#             '\n'
#             'class MinStack:\n'
#             '    """A stack data structure that supports constant time push, '
#             'pop, and minimum element retrieval.\n'
#             '    \n'
#             '    This implementation maintains two internal stacks:\n'
#             '    - A main stack for all elements\n'
#             '    - A minimum stack that keeps track of minimums at each state\n'
#             '    \n'
#             '    All operations (push, pop, getMin) are guaranteed to run in '
#             'O(1) time complexity.\n'
#             '    """\n'
#             '    \n'
#             '    def __init__(self) -> None:\n'
#             '        """Initialize an empty MinStack."""\n'
#             '        self.main_stack: List[int] = []  # Stores all elements\n'
#             '        self.min_stack: List[int] = []   # Tracks minimum '
#             'elements\n'
#             '        \n'
#             '    def push(self, x: int) -> None:\n'
#             '        """Push an element onto the stack.\n'
#             '        \n'
#             '        Args:\n'
#             '            x: The integer to be pushed onto the stack\n'
#             '        """\n'
#             '        self.main_stack.append(x)\n'
#             '        # Update min_stack if empty or x is not greater than '
#             'current minimum\n'
#             '        if not self.min_stack or x <= self.min_stack[-1]:\n'
#             '            self.min_stack.append(x)\n'
#             '            \n'
#             '    def pop(self) -> None:\n'
#             '        """Remove the top element from the stack.\n'
#             '        \n'
#             '        Raises:\n'
#             '            IndexError: If the stack is empty\n'
#             '        """\n'
#             '        if not self.main_stack:\n'
#             '            raise IndexError("pop from empty stack")\n'
#             '            \n'
#             '        # If top element is current minimum, update min_stack\n'
#             '        if self.main_stack[-1] == self.min_stack[-1]:\n'
#             '            self.min_stack.pop()\n'
#             '        self.main_stack.pop()\n'
#             '            \n'
#             '    def top(self) -> int:\n'
#             '        """Return the top element without removing it.\n'
#             '        \n'
#             '        Returns:\n'
#             '            The top element of the stack\n'
#             '            \n'
#             '        Raises:\n'
#             '            IndexError: If the stack is empty\n'
#             '        """\n'
#             '        if not self.main_stack:\n'
#             '            raise IndexError("top from empty stack")\n'
#             '        return self.main_stack[-1]\n'
#             '        \n'
#             '    def getMin(self) -> int:\n'
#             '        """Return the minimum element in the stack.\n'
#             '        \n'
#             '        Returns:\n'
#             '            The minimum element in the stack\n'
#             '            \n'
#             '        Raises:\n'
#             '            IndexError: If the stack is empty\n'
#             '        """\n'
#             '        if not self.min_stack:\n'
#             '            raise IndexError("getMin from empty stack")\n'
#             '        return self.min_stack[-1]',
#   'thoughts': "Based on the feedback, I'll improve the solution by:\n"
#               '1. Adding proper exception handling with custom error messages\n'
#               '2. Adding complete type hints including List[int] for stacks\n'
#               '3. Adding comprehensive docstrings for class and methods\n'
#               '4. Making code more professional with better error handling\n'
#               '5. Adding a top() method for completeness\n'
#               '6. Making pop() implementation more concise\n'
#               '\n'
#               'The core logic is working correctly with O(1) time complexity '
#               'for all operations. The main improvements are around code '
#               'quality, documentation, and robustness.'}]
