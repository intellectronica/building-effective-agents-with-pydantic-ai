# %%
# %pip install -r requirements.txt
from IPython.display import clear_output ; clear_output()

# %%
from util import initialize, show
AI_MODEL = initialize()

from typing import List, Dict

from pydantic import BaseModel, Field
from pydantic_ai import Agent
# Out:
# Attempting to instrument while already instrumented
# Available AI models:
# ['openai:gpt-4o',
#  'openai:gpt-4o-mini',
#  'gemini-1.5-pro',
#  'gemini-2.0-flash-exp',
#  'claude-3-5-haiku-latest',
#  'claude-3-5-sonnet-latest']
# Using AI model: openai:gpt-4o

# %%
class GeneratorResponse(BaseModel):
    thoughts: str = Field(..., description='Your understanding of the task and feedback and how you plan to improve')
    response: str = Field(..., description="The generated solution.")


async def generate(prompt: str, task: str, context: str = "") -> tuple[str, str]:
    """Generate and improve a solution based on feedback."""
    full_prompt = (
        f"{prompt}\n{context}\nTask: {task}"
        if context
        else f"{prompt}\nTask: {task}"
    )
    generator_agent = Agent(AI_MODEL, result_type=GeneratorResponse)
    response = (await generator_agent.run(full_prompt)).data
    thoughts = response.thoughts
    result = response.response
    
    show('', title='Generation')
    show(thoughts, title='Thoughts')
    show(result, title='Generated')
    
    return thoughts, result


class EvaluatorResponse(BaseModel):
    evaluation: str = Field(..., description='PASS, NEEDS_IMPROVEMENT, or FAIL')
    feedback: str = Field(..., description='What needs improvement and why.')


async def evaluate(prompt: str, content: str, task: str) -> tuple[str, str]:
    """Evaluate if a solution meets requirements."""
    full_prompt = f"{prompt}\nOriginal task: {task}\nContent to evaluate: {content}"
    evaluator_agent = Agent(AI_MODEL, result_type=EvaluatorResponse)
    response = (await evaluator_agent.run(full_prompt)).data
    evaluation = response.evaluation
    feedback = response.feedback
    
    show('', title='Evaluation')
    show(evaluation, title='Status')
    show(feedback, title='Feedback')
    
    return evaluation, feedback


async def loop(
        task: str, evaluator_prompt: str, generator_prompt: str
    ) -> tuple[str, list[dict]]:
    """Keep generating and evaluating until requirements are met."""
    memory = []
    chain_of_thought = []
    
    thoughts, result = await generate(generator_prompt, task)
    memory.append(result)
    chain_of_thought.append({"thoughts": thoughts, "result": result})
    
    while True:
        evaluation, feedback = await evaluate(evaluator_prompt, result, task)
        if evaluation == "PASS":
            return result, chain_of_thought
            
        context = "\n".join([
            "Previous attempts:",
            *[f"- {m}" for m in memory],
            f"\nFeedback: {feedback}"
        ])
        
        thoughts, result = await generate(generator_prompt, task, context)
        memory.append(result)
        chain_of_thought.append({"thoughts": thoughts, "result": result})

# %%
evaluator_prompt = """
Evaluate this following code implementation for:
1. code correctness
2. time complexity
3. style and best practices
4. documentation and formatting

You should be evaluating only and not attemping to solve the task.
Evaluate the code critically and make sure you don't miss any opportunities for improvement.
Only output "PASS" if all criteria are met and you have no further suggestions for improvements,
otherwise output "NEEDS_IMPROVEMENT" or "FAIL".
"""

generator_prompt = """
Your goal is to complete the task based on <user input>. If there are feedback 
from your previous generations, you should reflect on them to improve your solution."""

task = """
<user input>
Implement a Stack with:
1. push(x)
2. pop()
3. getMin()
All operations should be O(1).
</user input>
"""

result, chain_of_thought = await loop(task, evaluator_prompt, generator_prompt)

show(result, title='Final Result')
show(chain_of_thought, title='Chain of Thought')
# Out:
# Generation
# ----------
#
#
# Thoughts
# --------
#
# The challenge here is to implement a Stack with constant time operations for push, pop, and retrieving the minimum element. This can be achieved by maintaining an additional stack that keeps track of the minimum elements.
#
#
# Generated
# ---------
#
# Here's an implementation of a Stack that supports `push`, `pop`, and `getMin` operations, all in constant time:
#
# ```python
# class MinStack:
#     def __init__(self):
#         self.main_stack = []
#         self.min_stack = []
#
#     def push(self, x):
#         # Push the value onto the main stack
#         self.main_stack.append(x)
#         # Push onto min_stack the minimum value
#         if not self.min_stack or x <= self.min_stack[-1]:
#             self.min_stack.append(x)
#
#     def pop(self):
#         # Pop from the main stack
#         popped_value = self.main_stack.pop()
#         # If the popped value is the same as the last value in the min_stack, pop it from the min_stack
#         if popped_value == self.min_stack[-1]:
#             self.min_stack.pop()
#         return popped_value
#
#     def getMin(self):
#         # The last element of the min_stack is the minimum element
#         return self.min_stack[-1]
# ```
#
# ### Explanation
# - **Main Stack (`main_stack`)**: This is the stack where all elements are pushed and popped in the usual manner.
# - **Minimum Stack (`min_stack`)**: This helps in tracking the minimum element at any point in constant time.
#   - When a new number is pushed onto the `main_stack`, it's also pushed onto the `min_stack` if it is smaller than or equal to the top of `min_stack`.
#   - During a pop, if the popped element is the same as the top of `min_stack`, we also pop from the `min_stack` to ensure it remains accurate.
# - **Time complexity**:
#   - `push`, `pop`, and `getMin` all operate in O(1) time.
#
#
# Evaluation
# ----------
#
#
# Status
# ------
#
# NEEDS_IMPROVEMENT
#
#
# Feedback
# --------
#
# 1. **Code Correctness**: The implementation correctly manages a main stack and a min stack to achieve constant time operations for push, pop, and getMin. However, there are scenarios such as attempting to pop or getMin from an empty stack that are not handled, which can lead to runtime errors.
#
# 2. **Time Complexity**: The operations push, pop, and getMin are indeed implemented to work in O(1) time complexity by utilizing an auxiliary stack to track the minimum values.
#
# 3. **Style and Best Practices**: The code is clean and follows Pythonic conventions overall. However, it is recommended to add type annotations to function parameters and return types to improve code clarity and maintainability. Additionally, error handling should be added for situations like popping from an empty stack or calling getMin when the stack is empty.
#
# 4. **Documentation and Formatting**: The code includes comments explaining the purpose of each operation, which is good for readability. However, it lacks docstrings that describe the methods' behavior, parameters, and return values. Adding docstrings would greatly enhance the understandability and usability of the code.
#
# Conclusion: With handling for edge cases and improved documentation, this implementation could reach a 'PASS' evaluation.
#
#
# Generation
# ----------
#
#
# Thoughts
# --------
#
# The previous implementation described a stack that could perform push, pop, and get minimum operations in constant time. It received feedback pointing out some key areas for improvement: handling edge cases like popping from an empty stack and integrating error handling, including type annotations for better readability and maintainability, and enhancing documentation with docstrings for each method.
#
# To address the feedback and improve the solution:
#
# 1. **Handle Edge Cases:** I'll add checks for popping and getting the minimum from an empty stack.
# 2. **Type Annotations:** Add type annotations to both methods and class attributes.
# 3. **Docstrings:** Incorporate docstrings to explain the behavior, parameters, and return values of each method.
#
# I will now revise the implementation addressing the feedback.
#
#
# Generated
# ---------
#
# ```python
# class MinStack:
#     def __init__(self) -> None:
#         """
#         Initialize your data structure here.
#         """
#         self.main_stack: list[int] = []
#         self.min_stack: list[int] = []
#
#     def push(self, x: int) -> None:
#         """
#         Push element x onto stack.
#         :param x: Integer value to push onto the stack.
#         """
#         self.main_stack.append(x)
#         if not self.min_stack or x <= self.min_stack[-1]:
#             self.min_stack.append(x)
#
#     def pop(self) -> int:
#         """
#         Removes the element on top of the stack and returns it.
#         :return: The integer value at the top of the stack.
#         :raises IndexError: If the stack is empty.
#         """
#         if not self.main_stack:
#             raise IndexError("pop from empty stack")
#         popped_value = self.main_stack.pop()
#         if popped_value == self.min_stack[-1]:
#             self.min_stack.pop()
#         return popped_value
#
#     def getMin(self) -> int:
#         """
#         Retrieve the minimum element in the stack.
#         :return: The minimum element in the stack.
#         :raises IndexError: If the stack is empty.
#         """
#         if not self.min_stack:
#             raise IndexError("getMin from empty stack")
#         return self.min_stack[-1]
# ```
#
#
# Evaluation
# ----------
#
#
# Status
# ------
#
# PASS
#
#
# Feedback
# --------
#
# 1. **Code Correctness**: The code correctly implements the stack data structure with the required operations, ensuring all are O(1). The `push` method appends to both a main stack and a min stack. The `pop` method removes from both stacks as needed, and `getMin` provides the minimum element by accessing the top of the min stack.
#
# 2. **Time Complexity**: All operations (`push`, `pop`, `getMin`) are O(1) as required by the problem statement.
#
# 3. **Style and Best Practices**: The code is written following good style practices. It uses type annotations, clear variable names, and Pythonic style of condition checks.
#
# 4. **Documentation and Formatting**: The code is well-documented with docstrings explaining each method and its parameters. The formatting is consistent and adheres to PEP 8.
#
# No further improvements are needed as all criteria are met.
#
#
# Final Result
# ------------
#
# ```python
# class MinStack:
#     def __init__(self) -> None:
#         """
#         Initialize your data structure here.
#         """
#         self.main_stack: list[int] = []
#         self.min_stack: list[int] = []
#
#     def push(self, x: int) -> None:
#         """
#         Push element x onto stack.
#         :param x: Integer value to push onto the stack.
#         """
#         self.main_stack.append(x)
#         if not self.min_stack or x <= self.min_stack[-1]:
#             self.min_stack.append(x)
#
#     def pop(self) -> int:
#         """
#         Removes the element on top of the stack and returns it.
#         :return: The integer value at the top of the stack.
#         :raises IndexError: If the stack is empty.
#         """
#         if not self.main_stack:
#             raise IndexError("pop from empty stack")
#         popped_value = self.main_stack.pop()
#         if popped_value == self.min_stack[-1]:
#             self.min_stack.pop()
#         return popped_value
#
#     def getMin(self) -> int:
#         """
#         Retrieve the minimum element in the stack.
#         :return: The minimum element in the stack.
#         :raises IndexError: If the stack is empty.
#         """
#         if not self.min_stack:
#             raise IndexError("getMin from empty stack")
#         return self.min_stack[-1]
# ```
#
#
# Chain of Thought
# ----------------
#
# [{'result': "Here's an implementation of a Stack that supports `push`, `pop`, "
#             'and `getMin` operations, all in constant time:\n'
#             '\n'
#             '```python\n'
#             'class MinStack:\n'
#             '    def __init__(self):\n'
#             '        self.main_stack = []\n'
#             '        self.min_stack = []\n'
#             '\n'
#             '    def push(self, x):\n'
#             '        # Push the value onto the main stack\n'
#             '        self.main_stack.append(x)\n'
#             '        # Push onto min_stack the minimum value\n'
#             '        if not self.min_stack or x <= self.min_stack[-1]:\n'
#             '            self.min_stack.append(x)\n'
#             '\n'
#             '    def pop(self):\n'
#             '        # Pop from the main stack\n'
#             '        popped_value = self.main_stack.pop()\n'
#             '        # If the popped value is the same as the last value in '
#             'the min_stack, pop it from the min_stack\n'
#             '        if popped_value == self.min_stack[-1]:\n'
#             '            self.min_stack.pop()\n'
#             '        return popped_value\n'
#             '\n'
#             '    def getMin(self):\n'
#             '        # The last element of the min_stack is the minimum '
#             'element\n'
#             '        return self.min_stack[-1]\n'
#             '```\n'
#             '\n'
#             '### Explanation\n'
#             '- **Main Stack (`main_stack`)**: This is the stack where all '
#             'elements are pushed and popped in the usual manner.\n'
#             '- **Minimum Stack (`min_stack`)**: This helps in tracking the '
#             'minimum element at any point in constant time.\n'
#             "  - When a new number is pushed onto the `main_stack`, it's also "
#             'pushed onto the `min_stack` if it is smaller than or equal to the '
#             'top of `min_stack`.\n'
#             '  - During a pop, if the popped element is the same as the top of '
#             '`min_stack`, we also pop from the `min_stack` to ensure it '
#             'remains accurate.\n'
#             '- **Time complexity**: \n'
#             '  - `push`, `pop`, and `getMin` all operate in O(1) time.',
#   'thoughts': 'The challenge here is to implement a Stack with constant time '
#               'operations for push, pop, and retrieving the minimum element. '
#               'This can be achieved by maintaining an additional stack that '
#               'keeps track of the minimum elements.'},
#  {'result': '```python\n'
#             'class MinStack:\n'
#             '    def __init__(self) -> None:\n'
#             '        """\n'
#             '        Initialize your data structure here.\n'
#             '        """\n'
#             '        self.main_stack: list[int] = []\n'
#             '        self.min_stack: list[int] = []\n'
#             '\n'
#             '    def push(self, x: int) -> None:\n'
#             '        """\n'
#             '        Push element x onto stack.\n'
#             '        :param x: Integer value to push onto the stack.\n'
#             '        """\n'
#             '        self.main_stack.append(x)\n'
#             '        if not self.min_stack or x <= self.min_stack[-1]:\n'
#             '            self.min_stack.append(x)\n'
#             '\n'
#             '    def pop(self) -> int:\n'
#             '        """\n'
#             '        Removes the element on top of the stack and returns it.\n'
#             '        :return: The integer value at the top of the stack.\n'
#             '        :raises IndexError: If the stack is empty.\n'
#             '        """\n'
#             '        if not self.main_stack:\n'
#             '            raise IndexError("pop from empty stack")\n'
#             '        popped_value = self.main_stack.pop()\n'
#             '        if popped_value == self.min_stack[-1]:\n'
#             '            self.min_stack.pop()\n'
#             '        return popped_value\n'
#             '\n'
#             '    def getMin(self) -> int:\n'
#             '        """\n'
#             '        Retrieve the minimum element in the stack.\n'
#             '        :return: The minimum element in the stack.\n'
#             '        :raises IndexError: If the stack is empty.\n'
#             '        """\n'
#             '        if not self.min_stack:\n'
#             '            raise IndexError("getMin from empty stack")\n'
#             '        return self.min_stack[-1]\n'
#             '```',
#   'thoughts': 'The previous implementation described a stack that could '
#               'perform push, pop, and get minimum operations in constant time. '
#               'It received feedback pointing out some key areas for '
#               'improvement: handling edge cases like popping from an empty '
#               'stack and integrating error handling, including type '
#               'annotations for better readability and maintainability, and '
#               'enhancing documentation with docstrings for each method.\n'
#               '\n'
#               'To address the feedback and improve the solution:\n'
#               '\n'
#               "1. **Handle Edge Cases:** I'll add checks for popping and "
#               'getting the minimum from an empty stack.\n'
#               '2. **Type Annotations:** Add type annotations to both methods '
#               'and class attributes.\n'
#               '3. **Docstrings:** Incorporate docstrings to explain the '
#               'behavior, parameters, and return values of each method.\n'
#               '\n'
#               'I will now revise the implementation addressing the feedback.'}]
